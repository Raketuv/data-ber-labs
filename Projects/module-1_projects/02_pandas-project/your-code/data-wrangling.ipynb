# %% [markdown]
# # Project: Data Cleaning and Manipulation with Pandas
#
# Task description:
#
# ## Technical Requirements
#
# * Import the data using Pandas.
# * Examine the data for potential issues.
# * Use at least 8 of the cleaning and manipulation methods you have learned on the data.
# * Produce a Jupyter Notebook that shows the steps you took and the code you used to clean and transform your data set.
# * Export a clean CSV version of your data using Pandas.
#
# ## Necessary Deliverables
#
# The following deliverables should be pushed to your Github repo for this chapter.
#
# * **A cleaned CSV data file** containing the results of your data wrangling work.
# * **A Jupyter Notebook (data-wrangling.ipynb)** containing all Python code and commands used in the importing, cleaning, manipulation, and exporting of your data set.
# * **A ``README.md`` file** containing a detailed explanation of the process followed in the importing, cleaning, manipulation, and exporting of your data as well as your results, obstacles encountered, and lessons learned.

# %%
# Import required
import pandas as pd
import numpy as np
import re

# %%
# Import the data using pandas
df = pd.read_csv("sharkattack.csv", sep=",", engine="python")

# %%
## Examine the dataset for potential issues

# display df

df
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 0               Florida     New Smyrna Beach, Volusia County       Surfing
# 1               Florida     New Smyrna Beach, Volusia County       Surfing
# 2               Florida     New Smyrna Beach, Volusia County       Surfing
# 3              Victoria                     Thirteenth Beach       Surfing
# 4              Victoria                          Bells Beach       Surfing
# ...                 ...                                  ...           ...
# 5987  Western Australia                          Roebuck Bay        Diving
# 5988  Western Australia                                  NaN  Pearl diving
# 5989     North Carolina                       Ocracoke Inlet      Swimming
# 5990                NaN                 Panama Bay 8�N, 79�W           NaN
# 5991   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...   Species   \
# 0                      male    M  ...        NaN
# 1            Chucky Luciano    M  ...        NaN
# 2                      male    M  ...        NaN
# 3           Rory Angiolella    M  ...        NaN
# 4                      male    M  ...  2 m shark
# ...                     ...  ...  ...        ...
# 5987                   male    M  ...        NaN
# 5988                  Ahmun    M  ...        NaN
# 5989  Coast Guard personnel    M  ...        NaN
# 5990        Jules Patterson    M  ...        NaN
# 5991                   male    M  ...        NaN
#
#                      Investigator or Source                             pdf  \
# 0               Orlando Sentinel, 9/19/2016            2016.09.18.c-NSB.pdf
# 1               Orlando Sentinel, 9/19/2016        2016.09.18.b-Luciano.pdf
# 2               Orlando Sentinel, 9/19/2016            2016.09.18.a-NSB.pdf
# 3                        The Age, 9/18/2016       2016.09.17-Angiolella.pdf
# 4                        The Age, 9/16/2016       2016.09.16-BellsBeach.pdf
# ...                                     ...                             ...
# 5987       H. Taunton; N. Bartlett,  p. 234          ND-0005-RoebuckBay.pdf
# 5988  H. Taunton; N. Bartlett,  pp. 233-234               ND-0004-Ahmun.pdf
# 5989   F. Schwartz, p.23; C. Creswell, GSAF  ND-0003-Ocracoke_1900-1905.pdf
# 5990                    The Sun, 10/20/1938      ND-0002-JulesPatterson.pdf
# 5991                             S.W. Baker              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5987  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5988  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5989  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5990  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5991  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.17
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
# ...                                                 ...           ...
# 5987  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 5988  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 5989  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 5990  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 5991  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0     2016.09.18.c           5993         NaN         NaN
# 1     2016.09.18.b           5992         NaN         NaN
# 2     2016.09.18.a           5991         NaN         NaN
# 3       2016.09.17           5990         NaN         NaN
# 4       2016.09.15           5989         NaN         NaN
# ...            ...            ...         ...         ...
# 5987       ND.0005              6         NaN         NaN
# 5988       ND.0004              5         NaN         NaN
# 5989       ND.0003              4         NaN         NaN
# 5990       ND.0002              3         NaN         NaN
# 5991       ND.0001              2         NaN         NaN
#
# [5992 rows x 24 columns]

# %%
# display column names

df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# display column types

df.dtypes
# Out:
# Case Number               object
# Date                      object
# Year                       int64
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int64
# Unnamed: 22               object
# Unnamed: 23               object
# dtype: object

# %%
# display missing cell count per column

df.isna().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
# Unnamed 22 and 23 can be dropped for sure

df = df.drop(['Unnamed: 22', 'Unnamed: 23'],axis=1)

# %%
# Case numbers seem to be duplicates

df = df.drop(['Case Number.1', 'Case Number.2'],axis=1)

# %%
# Check if href formula and href are duplicates

print(df.loc[0,"href formula"])
print(df.loc[0,"href"])

# Create column showing whether they are duplicate

df["href_equal"] = df["href formula"] == df["href"]
# Out:
# http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.18.c-NSB.pdf
# http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.18.c-NSB.pdf

# %%
# Check number of href duplicate

df["href_equal"].value_counts()
# Out:
# True     5938
# False      54
# Name: href_equal, dtype: int64

# %%
# Compare all unequal rows

href_unequal_df = df.loc[df["href_equal"]==False, ["href formula","href"]]

# %%
href_unequal_df
# Out:
#                                            href formula  \
# 20    http://sharkattackfile.net/spreadsheets/pdf_di...
# 27    http://sharkattackfile.net/spreadsheets/pdf_di...
# 61    http://sharkattackfile.net/spreadsheets/pdf_di...
# 107   http://sharkattackfile.net/spreadsheets/pdf_di...
# 114   http://sharkattackfile.net/spreadsheets/pdf_di...
# 134   http://sharkattackfile.net/spreadsheets/pdf_di...
# 180   http://sharkattackfile.net/spreadsheets/pdf_di...
# 193   http://sharkattackfile.net/spreadsheets/pdf_di...
# 232   http://sharkattackfile.net/spreadsheets/pdf_di...
# 262   http://sharkattackfile.net/spreadsheets/pdf_di...
# 263   http://sharkattackfile.net/spreadsheets/pdf_di...
# 264   http://sharkattackfile.net/spreadsheets/pdf_di...
# 271   http://sharkattackfile.net/spreadsheets/pdf_di...
# 272   http://sharkattackfile.net/spreadsheets/pdf_di...
# 293   http://sharkattackfile.net/spreadsheets/pdf_di...
# 305   http://sharkattackfile.net/spreadsheets/pdf_di...
# 323   http://sharkattackfile.net/spreadsheets/pdf_di...
# 347   http://sharkattackfile.net/spreadsheets/pdf_di...
# 361   http://sharkattackfile.net/spreadsheets/pdf_di...
# 362   http://sharkattackfile.net/spreadsheets/pdf_di...
# 363   http://sharkattackfile.net/spreadsheets/pdf_di...
# 364   http://sharkattackfile.net/spreadsheets/pdf_di...
# 365   http://sharkattackfile.net/spreadsheets/pdf_di...
# 367   http://sharkattackfile.net/spreadsheets/pdf_di...
# 377   http://sharkattackfile.net/spreadsheets/pdf_di...
# 378   http://sharkattackfile.net/spreadsheets/pdf_di...
# 379   http://sharkattackfile.net/spreadsheets/pdf_di...
# 380   http://sharkattackfile.net/spreadsheets/pdf_di...
# 381   http://sharkattackfile.net/spreadsheets/pdf_di...
# 382   http://sharkattackfile.net/spreadsheets/pdf_di...
# 383   http://sharkattackfile.net/spreadsheets/pdf_di...
# 384   http://sharkattackfile.net/spreadsheets/pdf_di...
# 448                  pdf-directory/2013.05.27.b-Ena.pdf
# 449   http://sharkattackfile.net/spreadsheets/pdf_di...
# 823   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1217  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1218  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2274  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2477  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3019                                                NaN
# 3549  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3603  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3917  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3928  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4394  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4642  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4668  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4719  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5317  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5458  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5686  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5694  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5819  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5857  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href
# 20    http://sharkattackfile.net/spreadsheets/pdf_di...
# 27    http://sharkattackfile.net/spreadsheets/pdf_di...
# 61    http://sharkattackfile.net/spreadsheets/pdf_di...
# 107   http://sharkattackfile.net/spreadsheets/pdf_di...
# 114   http://sharkattackfile.net/spreadsheets/pdf_di...
# 134   http://sharkattackfile.net/spreadsheets/pdf_di...
# 180   http://sharkattackfile.net/spreadsheets/pdf_di...
# 193                                                 NaN
# 232   http://sharkattackfile.net/spreadsheets/pdf_di...
# 262   http://sharkattackfile.net/spreadsheets/pdf_di...
# 263   http://sharkattackfile.net/spreadsheets/pdf_di...
# 264   http://sharkattackfile.net/spreadsheets/pdf_di...
# 271   http://sharkattackfile.net/spreadsheets/pdf_di...
# 272   http://sharkattackfile.net/spreadsheets/pdf_di...
# 293   http://sharkattackfile.net/spreadsheets/pdf_di...
# 305   http://sharkattackfile.net/spreadsheets/pdf_di...
# 323   http://sharkattackfile.net/spreadsheets/pdf_di...
# 347   http://sharkattackfile.net/spreadsheets/pdf_di...
# 361   http://sharkattackfile.net/spreadsheets/pdf_di...
# 362   http://sharkattackfile.net/spreadsheets/pdf_di...
# 363   http://sharkattackfile.net/spreadsheets/pdf_di...
# 364   http://sharkattackfile.net/spreadsheets/pdf_di...
# 365                  pdf_directory2014.01.04-Riano.pdf
# 367   http://sharkattackfile.net/spreadsheets/pdf_di...
# 377   http://sharkattackfile.net/spreadsheets/pdf_di...
# 378   http://sharkattackfile.net/spreadsheets/pdf_di...
# 379   http://sharkattackfile.net/spreadsheets/pdf_di...
# 380   http://sharkattackfile.net/spreadsheets/pdf_di...
# 381   http://sharkattackfile.net/spreadsheets/pdf_di...
# 382   http://sharkattackfile.net/spreadsheets/pdf_di...
# 383   http://sharkattackfile.net/spreadsheets/pdf_di...
# 384   http://sharkattackfile.net/spreadsheets/pdf_di...
# 448   http://sharkattackfile.net/spreadsheets/pdf_di...
# 449   http://sharkattackfile.net/spreadsheets/pdf_di...
# 823   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1217  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1218  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2274                                                NaN
# 2477  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3019  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3549  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3603  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3917  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3928  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4394  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4642  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4668  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4719  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5317  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5458  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5686                                                NaN
# 5694  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5819  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5857  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# Look at the columns values, do they link to the same object?

print(href_unequal_df.loc[27,"href formula"])
print(href_unequal_df.loc[27,"href"])
# Out:
# http://sharkattackfile.net/spreadsheets/pdf_directory/2016.07.23.a-Cutbirth.pdf
# http://sharkattackfile.net/spreadsheets/pdf_directory/2016.07.23-Cutbirth.pdf

# %%
# Saw a NaN in the second column. Count for NaNs

href_unequal_df.isna().sum()
# Out:
# href formula    1
# href            3
# dtype: int64

# %%
# Copy href to href formula where href formula is NaN. Drop href column.

df.loc[pd.isna(df["href formula"]), ["href formula"]] = df["href"]

# %%
# Check if it worked

df["href formula"].isna().sum()
# Out:
# 0

# %%
# Drop href column and href_equal helper column, rename href formula column

df = df.drop(["href","href_equal"],axis=1)

df = df.rename(columns={"href formula":"href"})

# %%
df
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 0               Florida     New Smyrna Beach, Volusia County       Surfing
# 1               Florida     New Smyrna Beach, Volusia County       Surfing
# 2               Florida     New Smyrna Beach, Volusia County       Surfing
# 3              Victoria                     Thirteenth Beach       Surfing
# 4              Victoria                          Bells Beach       Surfing
# ...                 ...                                  ...           ...
# 5987  Western Australia                          Roebuck Bay        Diving
# 5988  Western Australia                                  NaN  Pearl diving
# 5989     North Carolina                       Ocracoke Inlet      Swimming
# 5990                NaN                 Panama Bay 8�N, 79�W           NaN
# 5991   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age  \
# 0                      male    M   16
# 1            Chucky Luciano    M   36
# 2                      male    M   43
# 3           Rory Angiolella    M  NaN
# 4                      male    M  NaN
# ...                     ...  ...  ...
# 5987                   male    M  NaN
# 5988                  Ahmun    M  NaN
# 5989  Coast Guard personnel    M  NaN
# 5990        Jules Patterson    M  NaN
# 5991                   male    M   15
#
#                                                  Injury Fatal (Y/N)   Time  \
# 0                                 Minor injury to thigh           N  13h00
# 1                                  Lacerations to hands           N  11h00
# 2                              Lacerations to lower leg           N  10h43
# 3                          Struck by fin on chest & leg           N    NaN
# 4                 No injury: Knocked off board by shark           N    NaN
# ...                                                 ...         ...    ...
# 5987                                              FATAL           Y    NaN
# 5988                                              FATAL           Y    NaN
# 5989                                              FATAL           Y    NaN
# 5990                                              FATAL           Y    NaN
# 5991  FATAL. "Shark bit him in half, carrying away t...           Y    NaN
#
#        Species                  Investigator or Source  \
# 0           NaN            Orlando Sentinel, 9/19/2016
# 1           NaN            Orlando Sentinel, 9/19/2016
# 2           NaN            Orlando Sentinel, 9/19/2016
# 3           NaN                     The Age, 9/18/2016
# 4     2 m shark                     The Age, 9/16/2016
# ...         ...                                    ...
# 5987        NaN       H. Taunton; N. Bartlett,  p. 234
# 5988        NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 5989        NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 5990        NaN                    The Sun, 10/20/1938
# 5991        NaN                             S.W. Baker
#
#                                  pdf  \
# 0               2016.09.18.c-NSB.pdf
# 1           2016.09.18.b-Luciano.pdf
# 2               2016.09.18.a-NSB.pdf
# 3          2016.09.17-Angiolella.pdf
# 4          2016.09.16-BellsBeach.pdf
# ...                              ...
# 5987          ND-0005-RoebuckBay.pdf
# 5988               ND-0004-Ahmun.pdf
# 5989  ND-0003-Ocracoke_1900-1905.pdf
# 5990      ND-0002-JulesPatterson.pdf
# 5991              ND-0001-Ceylon.pdf
#
#                                                    href  original order
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...            5993
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...            5992
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...            5991
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...            5990
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...            5989
# ...                                                 ...             ...
# 5987  http://sharkattackfile.net/spreadsheets/pdf_di...               6
# 5988  http://sharkattackfile.net/spreadsheets/pdf_di...               5
# 5989  http://sharkattackfile.net/spreadsheets/pdf_di...               4
# 5990  http://sharkattackfile.net/spreadsheets/pdf_di...               3
# 5991  http://sharkattackfile.net/spreadsheets/pdf_di...               2
#
# [5992 rows x 19 columns]

# %%
# Check what pdf column is

print(df.loc[0,"pdf"])
print(df.loc[0,"href"])
# Out:
# 2016.09.18.c-NSB.pdf
# http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.18.c-NSB.pdf

# %%
# It's just another variation of href. drop pdf.

df = df.drop(columns="pdf",index=1)

# %%
# Check if some case numbers are duplicated

df["Case Number"].value_counts().gt(1)
# Out:
# 1980.07.00       True
# 1962.06.11.b     True
# 1966.12.26       True
# 1923.00.00.a     True
# 2014.08.02       True
#                 ...
# 1878.11.17      False
# 1992.11.12.R    False
# 1903.00.00.b    False
# 1983.08.06      False
# 1908.06.02.R    False
# Name: Case Number, Length: 5975, dtype: bool

# %%
# Look into duplicated case number rows

dupdf = df[df.duplicated(['Case Number'])]
dupdf
# Out:
#          Case Number                  Date  Year        Type       Country  \
# 301       2014.08.02             02-Aug-14  2014  Unprovoked           USA
# 393       2013.10.05             10-Oct-13  2013  Unprovoked           USA
# 524     2012.09.02.b             02-Sep-12  2012    Provoked           USA
# 841       2009.12.18             18-Dec-09  2009     Invalid  SOUTH AFRICA
# 1213      2006.09.02             02-Sep-06  2006  Unprovoked  SOUTH AFRICA
# 1376      2005.04.06             06-Apr-05  2005     Invalid      HONDURAS
# 2410      1990.05.10             10-May-90  1990  Unprovoked     AUSTRALIA
# 2713      1983.06.15             15-Jun-83  1983     Invalid         ITALY
# 2838      1980.07.00        Early Jul-1980  1980  Unprovoked           USA
# 3318      1966.12.26             26-Dec-66  1966  Unprovoked     AUSTRALIA
# 3589    1962.06.11.b             11-Jun-62  1962  Unprovoked           USA
# 4983    1923.00.00.a                  1923  1922    Provoked           USA
# 5029    1920.00.00.b                  1920  1920  Unprovoked   NEW ZEALAND
# 5091  1915.07.06.a.R  Reported 06-Jul-1915  1915  Unprovoked        MEXICO
# 5121    1913.08.27.R  Reported 27-Aug-1913  1913     Invalid           USA
# 5208    1907.10.16.R  Reported 16-Oct-1907  1907  Unprovoked         CHINA
#
#                        Area                                         Location  \
# 301                 Florida                      Table Beach, Brevard County
# 393                 Florida                          Destin, Okaloosa County
# 524                  Hawaii                             Spreckelsville, Maui
# 841           KwaZulu-Natal                              North Beach, Durban
# 1213  Western Cape Province                                        Noordhoek
# 1376            Bay Islands                                            Utila
# 2410             Queensland             Outer Barrier Reef near Port Douglas
# 2713        Northwest Italy                             Riomaggiore (Ligura)
# 2838                Florida                 New Smyrna Beach, Volusia County
# 3318        New South Wales                                           Coogee
# 3589             California                                San Francisco Bay
# 4983             New Jersey                            Ocean City (offshore)
# 5029           North Island                     Stanley Bay, Auckland Harbor
# 5091                    NaN                                  Santa Maria Bar
# 5121             New Jersey                     Spring Lake, Monmouth County
# 5208              Hong Kong  Sharp Peak, Sai Kung Peninsula, New Territories
#
#                                  Activity                      Name Sex   Age  \
# 301                       Boogie boarding        Christian Sanhueza    M    8
# 393                                Wading  Zachary Tyke Standridge     M   12
# 524                          Spearfishing                M. Malabon  NaN  NaN
# 841                               Surfing              Lance Morris    M  NaN
# 1213                              Surfing      Steven Harcourt-Wood    M   37
# 1376                         SCUBA Diving                    female    F  NaN
# 2410  Snorkeling, possibly holding a fish               German male    M  30s
# 2713                         Scuba diving          Roberto Piaviali    M  NaN
# 2838                              Surfing              Tom Durrance    M  NaN
# 3318                         Spearfishing              David Jensen    M   29
# 3589              Escaping from Alacatraz      John William Anglin     M   32
# 4983   Hoisting shark aboard fishing boat                      male    M  NaN
# 5029                                  NaN                    female    F  NaN
# 5091                               Wading             J.W. McDonald    M  NaN
# 5121                                  NaN                       NaN    F  NaN
# 5208                              Fishing                 fishermen    M  NaN
#
#                                                  Injury Fatal (Y/N)   Time  \
# 301                                 Laceration to ankle           N  13h00
# 393                       Lacerations to  right forearm           N  15h30
# 524         Minor laceration to hand  PROVOKED INCIDENT           N  12h00
# 841   Minor lacerations to left leg. nitially report...           N    NaN
# 1213                  No injury, shark rammed surfboard           N    NaN
# 1376  Laceration on siide of calf, small laceration ...           N    NaN
# 2410                                        Lacerations           N    NaN
# 2713    No injury, shark "harassed" him at depth of 5 m           N    NaN
# 2838                                   Lower leg bitten           N    NaN
# 3318                                   Right leg bitten           N    NaN
# 3589  FATAL, but shark involvement uncomfirmed. Deat...           Y  Night
# 4983      Shark's tail broke his leg. PROVOKED INCIDENT           N    NaN
# 5029                                        "Recovered"           N    NaN
# 5091                                              FATAL           Y    NaN
# 5121                   Female foot recovered from shark     UNKNOWN    NaN
# 5208   2 of the 5 fishermen were so seriously injure...           Y    NaN
#
#                              Species   \
# 301                               NaN
# 393                  Small bull shark
# 524          Tiger shark, 10' to 12'
# 841              No shark involvement
# 1213               White shark, 3.5m
# 1376  Shark involvement not confirmed
# 2410                   2 m hammerhead
# 2713            3 m [10'] white shark
# 2838                              NaN
# 3318                 1.8 m [6'] shark
# 3589                              NaN
# 4983                              NaN
# 5029                              NaN
# 5091                              NaN
# 5121                              NaN
# 5208       Shark involvement probable
#
#                                  Investigator or Source  \
# 301                             Florida Today, 8/2/2014
# 393                   Monroe County Advocate, 10/9/2013
# 524                                       HawaiiNow.com
# 841                     M. Addison, C. Eckstander, GSAF
# 1213                               Cape Times, 9/3/2006
# 1376                  J. Engel, SRI & S. Fox, Deep Blue
# 2410                       Courier-Mail, 5/11/1990, p.1
# 2713                                             MEDSAF
# 2838            Daytona Beach Morning Journal, 7/9/1980
# 3318    Sun (Sydney), 12/29/1966; H.D. Baldridge, p.137
# 3589                  San Francisco Chronicle, 5/3/1986
# 4983  Ref in New York Herald Tribune, 8/23/1960; V.M...
# 5029                       V.M. Coppleson (1958), p.262
# 5091                          Oakland Tribune, 7/6/1915
# 5121                         Washington Post, 8/27/1913
# 5208                      Dawson Daily News, 11/20/1907
#
#                                                    href  original order
# 301   http://sharkattackfile.net/spreadsheets/pdf_di...            5691
# 393   http://sharkattackfile.net/spreadsheets/pdf_di...            5600
# 524   http://sharkattackfile.net/spreadsheets/pdf_di...            5469
# 841   http://sharkattackfile.net/spreadsheets/pdf_di...            5152
# 1213  http://sharkattackfile.net/spreadsheets/pdf_di...            4780
# 1376  http://sharkattackfile.net/spreadsheets/pdf_di...            4617
# 2410  http://sharkattackfile.net/spreadsheets/pdf_di...            3584
# 2713  http://sharkattackfile.net/spreadsheets/pdf_di...            3280
# 2838  http://sharkattackfile.net/spreadsheets/pdf_di...            3155
# 3318  http://sharkattackfile.net/spreadsheets/pdf_di...            2675
# 3589  http://sharkattackfile.net/spreadsheets/pdf_di...            2404
# 4983  http://sharkattackfile.net/spreadsheets/pdf_di...            1010
# 5029  http://sharkattackfile.net/spreadsheets/pdf_di...             964
# 5091  http://sharkattackfile.net/spreadsheets/pdf_di...             902
# 5121  http://sharkattackfile.net/spreadsheets/pdf_di...             872
# 5208  http://sharkattackfile.net/spreadsheets/pdf_di...             785

# %%
# Check if any rows in the whole df are duplicates

df.duplicated().value_counts()
# Out:
# False    5991
# dtype: int64

# %%
# Compare with number of duplicate case number rows

df.duplicated(['Case Number']).value_counts()
# Out:
# False    5975
# True       16
# dtype: int64

# %%
# Create list of duplicate case number columns

dup_case_no_list = list(df["Case Number"].value_counts().gt(1).index)
lis = dup_case_no_list

# %%
# Check if they are very similar, check one random item 6

df.loc[df['Case Number'] == lis[6]]
# Out:
#        Case Number                  Date  Year        Type Country       Area  \
# 5207  1907.10.16.R  Reported 16-Oct-1907  1907  Unprovoked   CHINA  Hong Kong
# 5208  1907.10.16.R  Reported 16-Oct-1907  1907  Unprovoked   CHINA  Hong Kong
#
#                                              Location Activity       Name  \
# 5207  Sharp Peak, Sai Kung Peninsula, New Territories  Fishing  fishermen
# 5208  Sharp Peak, Sai Kung Peninsula, New Territories  Fishing  fishermen
#
#      Sex   Age                                             Injury Fatal (Y/N)  \
# 5207    M  NaN  3 of thel 5 were injured, one of whom lost bot...           N
# 5208    M  NaN   2 of the 5 fishermen were so seriously injure...           Y
#
#      Time                    Species          Investigator or Source  \
# 5207  NaN  Shark involvement probable  Dawson Daily News, 11/20/1907
# 5208  NaN  Shark involvement probable  Dawson Daily News, 11/20/1907
#
#                                                    href  original order
# 5207  http://sharkattackfile.net/spreadsheets/pdf_di...             786
# 5208  http://sharkattackfile.net/spreadsheets/pdf_di...             785

# %%
# Duplicate case numbers are not duplicate caes. Since case numbers just seem to be a variation of date, they can be dropped. 

df = df.drop(columns="Case Number")

# %%
# Check out date column values

lis = list(df["Date"].value_counts().index)

# %%
# Replace words such as reported, early and summer, mid, before

removelist = ["Reported", "reported", "Early", "early", "Summer", "summer", "mid", "Mid", "before", "Before"]

for i in removelist:
    df["Date"] = df["Date"].str.replace(i,"")

# %%
df["Date"].value_counts()
# Out:
# 1957              11
# 1942               9
# 1956               8
# 1958               7
# 1941               7
#                   ..
# 29-Dec-63          1
#  30-March-1878     1
# 12-30-1980         1
# 12-Feb-88          1
#  28-Mar-1928       1
# Name: Date, Length: 5124, dtype: int64

# %%
# Furthermore, merge date and year columns into one uniform date format columns.

df['Date'] = pd.to_datetime(df['Date'], errors = "coerce")

# %%
# Check datetime

list(df["Date"].value_counts().index)
# Out:
# [Timestamp('1958-01-01 00:00:00'),
#  Timestamp('1957-01-01 00:00:00'),
#  Timestamp('1942-01-01 00:00:00'),
#  Timestamp('1956-01-01 00:00:00'),
#  Timestamp('1950-01-01 00:00:00'),
#  Timestamp('1941-01-01 00:00:00'),
#  Timestamp('1960-01-01 00:00:00'),
#  Timestamp('1898-01-01 00:00:00'),
#  Timestamp('1959-01-01 00:00:00'),
#  Timestamp('2060-10-01 00:00:00'),
#  Timestamp('2056-08-01 00:00:00'),
#  Timestamp('1949-01-01 00:00:00'),
#  Timestamp('1876-01-01 00:00:00'),
#  Timestamp('1952-01-01 00:00:00'),
#  Timestamp('1954-01-01 00:00:00'),
#  Timestamp('1971-01-01 00:00:00'),
#  Timestamp('1955-01-01 00:00:00'),
#  Timestamp('2001-04-12 00:00:00'),
#  Timestamp('1940-01-01 00:00:00'),
#  Timestamp('1961-01-01 00:00:00'),
#  Timestamp('2003-10-05 00:00:00'),
#  Timestamp('1938-01-01 00:00:00'),
#  Timestamp('1995-07-28 00:00:00'),
#  Timestamp('1911-01-01 00:00:00'),
#  Timestamp('1948-01-01 00:00:00'),
#  Timestamp('2060-04-01 00:00:00'),
#  Timestamp('1890-01-01 00:00:00'),
#  Timestamp('1998-01-01 00:00:00'),
#  Timestamp('1970-01-23 00:00:00'),
#  Timestamp('1906-01-01 00:00:00'),
#  Timestamp('2012-01-01 00:00:00'),
#  Timestamp('1883-01-01 00:00:00'),
#  Timestamp('1945-01-01 00:00:00'),
#  Timestamp('1929-01-01 00:00:00'),
#  Timestamp('2010-01-09 00:00:00'),
#  Timestamp('2009-07-24 00:00:00'),
#  Timestamp('1926-01-01 00:00:00'),
#  Timestamp('2015-09-20 00:00:00'),
#  Timestamp('1930-01-01 00:00:00'),
#  Timestamp('1996-01-01 00:00:00'),
#  Timestamp('2008-12-27 00:00:00'),
#  Timestamp('2052-07-27 00:00:00'),
#  Timestamp('2008-06-26 00:00:00'),
#  Timestamp('1994-07-09 00:00:00'),
#  Timestamp('1985-01-01 00:00:00'),
#  Timestamp('2012-06-14 00:00:00'),
#  Timestamp('2014-12-28 00:00:00'),
#  Timestamp('1995-01-01 00:00:00'),
#  Timestamp('1943-01-01 00:00:00'),
#  Timestamp('1906-10-10 00:00:00'),
#  Timestamp('1965-01-01 00:00:00'),
#  Timestamp('1962-01-01 00:00:00'),
#  Timestamp('2011-06-06 00:00:00'),
#  Timestamp('1905-01-01 00:00:00'),
#  Timestamp('2011-08-17 00:00:00'),
#  Timestamp('1981-01-01 00:00:00'),
#  Timestamp('2004-05-22 00:00:00'),
#  Timestamp('2001-08-19 00:00:00'),
#  Timestamp('2003-06-24 00:00:00'),
#  Timestamp('2002-09-27 00:00:00'),
#  Timestamp('2003-10-31 00:00:00'),
#  Timestamp('2008-06-28 00:00:00'),
#  Timestamp('1913-01-01 00:00:00'),
#  Timestamp('2064-02-01 00:00:00'),
#  Timestamp('2014-06-01 00:00:00'),
#  Timestamp('2014-08-27 00:00:00'),
#  Timestamp('2010-05-18 00:00:00'),
#  Timestamp('2004-07-27 00:00:00'),
#  Timestamp('2012-09-02 00:00:00'),
#  Timestamp('2013-06-25 00:00:00'),
#  Timestamp('1982-08-29 00:00:00'),
#  Timestamp('2013-07-28 00:00:00'),
#  Timestamp('1968-01-01 00:00:00'),
#  Timestamp('2062-01-11 00:00:00'),
#  Timestamp('2006-08-20 00:00:00'),
#  Timestamp('2009-03-06 00:00:00'),
#  Timestamp('2060-11-01 00:00:00'),
#  Timestamp('1903-01-01 00:00:00'),
#  Timestamp('1886-08-01 00:00:00'),
#  Timestamp('1974-01-07 00:00:00'),
#  Timestamp('1998-05-16 00:00:00'),
#  Timestamp('2058-07-01 00:00:00'),
#  Timestamp('2001-04-11 00:00:00'),
#  Timestamp('2003-09-14 00:00:00'),
#  Timestamp('1997-08-11 00:00:00'),
#  Timestamp('2007-08-19 00:00:00'),
#  Timestamp('1953-01-01 00:00:00'),
#  Timestamp('2005-04-06 00:00:00'),
#  Timestamp('2053-03-01 00:00:00'),
#  Timestamp('2061-12-28 00:00:00'),
#  Timestamp('2001-08-18 00:00:00'),
#  Timestamp('2042-11-01 00:00:00'),
#  Timestamp('1974-08-16 00:00:00'),
#  Timestamp('2013-09-21 00:00:00'),
#  Timestamp('2064-01-01 00:00:00'),
#  Timestamp('1992-03-08 00:00:00'),
#  Timestamp('1991-07-01 00:00:00'),
#  Timestamp('1982-01-01 00:00:00'),
#  Timestamp('1999-03-18 00:00:00'),
#  Timestamp('2016-07-08 00:00:00'),
#  Timestamp('1972-01-01 00:00:00'),
#  Timestamp('2012-07-07 00:00:00'),
#  Timestamp('2014-03-18 00:00:00'),
#  Timestamp('1904-01-01 00:00:00'),
#  Timestamp('2012-06-26 00:00:00'),
#  Timestamp('2014-06-09 00:00:00'),
#  Timestamp('1871-01-01 00:00:00'),
#  Timestamp('2003-04-20 00:00:00'),
#  Timestamp('2009-01-24 00:00:00'),
#  Timestamp('2013-09-01 00:00:00'),
#  Timestamp('1999-01-01 00:00:00'),
#  Timestamp('2016-07-12 00:00:00'),
#  Timestamp('1996-02-09 00:00:00'),
#  Timestamp('2015-10-17 00:00:00'),
#  Timestamp('2015-06-24 00:00:00'),
#  Timestamp('1973-01-01 00:00:00'),
#  Timestamp('1899-08-08 00:00:00'),
#  Timestamp('2034-04-01 00:00:00'),
#  Timestamp('1963-01-01 00:00:00'),
#  Timestamp('1927-01-01 00:00:00'),
#  Timestamp('1977-03-13 00:00:00'),
#  Timestamp('2062-06-11 00:00:00'),
#  Timestamp('2008-03-28 00:00:00'),
#  Timestamp('2010-02-06 00:00:00'),
#  Timestamp('2061-02-01 00:00:00'),
#  Timestamp('2016-07-07 00:00:00'),
#  Timestamp('1939-01-01 00:00:00'),
#  Timestamp('2061-01-06 00:00:00'),
#  Timestamp('1923-01-01 00:00:00'),
#  Timestamp('2062-01-14 00:00:00'),
#  Timestamp('2005-11-25 00:00:00'),
#  Timestamp('1997-05-31 00:00:00'),
#  Timestamp('1999-12-31 00:00:00'),
#  Timestamp('2014-05-14 00:00:00'),
#  Timestamp('2066-05-20 00:00:00'),
#  Timestamp('2008-08-30 00:00:00'),
#  Timestamp('1946-01-01 00:00:00'),
#  Timestamp('2015-06-26 00:00:00'),
#  Timestamp('2007-09-30 00:00:00'),
#  Timestamp('2000-09-08 00:00:00'),
#  Timestamp('1921-01-01 00:00:00'),
#  Timestamp('1885-07-26 00:00:00'),
#  Timestamp('2005-04-16 00:00:00'),
#  Timestamp('2066-08-27 00:00:00'),
#  Timestamp('1989-08-22 00:00:00'),
#  Timestamp('2008-05-07 00:00:00'),
#  Timestamp('1990-08-19 00:00:00'),
#  Timestamp('2040-07-13 00:00:00'),
#  Timestamp('1995-04-09 00:00:00'),
#  Timestamp('1849-06-08 00:00:00'),
#  Timestamp('1984-10-21 00:00:00'),
#  Timestamp('1882-11-12 00:00:00'),
#  Timestamp('2065-11-03 00:00:00'),
#  Timestamp('2063-12-26 00:00:00'),
#  Timestamp('2002-01-30 00:00:00'),
#  Timestamp('2060-02-27 00:00:00'),
#  Timestamp('1970-09-01 00:00:00'),
#  Timestamp('2002-10-05 00:00:00'),
#  Timestamp('2015-08-18 00:00:00'),
#  Timestamp('1974-01-01 00:00:00'),
#  Timestamp('1776-01-01 00:00:00'),
#  Timestamp('1975-07-30 00:00:00'),
#  Timestamp('2058-07-04 00:00:00'),
#  Timestamp('2001-01-24 00:00:00'),
#  Timestamp('1986-12-06 00:00:00'),
#  Timestamp('2067-08-01 00:00:00'),
#  Timestamp('2004-01-21 00:00:00'),
#  Timestamp('2047-11-14 00:00:00'),
#  Timestamp('2013-03-10 00:00:00'),
#  Timestamp('2029-03-04 00:00:00'),
#  Timestamp('2000-11-06 00:00:00'),
#  Timestamp('2011-10-29 00:00:00'),
#  Timestamp('2044-10-25 00:00:00'),
#  Timestamp('2006-02-12 00:00:00'),
#  Timestamp('2067-11-30 00:00:00'),
#  Timestamp('2012-01-18 00:00:00'),
#  Timestamp('1975-11-19 00:00:00'),
#  Timestamp('1988-07-04 00:00:00'),
#  Timestamp('2008-07-24 00:00:00'),
#  Timestamp('2002-11-28 00:00:00'),
#  Timestamp('2000-07-04 00:00:00'),
#  Timestamp('1984-01-01 00:00:00'),
#  Timestamp('2037-10-24 00:00:00'),
#  Timestamp('1996-07-23 00:00:00'),
#  Timestamp('2006-07-29 00:00:00'),
#  Timestamp('1997-02-28 00:00:00'),
#  Timestamp('1894-06-15 00:00:00'),
#  Timestamp('2001-04-13 00:00:00'),
#  Timestamp('2012-03-14 00:00:00'),
#  Timestamp('2013-04-13 00:00:00'),
#  Timestamp('2012-06-22 00:00:00'),
#  Timestamp('2000-09-10 00:00:00'),
#  Timestamp('1990-05-10 00:00:00'),
#  Timestamp('2016-07-13 00:00:00'),
#  Timestamp('1970-06-13 00:00:00'),
#  Timestamp('1993-08-15 00:00:00'),
#  Timestamp('2014-02-07 00:00:00'),
#  Timestamp('2041-11-27 00:00:00'),
#  Timestamp('1894-04-28 00:00:00'),
#  Timestamp('2016-03-28 00:00:00'),
#  Timestamp('1994-01-31 00:00:00'),
#  Timestamp('1997-08-14 00:00:00'),
#  Timestamp('2013-08-26 00:00:00'),
#  Timestamp('2007-04-20 00:00:00'),
#  Timestamp('2016-06-15 00:00:00'),
#  Timestamp('1994-07-08 00:00:00'),
#  Timestamp('1989-01-20 00:00:00'),
#  Timestamp('2012-06-02 00:00:00'),
#  Timestamp('1996-04-25 00:00:00'),
#  Timestamp('2012-04-19 00:00:00'),
#  Timestamp('2013-03-21 00:00:00'),
#  Timestamp('1983-07-25 00:00:00'),
#  Timestamp('2059-01-17 00:00:00'),
#  Timestamp('2014-08-09 00:00:00'),
#  Timestamp('2016-06-05 00:00:00'),
#  Timestamp('2007-09-22 00:00:00'),
#  Timestamp('1986-10-01 00:00:00'),
#  Timestamp('2046-02-10 00:00:00'),
#  Timestamp('1995-08-10 00:00:00'),
#  Timestamp('2065-05-01 00:00:00'),
#  Timestamp('1897-03-15 00:00:00'),
#  Timestamp('2000-07-02 00:00:00'),
#  Timestamp('1998-04-01 00:00:00'),
#  Timestamp('1998-10-01 00:00:00'),
#  Timestamp('2043-07-01 00:00:00'),
#  Timestamp('2034-12-31 00:00:00'),
#  Timestamp('1993-01-01 00:00:00'),
#  Timestamp('2009-01-11 00:00:00'),
#  Timestamp('1999-09-04 00:00:00'),
#  Timestamp('2008-04-20 00:00:00'),
#  Timestamp('2015-08-29 00:00:00'),
#  Timestamp('2004-03-31 00:00:00'),
#  Timestamp('1992-01-29 00:00:00'),
#  Timestamp('2055-02-01 00:00:00'),
#  Timestamp('2007-09-03 00:00:00'),
#  Timestamp('2006-09-03 00:00:00'),
#  Timestamp('2001-09-30 00:00:00'),
#  Timestamp('2012-11-04 00:00:00'),
#  Timestamp('2009-06-02 00:00:00'),
#  Timestamp('2063-12-22 00:00:00'),
#  Timestamp('1937-01-01 00:00:00'),
#  Timestamp('1944-01-01 00:00:00'),
#  Timestamp('1982-02-14 00:00:00'),
#  Timestamp('2060-06-27 00:00:00'),
#  Timestamp('1987-01-01 00:00:00'),
#  Timestamp('2011-08-24 00:00:00'),
#  Timestamp('1992-07-08 00:00:00'),
#  Timestamp('2002-05-22 00:00:00'),
#  Timestamp('1993-06-11 00:00:00'),
#  Timestamp('2014-10-05 00:00:00'),
#  Timestamp('2006-01-01 00:00:00'),
#  Timestamp('2011-09-17 00:00:00'),
#  Timestamp('2004-06-26 00:00:00'),
#  Timestamp('2002-03-15 00:00:00'),
#  Timestamp('2000-07-15 00:00:00'),
#  Timestamp('2044-10-26 00:00:00'),
#  Timestamp('2007-08-09 00:00:00'),
#  Timestamp('2013-08-31 00:00:00'),
#  Timestamp('1920-01-01 00:00:00'),
#  Timestamp('2008-07-25 00:00:00'),
#  Timestamp('1999-10-30 00:00:00'),
#  Timestamp('1991-06-07 00:00:00'),
#  Timestamp('2061-04-16 00:00:00'),
#  Timestamp('2001-09-15 00:00:00'),
#  Timestamp('2015-05-29 00:00:00'),
#  Timestamp('2049-08-28 00:00:00'),
#  Timestamp('2000-05-07 00:00:00'),
#  Timestamp('1995-08-26 00:00:00'),
#  Timestamp('1853-01-01 00:00:00'),
#  Timestamp('2056-09-01 00:00:00'),
#  Timestamp('2013-08-25 00:00:00'),
#  Timestamp('2013-05-27 00:00:00'),
#  Timestamp('2055-08-01 00:00:00'),
#  Timestamp('2008-05-10 00:00:00'),
#  Timestamp('2007-12-21 00:00:00'),
#  Timestamp('1998-11-02 00:00:00'),
#  Timestamp('2002-06-13 00:00:00'),
#  Timestamp('2014-11-08 00:00:00'),
#  Timestamp('2059-12-19 00:00:00'),
#  Timestamp('1971-04-05 00:00:00'),
#  Timestamp('2010-08-10 00:00:00'),
#  Timestamp('1987-03-30 00:00:00'),
#  Timestamp('1878-01-01 00:00:00'),
#  Timestamp('2065-11-21 00:00:00'),
#  Timestamp('2011-03-21 00:00:00'),
#  Timestamp('2035-01-24 00:00:00'),
#  Timestamp('2007-06-30 00:00:00'),
#  Timestamp('2002-06-09 00:00:00'),
#  Timestamp('2059-06-14 00:00:00'),
#  Timestamp('2058-07-27 00:00:00'),
#  Timestamp('2015-11-15 00:00:00'),
#  Timestamp('1996-09-02 00:00:00'),
#  Timestamp('1920-01-24 00:00:00'),
#  Timestamp('1998-05-29 00:00:00'),
#  Timestamp('1970-01-01 00:00:00'),
#  Timestamp('2059-08-15 00:00:00'),
#  Timestamp('2015-11-01 00:00:00'),
#  Timestamp('2014-10-17 00:00:00'),
#  Timestamp('2011-08-16 00:00:00'),
#  Timestamp('2016-07-26 00:00:00'),
#  Timestamp('2013-02-21 00:00:00'),
#  Timestamp('1996-10-03 00:00:00'),
#  Timestamp('2004-10-09 00:00:00'),
#  Timestamp('1995-08-22 00:00:00'),
#  Timestamp('1972-10-21 00:00:00'),
#  Timestamp('1989-09-09 00:00:00'),
#  Timestamp('2057-04-07 00:00:00'),
#  Timestamp('2009-07-22 00:00:00'),
#  Timestamp('1986-09-01 00:00:00'),
#  Timestamp('2003-11-06 00:00:00'),
#  Timestamp('1977-12-19 00:00:00'),
#  Timestamp('2010-06-25 00:00:00'),
#  Timestamp('1991-04-16 00:00:00'),
#  Timestamp('2015-11-10 00:00:00'),
#  Timestamp('2013-07-29 00:00:00'),
#  Timestamp('2004-06-10 00:00:00'),
#  Timestamp('1988-06-16 00:00:00'),
#  Timestamp('1981-08-10 00:00:00'),
#  Timestamp('2010-10-02 00:00:00'),
#  Timestamp('1981-10-19 00:00:00'),
#  Timestamp('1842-01-01 00:00:00'),
#  Timestamp('2061-09-24 00:00:00'),
#  Timestamp('2015-07-23 00:00:00'),
#  Timestamp('1901-01-01 00:00:00'),
#  Timestamp('2006-08-22 00:00:00'),
#  Timestamp('1915-07-06 00:00:00'),
#  Timestamp('2042-11-13 00:00:00'),
#  Timestamp('1988-04-15 00:00:00'),
#  Timestamp('1993-08-19 00:00:00'),
#  Timestamp('2015-06-27 00:00:00'),
#  Timestamp('2062-08-01 00:00:00'),
#  Timestamp('1994-05-31 00:00:00'),
#  Timestamp('1984-07-01 00:00:00'),
#  Timestamp('2002-01-01 00:00:00'),
#  Timestamp('2015-03-29 00:00:00'),
#  Timestamp('2004-07-02 00:00:00'),
#  Timestamp('2009-12-18 00:00:00'),
#  Timestamp('2043-05-17 00:00:00'),
#  Timestamp('2014-12-29 00:00:00'),
#  Timestamp('1936-01-01 00:00:00'),
#  Timestamp('2062-01-07 00:00:00'),
#  Timestamp('2059-09-26 00:00:00'),
#  Timestamp('2016-04-07 00:00:00'),
#  Timestamp('2010-09-03 00:00:00'),
#  Timestamp('2064-07-08 00:00:00'),
#  Timestamp('2015-06-25 00:00:00'),
#  Timestamp('2003-11-30 00:00:00'),
#  Timestamp('2010-11-30 00:00:00'),
#  Timestamp('2015-07-26 00:00:00'),
#  Timestamp('2009-12-20 00:00:00'),
#  Timestamp('2046-01-24 00:00:00'),
#  Timestamp('2062-03-25 00:00:00'),
#  Timestamp('2047-11-08 00:00:00'),
#  Timestamp('2062-08-30 00:00:00'),
#  Timestamp('2014-04-12 00:00:00'),
#  Timestamp('2008-05-24 00:00:00'),
#  Timestamp('2011-09-20 00:00:00'),
#  Timestamp('2016-05-21 00:00:00'),
#  Timestamp('1983-06-15 00:00:00'),
#  Timestamp('2031-09-21 00:00:00'),
#  Timestamp('2000-08-21 00:00:00'),
#  Timestamp('1987-07-12 00:00:00'),
#  Timestamp('1972-10-14 00:00:00'),
#  Timestamp('2061-12-18 00:00:00'),
#  Timestamp('1893-06-22 00:00:00'),
#  Timestamp('2009-12-05 00:00:00'),
#  Timestamp('1998-07-06 00:00:00'),
#  Timestamp('2009-02-07 00:00:00'),
#  Timestamp('1997-08-02 00:00:00'),
#  Timestamp('2064-02-14 00:00:00'),
#  Timestamp('1860-04-01 00:00:00'),
#  Timestamp('2055-03-01 00:00:00'),
#  Timestamp('2009-03-01 00:00:00'),
#  Timestamp('1882-01-01 00:00:00'),
#  Timestamp('1978-01-01 00:00:00'),
#  Timestamp('1976-09-12 00:00:00'),
#  Timestamp('1993-09-16 00:00:00'),
#  Timestamp('2013-09-29 00:00:00'),
#  Timestamp('2066-12-27 00:00:00'),
#  Timestamp('1996-12-01 00:00:00'),
#  Timestamp('2015-01-01 00:00:00'),
#  Timestamp('2003-12-13 00:00:00'),
#  Timestamp('1983-01-01 00:00:00'),
#  Timestamp('2007-02-03 00:00:00'),
#  Timestamp('2001-04-08 00:00:00'),
#  Timestamp('2016-02-10 00:00:00'),
#  Timestamp('1995-06-17 00:00:00'),
#  Timestamp('1983-08-13 00:00:00'),
#  Timestamp('1992-06-28 00:00:00'),
#  Timestamp('2037-10-27 00:00:00'),
#  Timestamp('1880-05-02 00:00:00'),
#  Timestamp('1877-12-15 00:00:00'),
#  Timestamp('2006-08-29 00:00:00'),
#  Timestamp('2014-10-02 00:00:00'),
#  Timestamp('2063-06-01 00:00:00'),
#  Timestamp('2007-09-16 00:00:00'),
#  Timestamp('1997-12-25 00:00:00'),
#  Timestamp('2061-01-03 00:00:00'),
#  Timestamp('2000-06-09 00:00:00'),
#  Timestamp('2002-07-10 00:00:00'),
#  Timestamp('2015-06-14 00:00:00'),
#  Timestamp('1982-06-26 00:00:00'),
#  Timestamp('2064-02-05 00:00:00'),
#  Timestamp('2011-07-13 00:00:00'),
#  Timestamp('2008-09-28 00:00:00'),
#  Timestamp('2007-08-28 00:00:00'),
#  Timestamp('1976-03-12 00:00:00'),
#  Timestamp('2010-10-23 00:00:00'),
#  Timestamp('2014-08-02 00:00:00'),
#  Timestamp('2016-07-28 00:00:00'),
#  Timestamp('2002-05-21 00:00:00'),
#  Timestamp('2006-07-09 00:00:00'),
#  Timestamp('2012-10-18 00:00:00'),
#  Timestamp('1975-01-01 00:00:00'),
#  Timestamp('2035-07-27 00:00:00'),
#  Timestamp('1972-06-26 00:00:00'),
#  Timestamp('1981-09-03 00:00:00'),
#  Timestamp('2009-05-16 00:00:00'),
#  Timestamp('2063-11-30 00:00:00'),
#  Timestamp('2009-07-11 00:00:00'),
#  Timestamp('1998-08-01 00:00:00'),
#  Timestamp('2008-11-09 00:00:00'),
#  Timestamp('1979-05-01 00:00:00'),
#  Timestamp('1887-02-08 00:00:00'),
#  Timestamp('1907-10-16 00:00:00'),
#  Timestamp('2011-07-07 00:00:00'),
#  Timestamp('2062-06-10 00:00:00'),
#  Timestamp('2016-01-24 00:00:00'),
#  Timestamp('2009-03-19 00:00:00'),
#  Timestamp('2006-12-06 00:00:00'),
#  Timestamp('2050-04-09 00:00:00'),
#  Timestamp('1874-06-15 00:00:00'),
#  Timestamp('1995-08-31 00:00:00'),
#  Timestamp('2049-12-01 00:00:00'),
#  Timestamp('2004-11-11 00:00:00'),
#  Timestamp('2012-03-06 00:00:00'),
#  Timestamp('2011-09-04 00:00:00'),
#  Timestamp('2055-08-30 00:00:00'),
#  Timestamp('2015-07-04 00:00:00'),
#  Timestamp('1985-09-08 00:00:00'),
#  Timestamp('2005-03-25 00:00:00'),
#  Timestamp('2016-07-06 00:00:00'),
#  Timestamp('1995-09-30 00:00:00'),
#  Timestamp('2011-09-24 00:00:00'),
#  Timestamp('2011-01-01 00:00:00'),
#  Timestamp('2012-07-30 00:00:00'),
#  Timestamp('2004-05-23 00:00:00'),
#  Timestamp('2004-03-27 00:00:00'),
#  Timestamp('2065-10-16 00:00:00'),
#  Timestamp('2010-07-17 00:00:00'),
#  Timestamp('2016-06-21 00:00:00'),
#  Timestamp('2001-09-07 00:00:00'),
#  Timestamp('2016-06-23 00:00:00'),
#  Timestamp('2008-08-24 00:00:00'),
#  Timestamp('2008-04-08 00:00:00'),
#  Timestamp('2011-09-11 00:00:00'),
#  Timestamp('2064-03-28 00:00:00'),
#  Timestamp('2013-04-02 00:00:00'),
#  Timestamp('1983-08-20 00:00:00'),
#  Timestamp('2008-09-06 00:00:00'),
#  Timestamp('2002-09-21 00:00:00'),
#  Timestamp('1973-12-18 00:00:00'),
#  Timestamp('2023-01-27 00:00:00'),
#  Timestamp('1989-01-26 00:00:00'),
#  Timestamp('1999-11-01 00:00:00'),
#  Timestamp('1993-06-01 00:00:00'),
#  Timestamp('1913-08-27 00:00:00'),
#  Timestamp('2000-09-16 00:00:00'),
#  Timestamp('1909-01-01 00:00:00'),
#  Timestamp('2004-07-28 00:00:00'),
#  Timestamp('1886-01-01 00:00:00'),
#  Timestamp('2004-04-13 00:00:00'),
#  Timestamp('2003-11-12 00:00:00'),
#  Timestamp('2013-06-06 00:00:00'),
#  Timestamp('2006-07-31 00:00:00'),
#  Timestamp('1982-07-01 00:00:00'),
#  Timestamp('2000-10-06 00:00:00'),
#  Timestamp('2009-01-10 00:00:00'),
#  Timestamp('2046-07-18 00:00:00'),
#  Timestamp('1993-08-01 00:00:00'),
#  Timestamp('1991-11-26 00:00:00'),
#  Timestamp('2054-01-22 00:00:00'),
#  Timestamp('1974-02-13 00:00:00'),
#  Timestamp('1981-12-13 00:00:00'),
#  Timestamp('2007-01-25 00:00:00'),
#  Timestamp('1978-06-21 00:00:00'),
#  Timestamp('2012-07-23 00:00:00'),
#  Timestamp('2007-07-18 00:00:00'),
#  Timestamp('2008-04-26 00:00:00'),
#  Timestamp('2008-04-28 00:00:00'),
#  Timestamp('1974-09-01 00:00:00'),
#  Timestamp('2002-03-25 00:00:00'),
#  Timestamp('2011-05-13 00:00:00'),
#  Timestamp('2033-08-28 00:00:00'),
#  Timestamp('2010-01-22 00:00:00'),
#  Timestamp('2055-09-23 00:00:00'),
#  Timestamp('2010-10-28 00:00:00'),
#  Timestamp('1984-09-22 00:00:00'),
#  Timestamp('2001-09-03 00:00:00'),
#  Timestamp('2005-07-15 00:00:00'),
#  Timestamp('1910-01-01 00:00:00'),
#  Timestamp('2007-09-27 00:00:00'),
#  Timestamp('1874-07-15 00:00:00'),
#  Timestamp('2005-09-02 00:00:00'),
#  Timestamp('2006-07-08 00:00:00'),
#  Timestamp('1983-11-10 00:00:00'),
#  Timestamp('2014-07-05 00:00:00'),
#  Timestamp('2016-06-02 00:00:00'),
#  Timestamp('1906-09-27 00:00:00'),
#  Timestamp('1975-06-23 00:00:00'),
#  Timestamp('2066-08-23 00:00:00'),
#  Timestamp('2011-12-07 00:00:00'),
#  Timestamp('2065-04-04 00:00:00'),
#  Timestamp('2060-12-27 00:00:00'),
#  Timestamp('2059-07-25 00:00:00'),
#  Timestamp('2010-08-07 00:00:00'),
#  Timestamp('1988-08-22 00:00:00'),
#  Timestamp('2009-11-16 00:00:00'),
#  Timestamp('2054-10-02 00:00:00'),
#  Timestamp('2053-04-01 00:00:00'),
#  Timestamp('2003-09-13 00:00:00'),
#  Timestamp('1878-09-02 00:00:00'),
#  Timestamp('2059-07-23 00:00:00'),
#  Timestamp('1997-12-28 00:00:00'),
#  Timestamp('1983-04-02 00:00:00'),
#  Timestamp('2032-08-30 00:00:00'),
#  Timestamp('1897-01-01 00:00:00'),
#  Timestamp('1990-10-30 00:00:00'),
#  Timestamp('1827-06-01 00:00:00'),
#  Timestamp('2061-02-17 00:00:00'),
#  Timestamp('2003-07-05 00:00:00'),
#  Timestamp('2048-09-19 00:00:00'),
#  Timestamp('1980-01-01 00:00:00'),
#  Timestamp('2013-05-23 00:00:00'),
#  Timestamp('2016-08-29 00:00:00'),
#  Timestamp('2015-08-22 00:00:00'),
#  Timestamp('2006-07-17 00:00:00'),
#  Timestamp('2007-05-07 00:00:00'),
#  Timestamp('2042-09-12 00:00:00'),
#  Timestamp('2010-07-02 00:00:00'),
#  Timestamp('1931-01-01 00:00:00'),
#  Timestamp('1988-04-14 00:00:00'),
#  Timestamp('2061-10-01 00:00:00'),
#  Timestamp('2066-05-16 00:00:00'),
#  Timestamp('2005-05-02 00:00:00'),
#  Timestamp('2010-08-02 00:00:00'),
#  Timestamp('2003-04-23 00:00:00'),
#  Timestamp('2011-12-21 00:00:00'),
#  Timestamp('2060-04-03 00:00:00'),
#  Timestamp('2005-08-24 00:00:00'),
#  Timestamp('1984-06-03 00:00:00'),
#  Timestamp('1985-07-25 00:00:00'),
#  Timestamp('2011-06-19 00:00:00'),
#  Timestamp('2065-06-01 00:00:00'),
#  Timestamp('2016-09-05 00:00:00'),
#  Timestamp('1999-08-05 00:00:00'),
#  Timestamp('1978-04-02 00:00:00'),
#  Timestamp('1989-01-01 00:00:00'),
#  Timestamp('1995-11-25 00:00:00'),
#  Timestamp('2012-09-06 00:00:00'),
#  Timestamp('1907-08-12 00:00:00'),
#  Timestamp('1995-09-03 00:00:00'),
#  Timestamp('2016-07-16 00:00:00'),
#  Timestamp('2014-04-04 00:00:00'),
#  Timestamp('2054-08-12 00:00:00'),
#  Timestamp('2014-03-22 00:00:00'),
#  Timestamp('2011-08-28 00:00:00'),
#  Timestamp('2064-12-10 00:00:00'),
#  Timestamp('2004-10-30 00:00:00'),
#  Timestamp('2059-08-14 00:00:00'),
#  Timestamp('2051-08-17 00:00:00'),
#  Timestamp('1998-01-25 00:00:00'),
#  Timestamp('2015-01-19 00:00:00'),
#  Timestamp('2069-08-02 00:00:00'),
#  Timestamp('1996-10-28 00:00:00'),
#  Timestamp('2021-11-27 00:00:00'),
#  Timestamp('1992-01-01 00:00:00'),
#  Timestamp('2035-06-01 00:00:00'),
#  Timestamp('2012-07-31 00:00:00'),
#  Timestamp('2010-07-16 00:00:00'),
#  Timestamp('2016-05-29 00:00:00'),
#  Timestamp('2056-08-15 00:00:00'),
#  Timestamp('2015-06-30 00:00:00'),
#  Timestamp('2015-10-05 00:00:00'),
#  Timestamp('1994-12-09 00:00:00'),
#  Timestamp('2008-06-01 00:00:00'),
#  Timestamp('2016-09-18 00:00:00'),
#  Timestamp('2013-03-16 00:00:00'),
#  Timestamp('2061-07-01 00:00:00'),
#  Timestamp('2048-12-14 00:00:00'),
#  Timestamp('2004-01-23 00:00:00'),
#  Timestamp('1999-03-14 00:00:00'),
#  Timestamp('2014-09-09 00:00:00'),
#  Timestamp('2014-08-29 00:00:00'),
#  Timestamp('2006-01-28 00:00:00'),
#  Timestamp('1984-09-30 00:00:00'),
#  Timestamp('2066-07-17 00:00:00'),
#  Timestamp('2063-12-20 00:00:00'),
#  Timestamp('2000-09-15 00:00:00'),
#  Timestamp('1979-03-01 00:00:00'),
#  Timestamp('2002-09-16 00:00:00'),
#  Timestamp('2016-12-08 00:00:00'),
#  Timestamp('2058-10-01 00:00:00'),
#  Timestamp('2015-12-21 00:00:00'),
#  Timestamp('1979-04-08 00:00:00'),
#  Timestamp('2010-12-01 00:00:00'),
#  Timestamp('1899-10-12 00:00:00'),
#  Timestamp('2044-03-26 00:00:00'),
#  Timestamp('2005-07-17 00:00:00'),
#  Timestamp('1885-11-26 00:00:00'),
#  Timestamp('2006-09-02 00:00:00'),
#  Timestamp('1907-01-01 00:00:00'),
#  Timestamp('2012-09-08 00:00:00'),
#  Timestamp('1982-09-30 00:00:00'),
#  Timestamp('1972-04-01 00:00:00'),
#  Timestamp('1995-08-01 00:00:00'),
#  Timestamp('1896-01-01 00:00:00'),
#  Timestamp('2006-04-09 00:00:00'),
#  Timestamp('1970-04-01 00:00:00'),
#  Timestamp('2013-11-07 00:00:00'),
#  Timestamp('2015-10-09 00:00:00'),
#  Timestamp('2003-04-21 00:00:00'),
#  Timestamp('1994-03-23 00:00:00'),
#  Timestamp('1981-08-24 00:00:00'),
#  Timestamp('2000-07-16 00:00:00'),
#  Timestamp('1996-07-04 00:00:00'),
#  Timestamp('2008-07-30 00:00:00'),
#  Timestamp('1984-07-24 00:00:00'),
#  Timestamp('2009-04-06 00:00:00'),
#  Timestamp('1974-02-01 00:00:00'),
#  Timestamp('2005-11-02 00:00:00'),
#  Timestamp('2008-07-26 00:00:00'),
#  Timestamp('2064-07-01 00:00:00'),
#  Timestamp('1982-02-07 00:00:00'),
#  Timestamp('2004-01-01 00:00:00'),
#  Timestamp('2003-02-15 00:00:00'),
#  Timestamp('1988-09-13 00:00:00'),
#  Timestamp('2001-07-06 00:00:00'),
#  Timestamp('1974-09-02 00:00:00'),
#  Timestamp('2011-09-28 00:00:00'),
#  Timestamp('2032-04-16 00:00:00'),
#  Timestamp('2016-07-23 00:00:00'),
#  Timestamp('1997-11-05 00:00:00'),
#  Timestamp('2013-10-26 00:00:00'),
#  Timestamp('1999-01-03 00:00:00'),
#  Timestamp('2002-05-31 00:00:00'),
#  Timestamp('2011-05-21 00:00:00'),
#  Timestamp('2051-11-28 00:00:00'),
#  Timestamp('1996-09-06 00:00:00'),
#  Timestamp('2013-05-08 00:00:00'),
#  Timestamp('2007-03-31 00:00:00'),
#  Timestamp('1934-01-01 00:00:00'),
#  Timestamp('2026-10-23 00:00:00'),
#  Timestamp('2006-02-01 00:00:00'),
#  Timestamp('2014-06-18 00:00:00'),
#  Timestamp('2002-06-20 00:00:00'),
#  Timestamp('2059-04-09 00:00:00'),
#  Timestamp('1997-10-28 00:00:00'),
#  Timestamp('2014-10-03 00:00:00'),
#  Timestamp('1898-09-19 00:00:00'),
#  Timestamp('2001-07-15 00:00:00'),
#  Timestamp('1982-07-24 00:00:00'),
#  Timestamp('2009-03-17 00:00:00'),
#  Timestamp('1996-09-01 00:00:00'),
#  Timestamp('2007-07-17 00:00:00'),
#  Timestamp('2067-09-07 00:00:00'),
#  Timestamp('2004-01-03 00:00:00'),
#  Timestamp('2013-09-07 00:00:00'),
#  Timestamp('1917-01-01 00:00:00'),
#  Timestamp('2066-12-26 00:00:00'),
#  Timestamp('2060-08-04 00:00:00'),
#  Timestamp('2010-11-27 00:00:00'),
#  Timestamp('2013-07-19 00:00:00'),
#  Timestamp('2005-07-22 00:00:00'),
#  Timestamp('1988-03-14 00:00:00'),
#  Timestamp('2000-12-27 00:00:00'),
#  Timestamp('2067-07-29 00:00:00'),
#  Timestamp('1993-11-28 00:00:00'),
#  Timestamp('1989-02-15 00:00:00'),
#  Timestamp('2027-10-12 00:00:00'),
#  Timestamp('2014-06-17 00:00:00'),
#  Timestamp('2067-03-12 00:00:00'),
#  Timestamp('1993-03-14 00:00:00'),
#  Timestamp('2007-10-12 00:00:00'),
#  Timestamp('2014-07-09 00:00:00'),
#  Timestamp('1988-08-19 00:00:00'),
#  Timestamp('2007-08-11 00:00:00'),
#  Timestamp('1980-08-22 00:00:00'),
#  Timestamp('1997-07-02 00:00:00'),
#  Timestamp('2000-12-05 00:00:00'),
#  Timestamp('2059-08-20 00:00:00'),
#  Timestamp('2066-09-19 00:00:00'),
#  Timestamp('2061-01-25 00:00:00'),
#  Timestamp('2007-11-03 00:00:00'),
#  Timestamp('2046-04-01 00:00:00'),
#  Timestamp('2012-03-05 00:00:00'),
#  Timestamp('2062-06-21 00:00:00'),
#  Timestamp('2044-01-14 00:00:00'),
#  Timestamp('1882-12-03 00:00:00'),
#  Timestamp('2013-07-14 00:00:00'),
#  Timestamp('1995-01-24 00:00:00'),
#  Timestamp('2011-03-16 00:00:00'),
#  Timestamp('2062-09-30 00:00:00'),
#  Timestamp('1998-06-28 00:00:00'),
#  Timestamp('2036-08-01 00:00:00'),
#  Timestamp('1989-03-09 00:00:00'),
#  Timestamp('2062-02-05 00:00:00'),
#  Timestamp('2000-10-09 00:00:00'),
#  Timestamp('1947-02-06 00:00:00'),
#  Timestamp('2009-09-26 00:00:00'),
#  Timestamp('2007-10-29 00:00:00'),
#  Timestamp('1996-01-14 00:00:00'),
#  Timestamp('1988-06-01 00:00:00'),
#  Timestamp('2013-06-27 00:00:00'),
#  Timestamp('1974-04-14 00:00:00'),
#  Timestamp('2009-08-10 00:00:00'),
#  Timestamp('2012-05-06 00:00:00'),
#  Timestamp('2060-02-24 00:00:00'),
#  Timestamp('2065-01-10 00:00:00'),
#  Timestamp('1985-10-05 00:00:00'),
#  Timestamp('2006-11-25 00:00:00'),
#  Timestamp('1973-09-10 00:00:00'),
#  Timestamp('1976-10-18 00:00:00'),
#  Timestamp('1897-10-15 00:00:00'),
#  Timestamp('2063-01-22 00:00:00'),
#  Timestamp('1974-07-02 00:00:00'),
#  Timestamp('2043-03-21 00:00:00'),
#  Timestamp('2057-08-01 00:00:00'),
#  Timestamp('2045-09-19 00:00:00'),
#  Timestamp('2014-09-06 00:00:00'),
#  Timestamp('1877-03-16 00:00:00'),
#  Timestamp('2055-07-07 00:00:00'),
#  Timestamp('2011-02-04 00:00:00'),
#  Timestamp('1998-12-20 00:00:00'),
#  Timestamp('1926-10-29 00:00:00'),
#  Timestamp('1987-07-21 00:00:00'),
#  Timestamp('2029-01-14 00:00:00'),
#  Timestamp('1898-04-13 00:00:00'),
#  Timestamp('1976-03-09 00:00:00'),
#  Timestamp('2016-04-23 00:00:00'),
#  Timestamp('1975-03-01 00:00:00'),
#  Timestamp('2012-11-19 00:00:00'),
#  Timestamp('1885-04-16 00:00:00'),
#  Timestamp('2010-08-08 00:00:00'),
#  Timestamp('2016-09-11 00:00:00'),
#  Timestamp('2062-02-23 00:00:00'),
#  Timestamp('2001-06-03 00:00:00'),
#  Timestamp('2008-10-06 00:00:00'),
#  Timestamp('2066-09-18 00:00:00'),
#  Timestamp('2053-07-01 00:00:00'),
#  Timestamp('2015-07-22 00:00:00'),
#  Timestamp('2009-05-31 00:00:00'),
#  Timestamp('2009-11-05 00:00:00'),
#  Timestamp('2016-06-24 00:00:00'),
#  Timestamp('2013-08-05 00:00:00'),
#  Timestamp('2008-09-14 00:00:00'),
#  Timestamp('2001-04-02 00:00:00'),
#  Timestamp('1886-05-06 00:00:00'),
#  Timestamp('2001-08-21 00:00:00'),
#  Timestamp('1980-06-26 00:00:00'),
#  Timestamp('1975-12-02 00:00:00'),
#  Timestamp('1981-02-01 00:00:00'),
#  Timestamp('1999-11-23 00:00:00'),
#  Timestamp('2068-08-11 00:00:00'),
#  Timestamp('2050-07-09 00:00:00'),
#  Timestamp('2006-09-29 00:00:00'),
#  Timestamp('1901-06-29 00:00:00'),
#  Timestamp('2010-10-09 00:00:00'),
#  Timestamp('2003-08-12 00:00:00'),
#  Timestamp('1978-10-21 00:00:00'),
#  Timestamp('2067-12-18 00:00:00'),
#  Timestamp('2016-02-04 00:00:00'),
#  Timestamp('1970-10-24 00:00:00'),
#  Timestamp('2066-10-19 00:00:00'),
#  Timestamp('2008-02-07 00:00:00'),
#  Timestamp('2004-09-04 00:00:00'),
#  Timestamp('2064-06-23 00:00:00'),
#  Timestamp('2068-04-15 00:00:00'),
#  Timestamp('2045-06-15 00:00:00'),
#  Timestamp('2037-11-11 00:00:00'),
#  Timestamp('1870-01-09 00:00:00'),
#  Timestamp('1929-08-29 00:00:00'),
#  Timestamp('1927-01-08 00:00:00'),
#  Timestamp('1974-04-12 00:00:00'),
#  Timestamp('1992-10-29 00:00:00'),
#  Timestamp('1999-09-05 00:00:00'),
#  Timestamp('2007-05-24 00:00:00'),
#  Timestamp('2060-01-30 00:00:00'),
#  Timestamp('2000-07-25 00:00:00'),
#  Timestamp('2000-07-17 00:00:00'),
#  Timestamp('2061-04-08 00:00:00'),
#  Timestamp('2056-09-13 00:00:00'),
#  Timestamp('1990-04-08 00:00:00'),
#  Timestamp('2006-07-12 00:00:00'),
#  Timestamp('1995-04-13 00:00:00'),
#  Timestamp('1986-11-04 00:00:00'),
#  Timestamp('1984-09-23 00:00:00'),
#  Timestamp('1924-10-31 00:00:00'),
#  Timestamp('1999-11-06 00:00:00'),
#  Timestamp('2013-10-06 00:00:00'),
#  Timestamp('2009-10-09 00:00:00'),
#  Timestamp('2015-02-14 00:00:00'),
#  Timestamp('1898-07-01 00:00:00'),
#  Timestamp('1898-12-28 00:00:00'),
#  Timestamp('1995-08-15 00:00:00'),
#  Timestamp('1993-08-14 00:00:00'),
#  Timestamp('1974-12-12 00:00:00'),
#  Timestamp('2066-12-31 00:00:00'),
#  Timestamp('2049-05-16 00:00:00'),
#  Timestamp('1995-07-01 00:00:00'),
#  Timestamp('2034-02-22 00:00:00'),
#  Timestamp('2059-11-29 00:00:00'),
#  Timestamp('1976-08-24 00:00:00'),
#  Timestamp('1878-11-17 00:00:00'),
#  Timestamp('1995-01-02 00:00:00'),
#  Timestamp('2002-05-07 00:00:00'),
#  Timestamp('2048-12-26 00:00:00'),
#  Timestamp('1975-03-18 00:00:00'),
#  Timestamp('1971-10-14 00:00:00'),
#  Timestamp('1951-05-09 00:00:00'),
#  Timestamp('2059-03-08 00:00:00'),
#  Timestamp('1991-09-08 00:00:00'),
#  Timestamp('2002-08-11 00:00:00'),
#  Timestamp('1865-07-18 00:00:00'),
#  Timestamp('2029-12-13 00:00:00'),
#  Timestamp('2032-02-16 00:00:00'),
#  Timestamp('1996-04-07 00:00:00'),
#  Timestamp('1999-09-10 00:00:00'),
#  Timestamp('2005-08-21 00:00:00'),
#  Timestamp('2003-05-10 00:00:00'),
#  Timestamp('2004-04-04 00:00:00'),
#  Timestamp('2002-03-19 00:00:00'),
#  Timestamp('1997-08-24 00:00:00'),
#  Timestamp('1880-08-08 00:00:00'),
#  Timestamp('2058-12-13 00:00:00'),
#  Timestamp('1977-02-04 00:00:00'),
#  Timestamp('2015-09-04 00:00:00'),
#  Timestamp('1970-03-31 00:00:00'),
#  Timestamp('2068-08-24 00:00:00'),
#  Timestamp('2043-11-21 00:00:00'),
#  Timestamp('1904-07-01 00:00:00'),
#  Timestamp('2062-11-25 00:00:00'),
#  Timestamp('1970-12-07 00:00:00'),
#  Timestamp('2011-07-25 00:00:00'),
#  Timestamp('2009-04-12 00:00:00'),
#  Timestamp('2041-12-07 00:00:00'),
#  Timestamp('2060-02-29 00:00:00'),
#  Timestamp('1980-01-25 00:00:00'),
#  Timestamp('2066-07-31 00:00:00'),
#  Timestamp('2011-05-07 00:00:00'),
#  Timestamp('2013-08-18 00:00:00'),
#  Timestamp('1889-11-22 00:00:00'),
#  Timestamp('1979-02-21 00:00:00'),
#  Timestamp('2068-12-25 00:00:00'),
#  Timestamp('2067-01-27 00:00:00'),
#  Timestamp('1966-08-01 00:00:00'),
#  Timestamp('1972-04-16 00:00:00'),
#  Timestamp('1990-05-13 00:00:00'),
#  Timestamp('1985-10-18 00:00:00'),
#  Timestamp('1981-03-25 00:00:00'),
#  Timestamp('1977-12-31 00:00:00'),
#  Timestamp('1995-12-18 00:00:00'),
#  Timestamp('1895-05-21 00:00:00'),
#  Timestamp('2022-07-19 00:00:00'),
#  Timestamp('2057-11-08 00:00:00'),
#  Timestamp('1989-06-01 00:00:00'),
#  Timestamp('2014-07-22 00:00:00'),
#  Timestamp('2011-02-17 00:00:00'),
#  Timestamp('2006-07-25 00:00:00'),
#  Timestamp('2063-11-12 00:00:00'),
#  Timestamp('1992-11-11 00:00:00'),
#  Timestamp('2050-03-01 00:00:00'),
#  Timestamp('1981-06-12 00:00:00'),
#  Timestamp('2059-08-30 00:00:00'),
#  Timestamp('1905-11-17 00:00:00'),
#  Timestamp('2065-06-09 00:00:00'),
#  Timestamp('1983-06-29 00:00:00'),
#  Timestamp('2053-02-15 00:00:00'),
#  Timestamp('2050-08-06 00:00:00'),
#  Timestamp('2005-02-22 00:00:00'),
#  Timestamp('2059-12-26 00:00:00'),
#  Timestamp('1999-06-09 00:00:00'),
#  Timestamp('2061-04-21 00:00:00'),
#  Timestamp('2062-12-09 00:00:00'),
#  Timestamp('2048-08-03 00:00:00'),
#  Timestamp('2062-07-19 00:00:00'),
#  Timestamp('1914-09-26 00:00:00'),
#  Timestamp('2008-05-23 00:00:00'),
#  Timestamp('2010-09-04 00:00:00'),
#  Timestamp('2035-01-17 00:00:00'),
#  Timestamp('1868-01-17 00:00:00'),
#  Timestamp('2027-01-20 00:00:00'),
#  Timestamp('1892-04-21 00:00:00'),
#  Timestamp('2062-02-15 00:00:00'),
#  Timestamp('2011-01-26 00:00:00'),
#  Timestamp('2041-11-25 00:00:00'),
#  Timestamp('1995-02-01 00:00:00'),
#  Timestamp('1991-08-30 00:00:00'),
#  Timestamp('1997-08-10 00:00:00'),
#  Timestamp('2013-08-14 00:00:00'),
#  Timestamp('2012-06-20 00:00:00'),
#  Timestamp('1755-01-01 00:00:00'),
#  Timestamp('2008-07-27 00:00:00'),
#  Timestamp('2016-07-24 00:00:00'),
#  Timestamp('2068-02-26 00:00:00'),
#  Timestamp('2012-12-02 00:00:00'),
#  Timestamp('1986-12-01 00:00:00'),
#  Timestamp('1991-06-26 00:00:00'),
#  Timestamp('2012-05-23 00:00:00'),
#  Timestamp('1983-01-08 00:00:00'),
#  Timestamp('2038-01-14 00:00:00'),
#  Timestamp('2000-08-13 00:00:00'),
#  Timestamp('2060-11-27 00:00:00'),
#  Timestamp('2020-11-29 00:00:00'),
#  Timestamp('2012-01-13 00:00:00'),
#  Timestamp('2015-03-16 00:00:00'),
#  Timestamp('2001-07-03 00:00:00'),
#  Timestamp('1898-07-14 00:00:00'),
#  Timestamp('2016-08-07 00:00:00'),
#  Timestamp('1895-02-23 00:00:00'),
#  Timestamp('2007-01-23 00:00:00'),
#  Timestamp('2042-01-01 00:00:00'),
#  Timestamp('1978-09-02 00:00:00'),
#  Timestamp('1971-10-27 00:00:00'),
#  Timestamp('2010-06-27 00:00:00'),
#  Timestamp('1982-02-17 00:00:00'),
#  Timestamp('1978-09-16 00:00:00'),
#  Timestamp('2053-02-18 00:00:00'),
#  Timestamp('2022-09-28 00:00:00'),
#  Timestamp('2012-06-19 00:00:00'),
#  Timestamp('1895-12-09 00:00:00'),
#  Timestamp('2005-06-25 00:00:00'),
#  Timestamp('2037-03-26 00:00:00'),
#  Timestamp('1953-09-03 00:00:00'),
#  Timestamp('1962-08-31 00:00:00'),
#  Timestamp('2063-02-08 00:00:00'),
#  Timestamp('2016-09-06 00:00:00'),
#  Timestamp('2013-04-04 00:00:00'),
#  Timestamp('2008-09-09 00:00:00'),
#  Timestamp('2006-05-27 00:00:00'),
#  Timestamp('2006-03-28 00:00:00'),
#  Timestamp('2000-09-12 00:00:00'),
#  Timestamp('2028-01-02 00:00:00'),
#  Timestamp('2057-12-31 00:00:00'),
#  Timestamp('1986-12-31 00:00:00'),
#  Timestamp('2030-01-22 00:00:00'),
#  Timestamp('1977-11-12 00:00:00'),
#  Timestamp('2036-04-22 00:00:00'),
#  Timestamp('2035-03-02 00:00:00'),
#  Timestamp('2068-08-21 00:00:00'),
#  Timestamp('1827-01-01 00:00:00'),
#  Timestamp('2024-11-21 00:00:00'),
#  Timestamp('2036-12-15 00:00:00'),
#  Timestamp('2015-10-04 00:00:00'),
#  Timestamp('2010-10-20 00:00:00'),
#  Timestamp('2025-09-03 00:00:00'),
#  Timestamp('1985-08-22 00:00:00'),
#  Timestamp('1956-12-15 00:00:00'),
#  Timestamp('1986-07-26 00:00:00'),
#  Timestamp('2015-02-09 00:00:00'),
#  Timestamp('2019-01-15 00:00:00'),
#  Timestamp('2033-11-18 00:00:00'),
#  Timestamp('1878-10-24 00:00:00'),
#  Timestamp('2004-10-31 00:00:00'),
#  Timestamp('2053-07-04 00:00:00'),
#  Timestamp('2002-07-20 00:00:00'),
#  Timestamp('2044-02-27 00:00:00'),
#  Timestamp('2051-01-03 00:00:00'),
#  Timestamp('1995-09-13 00:00:00'),
#  Timestamp('2041-08-01 00:00:00'),
#  Timestamp('2001-08-16 00:00:00'),
#  Timestamp('1994-11-06 00:00:00'),
#  Timestamp('2062-06-04 00:00:00'),
#  Timestamp('2061-02-12 00:00:00'),
#  Timestamp('2000-07-22 00:00:00'),
#  Timestamp('2068-02-18 00:00:00'),
#  Timestamp('1958-01-09 00:00:00'),
#  Timestamp('2015-04-29 00:00:00'),
#  Timestamp('2008-07-19 00:00:00'),
#  Timestamp('1950-01-12 00:00:00'),
#  Timestamp('2064-10-31 00:00:00'),
#  Timestamp('2007-10-07 00:00:00'),
#  Timestamp('1996-05-07 00:00:00'),
#  Timestamp('2032-08-09 00:00:00'),
#  Timestamp('1988-05-10 00:00:00'),
#  Timestamp('2049-07-07 00:00:00'),
#  Timestamp('1916-08-24 00:00:00'),
#  Timestamp('2013-10-28 00:00:00'),
#  Timestamp('1979-08-28 00:00:00'),
#  Timestamp('1963-07-10 00:00:00'),
#  Timestamp('1970-03-23 00:00:00'),
#  Timestamp('1973-08-25 00:00:00'),
#  Timestamp('2053-01-08 00:00:00'),
#  Timestamp('1876-09-07 00:00:00'),
#  Timestamp('1982-10-13 00:00:00'),
#  Timestamp('2001-07-25 00:00:00'),
#  Timestamp('1987-05-08 00:00:00'),
#  Timestamp('2054-12-04 00:00:00'),
#  Timestamp('1996-06-25 00:00:00'),
#  Timestamp('2064-01-22 00:00:00'),
#  ...]

# %%
# Check how many could not be converted.

df["Date"].isnull().sum()
# Out:
# 272

# %%
# Drop year column, as it overlaps with Date column

df = df.drop(columns="Year")

# %%
# Check type column.

df["Type"].value_counts()
# Out:
# Unprovoked      4385
# Provoked         557
# Invalid          519
# Sea Disaster     220
# Boat             200
# Boating          110
# Name: Type, dtype: int64

# %%
# Merge Boat and Boating to Boat Type Attacks. Other types seem ok

df.loc[df["Type"] == "Boating", ["Type"]] = "Boat"

# %%
## Next, look at country, area and location

list(df["Country"].value_counts().index)
# Out:
# ['USA',
#  'AUSTRALIA',
#  'SOUTH AFRICA',
#  'PAPUA NEW GUINEA',
#  'NEW ZEALAND',
#  'BRAZIL',
#  'BAHAMAS',
#  'MEXICO',
#  'ITALY',
#  'FIJI',
#  'PHILIPPINES',
#  'REUNION',
#  'NEW CALEDONIA',
#  'MOZAMBIQUE',
#  'CUBA',
#  'SPAIN',
#  'INDIA',
#  'EGYPT',
#  'CROATIA',
#  'JAPAN',
#  'PANAMA',
#  'SOLOMON ISLANDS',
#  'IRAN',
#  'GREECE',
#  'HONG KONG',
#  'JAMAICA',
#  'FRENCH POLYNESIA',
#  'INDONESIA',
#  'ENGLAND',
#  'PACIFIC OCEAN',
#  'ATLANTIC OCEAN',
#  'BERMUDA',
#  'TONGA',
#  'VANUATU',
#  'VIETNAM',
#  'MARSHALL ISLANDS',
#  'SRI LANKA',
#  'FRANCE',
#  'TURKEY',
#  'IRAQ',
#  'SOUTH ATLANTIC OCEAN',
#  'COSTA RICA',
#  'SENEGAL',
#  'VENEZUELA',
#  'CANADA',
#  'UNITED KINGDOM',
#  'NEW GUINEA',
#  'KENYA',
#  'COLUMBIA',
#  'TAIWAN',
#  'SOUTH KOREA',
#  'SCOTLAND',
#  'ECUADOR',
#  'SIERRA LEONE',
#  'TANZANIA',
#  'CARIBBEAN SEA',
#  'CHILE',
#  'DOMINICAN REPUBLIC',
#  'NORTH PACIFIC OCEAN',
#  'YEMEN ',
#  'ISRAEL',
#  'INDIAN OCEAN',
#  'SAMOA',
#  'MAURITIUS',
#  'MADAGASCAR',
#  'SEYCHELLES',
#  'NICARAGUA',
#  'KIRIBATI',
#  'SOMALIA',
#  'SINGAPORE',
#  'CHINA',
#  'THAILAND',
#  'NEW BRITAIN',
#  'OKINAWA',
#  'AZORES',
#  'PALAU',
#  'MID ATLANTIC OCEAN',
#  'TURKS & CAICOS',
#  'SAUDI ARABIA',
#  'BARBADOS',
#  'MALTA',
#  'LIBYA',
#  'GRENADA',
#  'NIGERIA',
#  'RUSSIA',
#  'GUAM',
#  'SUDAN',
#  'PERSIAN GULF',
#  'BURMA',
#  'EL SALVADOR',
#  'NORTH ATLANTIC OCEAN',
#  'MALAYSIA',
#  'URUGUAY',
#  'BELIZE',
#  'GUINEA',
#  'AMERICAN SAMOA',
#  ' TONGA',
#  'CAPE VERDE',
#  'MICRONESIA',
#  'LIBERIA',
#  'MONTENEGRO',
#  'Fiji',
#  'LEBANON',
#  'TUNISIA',
#  'HONDURAS',
#  'HAITI',
#  'PORTUGAL',
#  'TRINIDAD & TOBAGO',
#  'CAYMAN ISLANDS',
#  'MEDITERRANEAN SEA',
#  'PACIFIC OCEAN ',
#  'SOUTHWEST PACIFIC OCEAN',
#  'NORWAY',
#  'UNITED ARAB EMIRATES (UAE)',
#  'CENTRAL PACIFIC',
#  'NAMIBIA',
#  'YEMEN',
#  'SOUTH PACIFIC OCEAN',
#  'JOHNSTON ISLAND',
#  'EGYPT ',
#  'CRETE',
#  'COOK ISLANDS',
#  ' PHILIPPINES',
#  'St Helena',
#  'Seychelles',
#  'GUYANA',
#  'MAYOTTE',
#  'ADMIRALTY ISLANDS',
#  'NORTHERN ARABIAN SEA',
#  'GULF OF ADEN',
#  'EQUATORIAL GUINEA / CAMEROON',
#  'BRITISH NEW GUINEA',
#  'ANTIGUA',
#  'MEDITERRANEAN SEA?',
#  'RED SEA / INDIAN OCEAN',
#  'Coast of AFRICA',
#  'SOLOMON ISLANDS / VANUATU',
#  'RED SEA',
#  'JAVA',
#  'NEVIS',
#  'IRELAND',
#  'BRITISH ISLES',
#  'ST. MAARTIN',
#  'SLOVENIA',
#  'THE BALKANS',
#  'NORTH SEA',
#  'KUWAIT',
#  'GRAND CAYMAN',
#  'IRAN / IRAQ',
#  'BANGLADESH',
#  'TUVALU',
#  'ARGENTINA',
#  'FALKLAND ISLANDS',
#  'RED SEA?',
#  'SWEDEN',
#  'CURACAO',
#  'MEXICO ',
#  'NETHERLANDS ANTILLES',
#  'MALDIVE ISLANDS',
#  'DJIBOUTI',
#  'ALGERIA',
#  'GEORGIA',
#  'SUDAN?',
#  'MID-PACIFC OCEAN',
#  'ASIA?',
#  'Between PORTUGAL & INDIA',
#  'TASMAN SEA',
#  'INDIAN OCEAN?',
#  'BRITISH VIRGIN ISLANDS',
#  'PARAGUAY',
#  'SYRIA',
#  'MARTINIQUE',
#  'NICARAGUA ',
#  'BAHREIN',
#  'NORTHERN MARIANA ISLANDS',
#  'SAN DOMINGO',
#  'PUERTO RICO',
#  'GREENLAND',
#  'WESTERN SAMOA',
#  'NORTH ATLANTIC OCEAN ',
#  'ANDAMAN / NICOBAR ISLANDAS',
#  'GHANA',
#  'ST. MARTIN',
#  'FEDERATED STATES OF MICRONESIA',
#  'KOREA',
#  'BRITISH WEST INDIES',
#  'ITALY / CROATIA',
#  'GUATEMALA',
#  'GABON',
#  'PALESTINIAN TERRITORIES',
#  'EGYPT / ISRAEL',
#  'Sierra Leone',
#  'CEYLON (SRI LANKA)',
#  'BAY OF BENGAL',
#  'CYPRUS',
#  'MONACO',
#  'SOUTH CHINA SEA',
#  'OCEAN',
#  'ICELAND',
#  'ARUBA',
#  'DIEGO GARCIA',
#  'UNITED ARAB EMIRATES',
#  'ANGOLA']

# %%
## Country: Uppercase all, remove question marks, remove whitespace at beginning and end

df['Country'] = df['Country'].str.upper() 
df['Country'] = df['Country'].str.replace("?","")
df['Country'] = df['Country'].str.lstrip().str.rstrip()

# %%
list(df["Country"].value_counts().index)
# Out:
# ['USA',
#  'AUSTRALIA',
#  'SOUTH AFRICA',
#  'PAPUA NEW GUINEA',
#  'NEW ZEALAND',
#  'BRAZIL',
#  'BAHAMAS',
#  'MEXICO',
#  'ITALY',
#  'FIJI',
#  'PHILIPPINES',
#  'REUNION',
#  'NEW CALEDONIA',
#  'MOZAMBIQUE',
#  'CUBA',
#  'SPAIN',
#  'EGYPT',
#  'INDIA',
#  'CROATIA',
#  'PANAMA',
#  'JAPAN',
#  'IRAN',
#  'SOLOMON ISLANDS',
#  'GREECE',
#  'HONG KONG',
#  'JAMAICA',
#  'FRENCH POLYNESIA',
#  'INDONESIA',
#  'PACIFIC OCEAN',
#  'ENGLAND',
#  'TONGA',
#  'ATLANTIC OCEAN',
#  'BERMUDA',
#  'VIETNAM',
#  'VANUATU',
#  'SRI LANKA',
#  'MARSHALL ISLANDS',
#  'FRANCE',
#  'COSTA RICA',
#  'IRAQ',
#  'TURKEY',
#  'SOUTH ATLANTIC OCEAN',
#  'VENEZUELA',
#  'SENEGAL',
#  'CANADA',
#  'KENYA',
#  'UNITED KINGDOM',
#  'NEW GUINEA',
#  'YEMEN',
#  'SIERRA LEONE',
#  'COLUMBIA',
#  'TAIWAN',
#  'SOUTH KOREA',
#  'ECUADOR',
#  'SCOTLAND',
#  'SEYCHELLES',
#  'TANZANIA',
#  'CARIBBEAN SEA',
#  'INDIAN OCEAN',
#  'CHILE',
#  'DOMINICAN REPUBLIC',
#  'MADAGASCAR',
#  'SAMOA',
#  'MAURITIUS',
#  'NICARAGUA',
#  'NORTH PACIFIC OCEAN',
#  'ISRAEL',
#  'THAILAND',
#  'KIRIBATI',
#  'CHINA',
#  'SOMALIA',
#  'NEW BRITAIN',
#  'OKINAWA',
#  'SINGAPORE',
#  'SUDAN',
#  'LIBYA',
#  'NORTH ATLANTIC OCEAN',
#  'PALAU',
#  'SAUDI ARABIA',
#  'TURKS & CAICOS',
#  'MID ATLANTIC OCEAN',
#  'AZORES',
#  'BARBADOS',
#  'MALTA',
#  'MALAYSIA',
#  'BURMA',
#  'NIGERIA',
#  'GRENADA',
#  'EL SALVADOR',
#  'GUAM',
#  'PERSIAN GULF',
#  'RUSSIA',
#  'URUGUAY',
#  'LIBERIA',
#  'MEDITERRANEAN SEA',
#  'MONTENEGRO',
#  'HONDURAS',
#  'AMERICAN SAMOA',
#  'TRINIDAD & TOBAGO',
#  'PORTUGAL',
#  'TUNISIA',
#  'MICRONESIA',
#  'BELIZE',
#  'HAITI',
#  'CAPE VERDE',
#  'GUINEA',
#  'LEBANON',
#  'JOHNSTON ISLAND',
#  'SOUTHWEST PACIFIC OCEAN',
#  'SOUTH PACIFIC OCEAN',
#  'CRETE',
#  'CAYMAN ISLANDS',
#  'CENTRAL PACIFIC',
#  'NAMIBIA',
#  'NORWAY',
#  'UNITED ARAB EMIRATES (UAE)',
#  'RED SEA',
#  'ADMIRALTY ISLANDS',
#  'GULF OF ADEN',
#  'COOK ISLANDS',
#  'ST. MAARTIN',
#  'BRITISH ISLES',
#  'JAVA',
#  'GUYANA',
#  'RED SEA / INDIAN OCEAN',
#  'NEVIS',
#  'COAST OF AFRICA',
#  'EQUATORIAL GUINEA / CAMEROON',
#  'SLOVENIA',
#  'NORTHERN ARABIAN SEA',
#  'BRITISH NEW GUINEA',
#  'ANTIGUA',
#  'NORTH SEA',
#  'MAYOTTE',
#  'THE BALKANS',
#  'KUWAIT',
#  'SOLOMON ISLANDS / VANUATU',
#  'IRELAND',
#  'BRITISH WEST INDIES',
#  'KOREA',
#  'GREENLAND',
#  'IRAN / IRAQ',
#  'GEORGIA',
#  'ANGOLA',
#  'SAN DOMINGO',
#  'ASIA',
#  'NORTHERN MARIANA ISLANDS',
#  'TUVALU',
#  'SYRIA',
#  'SWEDEN',
#  'CURACAO',
#  'NETHERLANDS ANTILLES',
#  'GRAND CAYMAN',
#  'DJIBOUTI',
#  'ALGERIA',
#  'ST HELENA',
#  'BANGLADESH',
#  'MID-PACIFC OCEAN',
#  'BAHREIN',
#  'TASMAN SEA',
#  'BRITISH VIRGIN ISLANDS',
#  'PARAGUAY',
#  'MARTINIQUE',
#  'ARUBA',
#  'ICELAND',
#  'SOUTH CHINA SEA',
#  'GUATEMALA',
#  'PUERTO RICO',
#  'WESTERN SAMOA',
#  'CEYLON (SRI LANKA)',
#  'ANDAMAN / NICOBAR ISLANDAS',
#  'GHANA',
#  'ST. MARTIN',
#  'FEDERATED STATES OF MICRONESIA',
#  'BETWEEN PORTUGAL & INDIA',
#  'ITALY / CROATIA',
#  'GABON',
#  'MONACO',
#  'CYPRUS',
#  'OCEAN',
#  'PALESTINIAN TERRITORIES',
#  'DIEGO GARCIA',
#  'UNITED ARAB EMIRATES',
#  'BAY OF BENGAL',
#  'ARGENTINA',
#  'FALKLAND ISLANDS',
#  'MALDIVE ISLANDS',
#  'EGYPT / ISRAEL']

# %%
# Area column: remove whitespaces at beginning and end, remove �, Capitalise all words



df['Area'] = df['Area'].str.title() 
df['Area'] = df['Area'].str.lstrip().str.rstrip()
df['Area'] = df['Area'].str.replace("�","")
df['Area'] = df['Area'].str.replace("?","")

# %%
list(df["Area"].value_counts().index)
# Out:
# ['Florida',
#  'New South Wales',
#  'Queensland',
#  'Hawaii',
#  'California',
#  'Kwazulu-Natal',
#  'Western Cape Province',
#  'Western Australia',
#  'Eastern Cape Province',
#  'South Carolina',
#  'North Carolina',
#  'South Australia',
#  'Victoria',
#  'Torres Strait',
#  'Texas',
#  'Pernambuco',
#  'North Island',
#  'New Jersey',
#  'Tasmania',
#  'South Island',
#  'New York',
#  'Oregon',
#  'Northern Territory',
#  'Central Province',
#  'Abaco Islands',
#  'Virginia',
#  'Havana Province',
#  'South Province',
#  'Veracruz',
#  'Puerto Rico',
#  'Gaza',
#  'New Ireland Province',
#  'Madang Province',
#  'Alabama',
#  'Khuzestan Province',
#  'Georgia',
#  'Guerrero',
#  'Primorje-Gorski Kotar County',
#  'North Province',
#  'Quintana Roo',
#  'Adriatic Sea',
#  'Luzon Island',
#  'Tyrrhenian Sea',
#  'Mediterranean Sea',
#  'Louisiana',
#  'Rio De Janeiro',
#  'Massachusetts',
#  'Malampa Province',
#  'Grand Bahama Island',
#  'Baja California',
#  'Red Sea',
#  'Basrah',
#  'Society Islands',
#  'Bougainville (North Solomons)',
#  'Eastern Province',
#  'Morobe Province',
#  'West Bengal',
#  'Viti Levu Island',
#  'Maputo Province',
#  'Milne Bay Province',
#  'New Britain',
#  'Admiralty Islands, Manus Province',
#  'Kingston Parish',
#  'Binh Dinh Province',
#  'Tamil Nadu',
#  'Sicily',
#  'Mirs Bay',
#  'West New Britain Province',
#  'Loyalty Islands',
#  'South Sinai Peninsula',
#  'Aden',
#  'Caribbean Sea',
#  'Western Area',
#  'Canary Islands',
#  'Maryland',
#  'Karun River',
#  'Delaware',
#  'Rhode Island',
#  'Andros Islands',
#  'New Providence Island',
#  'Hamilton',
#  'Shatt-Al-Arab River',
#  'Inhambane Province',
#  'Coast Province',
#  'Tuamotus',
#  'Ehime Prefecture',
#  'Connecticut',
#  'Guantanamo Province',
#  'Cap Vert Peninsula',
#  'Galapagos Islands',
#  'Bimini Islands',
#  'Saint-Paul',
#  'Tamaulipas',
#  'MaranhO',
#  'Mississippi',
#  'Bali',
#  'Western Province',
#  'Us Virgin Islands',
#  'Exuma Islands',
#  'Madang',
#  'Limpopo River',
#  "Vava'U",
#  'Taveuni',
#  'Cook Islands',
#  'New Ireland Province, Bismarck Archipelago',
#  'La Libertad',
#  'Zadar County',
#  '22N, 88E',
#  'Saint-Denis',
#  'Vita Levu',
#  'Guerro',
#  'Catalonia',
#  'Sinai Peninsula',
#  'Tuscany',
#  'Banaadir Region',
#  'Eleuthera',
#  'Vanua Levu',
#  'Saint-Gilles',
#  'New Territories',
#  'Liguria',
#  'Sardinia',
#  'Guerrrero',
#  'Abau Sub District, Central Province',
#  'Valencia',
#  'Tutuila Island',
#  'Westmoreland Parish',
#  'Western Caroline Islands',
#  'Calabria',
#  'Corfu',
#  'Java',
#  "Grand'Anse",
#  'Saint-Pierre',
#  'CDiz',
#  'Istria County',
#  'VavaU',
#  'Viti Levu',
#  'Corfu Island',
#  'Northern Taiwan',
#  'Split-Dalmatia Count,',
#  'Hong Kong',
#  'Zamboanga Del Sur Province',
#  'Lake Nicaragua (Fresh Water)',
#  'Red Sea State',
#  'Cornwall',
#  'Manila',
#  'Alicante',
#  'Eniwetok Atoll',
#  'Isle Of Wight',
#  'Santiago De Cuba Province',
#  'Yasawa Islands',
#  'Rocha',
#  'Nova Scotia',
#  'Saint-Gilles-Les-Bains',
#  'Guadalcanal Province',
#  'Mombasa',
#  'Okayama Prefecture',
#  'Sinaloa',
#  'Devon',
#  "CTe D'Azur",
#  'Upolu Island',
#  'Vitu Levu',
#  'Bahia',
#  'St. Andrew Parish',
#  'Louisiade Archipelago',
#  'Colima',
#  'St. Johns Reef',
#  'Trinidad',
#  'Gulf Of Panama',
#  'Near Puntarenas',
#  'Hoogly River',
#  'Chatham Islands',
#  'Tongapatu Group',
#  'Off The Coast Of West Africa',
#  'Saint-Joseph',
#  'LimN Province',
#  'Taitung',
#  'Berry Islands',
#  "Ha'Api",
#  'English Channel',
#  'Saint-BenoT',
#  'Makira-Ulawa Province',
#  'Gilbert Islands',
#  'Miyako',
#  'Guanacaste',
#  'San Blas Islands',
#  'St Michael Parish',
#  'DTang-Sal',
#  'Honiara',
#  'Palmyra Atoll',
#  'Saint-Leu',
#  'East New Britain Province',
#  'Cheshire',
#  'Southland',
#  'Colon Province',
#  '1000 Miles West Of Hawaii',
#  'Rio Grande De Norte',
#  'Rangoon',
#  'Anzoategui',
#  'Ligurian Sea',
#  'Out Islands',
#  'Vera Cruz',
#  'Nueva Esparta',
#  'Montserrado',
#  'Lau Group',
#  'ColN Province',
#  'Canal Zone',
#  'Phoenix Islands',
#  'Grand Terre',
#  'Saint-Benoit',
#  'Alinglaplap Atoll',
#  'Gulf Province',
#  'Luzon',
#  'Eastern Caroline Islands',
#  'Paget',
#  'Maharashtra',
#  'Dorset',
#  'Saint-Philippe',
#  'Cat Cay',
#  'Matanzas Province (North Coast)',
#  'Split-Dalmatia County',
#  'East Java',
#  'Wakayama Prefecture',
#  'Praslin',
#  'West End',
#  'Eastern  Province',
#  'Duke Of York Islands',
#  'Ralik Archipelago',
#  'Malaga',
#  'Kadavu',
#  'Venice Province',
#  'Villa Clara Province',
#  'Between Hawaii & Wake Island',
#  'Sussex',
#  'New Georgia',
#  'Oaxaca',
#  'Off Libya',
#  'East Sepik',
#  'Caicos Bank',
#  'Inhambe Province',
#  'Bora Bora',
#  'Grand Canary Island',
#  'Sea Of Japan',
#  'Palawan',
#  'Newfoundland',
#  'Camaguey Province',
#  'Dodecanese Islands',
#  "Nuku'Alofa",
#  'Miyako Island',
#  'Orissa',
#  'Ionian Sea',
#  'Great Exuma Island',
#  'New Ireland',
#  'Lomaloma, Lau',
#  'Between Hastings & Fairlight, Sussex',
#  'Sucre',
#  'Istria',
#  'Inner Islands',
#  'Trois-Bassins',
#  'Mount Lebanon',
#  'Rayong Province',
#  'Southern Thailand',
#  'Kent',
#  'Leyte Island',
#  'Santa Elena',
#  'Socotra Islands',
#  'Northern Java',
#  'Negros',
#  'Off Coast Of West Africa',
#  'Attica',
#  'Western Caroline Islands (North Pacific Ocean)',
#  'Port Louis Province',
#  '150 Miles Offshore',
#  'South Sinai, Gulf Of Aqaba',
#  'West Coast',
#  'Nagasaki Prefecture',
#  'Chungnam',
#  'Ba Ria-Vung Tau  Province',
#  'Southern Province',
#  'Sandaun Province',
#  'East Coast',
#  'Carpathian Sea',
#  'Anatolia',
#  'Cavite Province, Luzon',
#  'Providenciales',
#  'Eastern Catalona',
#  'Near Dakar, Cap Vert Peninsula',
#  'Bocas',
#  'Guyamas',
#  'Sago Prefecture',
#  'Lomaiviti  Island Group',
#  'Pacific Coast',
#  'Florida Straits',
#  '33N, 68W',
#  'Buenos Aires Province',
#  'Manfredonia',
#  'Los Vilos',
#  'Bois-Blanc',
#  '300 Miles From Antigua',
#  '165  Miles From Bermuda',
#  'Las Perlas Archipelago',
#  'French Southern Territories',
#  '"Head Of The Gulf"',
#  'Caribbean Coast',
#  '180 Miles Southeast Of Okinawa',
#  'Mugla Province',
#  'Manila Bay',
#  'Atsumi Peninsula',
#  'Toamasina Province',
#  'Fujairah Emirate',
#  'Bay Islands',
#  'Between Honiara & Isabel Island',
#  'Madeira',
#  'Saint Gilles',
#  'St. Thomas Bay',
#  'Mindoro Occidental',
#  'Cap-Vert Peninsula',
#  '800 Miles From Land',
#  'San Carlos',
#  'North & South Carolina',
#  'Bocas Del Toro',
#  'Antalya Province',
#  'Muala',
#  'Norfolk',
#  '(Southwestern Pacific)',
#  'South Shore',
#  'Shatt-El-Arab River',
#  'Salerno Province',
#  'Pacific Ocean',
#  'Santa Catarina State',
#  'West Of Ceylon (Sri  Lanka)',
#  'Jeju Province',
#  'Isla Provedencia',
#  'South Island, Near Karitane North Of Dunedin',
#  'Northlands',
#  'Taipei Hsien',
#  'Barlavento Islands',
#  'Gulf Of Lyons',
#  'Sainte-Marie',
#  'Midway Atoll',
#  'Madeira Islands',
#  'Edinburgh',
#  'Manus Island',
#  'Bandar MaShur Sea Inlet',
#  'Guam',
#  'Somewhere Between Philadelphia And Hiogo, Japan',
#  'Slovenia',
#  'Conakry Region',
#  'Thessaly',
#  'Between Dr And Puerto Rico',
#  '25 Km Off The Coast Of Iran & 483Km From Mouth Of Persian Gulf',
#  "St. Mary'S Parish",
#  'Aichi Prefecture',
#  'Between Somalia & Yemen',
#  'Off Thessaly',
#  'Johnston Atoll',
#  'Inner Hebrides',
#  'Rio Grande Do Sul',
#  'Cyclades Archipelago',
#  'Cyrenaica',
#  'Tel Aviv',
#  'Genoa Province',
#  'Kagoshima Prefecture',
#  'San AndrS Archipelago',
#  'Minerva Reef',
#  '740 Miles Se Of Tarawa Atoll',
#  'Antofagasta Province',
#  '2 To 3 Miles Off Taboguilla Island, Pacific Ocean',
#  'In The English Channel',
#  'Pagasitikos Gulf',
#  'South China Sea 200 Miles From Hong Kong',
#  'Georges Bank',
#  'Shanghai',
#  'Western District',
#  'Territory Of Cocos (Keeling) Islands',
#  'Cay Sal Bank',
#  'Viscayan Sea',
#  'Sants-Montjic',
#  'Mafia Island',
#  'Arran',
#  'Foveaux Strait',
#  'Open Sea',
#  'Rivers State',
#  'Western Papuan Gulf',
#  'Pennsylvania',
#  'Moala Island',
#  'Near The Andaman & Nicobar Islands',
#  'Curacao',
#  'Unknown, Treated At Wick, Scotland',
#  'Near Bougainville (North Solomons)',
#  'Marches Region',
#  'Dubai',
#  'Laucala Island',
#  'Ancona Province',
#  'Southwest Coast',
#  'Off Green Island',
#  'Wallis And Futuna',
#  'Dar-Es-Salaam',
#  'British Colombia',
#  'Cienfuegos Province',
#  'Sainte-Suzanne',
#  'San Blas Coast',
#  'Delagoa Bay',
#  'Fernando Po Island',
#  'Saint-Louis',
#  'Munxar Reef',
#  'East Wall',
#  'Bernardino Strait Near Gulf Of Leyte',
#  'Andikira Fokithes',
#  'Kentucky',
#  'In Convoy Ob 274',
#  '12 Miles Off The North Coast',
#  '19S, 178E',
#  'Alicante Province',
#  'New Mexico',
#  'Altagracia Province',
#  'Porto Seguro',
#  'Grand Baie',
#  'Ysabel Island',
#  'Kuril Islands In The Pacific',
#  'Lamu Archipelago',
#  'Trelawney Province',
#  "St John'S",
#  'Milne Bay  Province',
#  'On The Kowloon Penisula, South Of Sai Kung',
#  'Lomaiviti Province',
#  'Simpson Bay',
#  'Le Port',
#  'Kochi Prefecture',
#  '04.05N-13.23W',
#  'Ibaraki Prefecture',
#  'Queaon',
#  'Gibraltar',
#  'St. Georges',
#  'Tyrrenian Sea',
#  'Off The Coromandel Peninsula, North Island',
#  'Antarctic Ocean',
#  'Galica',
#  'Northern Peloponnese',
#  '330 To 350 Miles East Of Wake Island',
#  'Eastern Cape  Province',
#  'Bay Of Maputu',
#  'Primorsky Krai',
#  'MLaga',
#  'Provence',
#  'United Arab Emirates',
#  'Oslo Fjord',
#  'Kikori River Mouth',
#  'Kerala',
#  'Saman Province',
#  "250 Miles Southwest Of O'Ahu, Hawaii",
#  'Merizo',
#  'Cyclades',
#  'Panama City',
#  'Bay Of Maputo',
#  'North Of Pernambuco, Brazil',
#  'Syracuse',
#  'Ralik Chain',
#  'Rigo Subdistrict',
#  'Riau Province',
#  'Enroute From Suez To Aden (Yemen)',
#  'Golfo De Venezia',
#  'Peter The Great Bay, Khasan, Primorsky Krai (Far East)',
#  'Northern Province',
#  'Southern District',
#  'Kwajalein Atoll',
#  'Off The Coast Of South America',
#  'Eronogo Region',
#  'Leyte',
#  'New Britain, Bismarck Archipelago',
#  'Kagawa Prefecture',
#  'Mersin Province',
#  '30 Nm From Singapore',
#  'St. Catherine',
#  'Izo Islands',
#  'Saint Leu',
#  'Northern Bahamas',
#  'Niua',
#  'Western Viscayas',
#  'Shat-Al-Arab River',
#  'Casamance',
#  'Bay Of Campeche',
#  'Mercury Islands',
#  'Grand Cayman',
#  'Rombion Province',
#  'Congreve Channel',
#  'Piraeus',
#  'Cikobia Island (North Of Vanua Levu)',
#  'Naples Province',
#  'Between Southampton & Canary Islands',
#  'Lagos',
#  'Northern District',
#  'Trieste',
#  'Mindanao',
#  'Taranto Province',
#  'Off Samar Island In The Gulf Of Leyte',
#  'Off Cape Haitien',
#  'Kadavu Island Group',
#  'Galicia',
#  'San Blas',
#  'Island Of Volos',
#  'Corregidor Island',
#  'Viti Levu Group',
#  'Tokyo Prefecture',
#  'Camiguin Island',
#  '300 Miles East Of Luzon',
#  'Illeginni Atoll',
#  'Green Bay',
#  'Andaman Islands',
#  'Magarita Or Cubagua Islands',
#  'Washington',
#  'Sanma Province',
#  'Middle Caicos',
#  'Clearwater Bay',
#  'Batanes Provine',
#  'Johor',
#  'Between England & South Africa',
#  '9.35N 79.35W',
#  'Santo Domingo',
#  'Paraiba',
#  'Genoa  Province',
#  'Cook Strait',
#  'Demerara County',
#  'Lucy',
#  'Kumamoto Prefecture',
#  'Moro Gulf',
#  'Ambergris Caye',
#  'Caroline Islands',
#  'Taranto',
#  'Alpes Maritime',
#  'Surigao Del Norte',
#  'Hokkaido Prefecture',
#  'Nicoya Peninsula',
#  '1,000 Miles East Of Hawaii',
#  'Bird Island',
#  'Black River',
#  'Misamis Oriental',
#  'ConservatRia District',
#  'Between New Ireland & New Britain',
#  'Cabo San Lucas',
#  'Colon',
#  'Ho Ha Wan Marine Park',
#  'Tiburon Peninsula',
#  'Moray',
#  'Bocas Del Toro Province',
#  'Bonin Islands',
#  'Beaufonds',
#  'Tongatapu',
#  'Argyll',
#  'Between Beira & Maputo',
#  'Romblon Province',
#  'Between Kwajalein Atoll & Johnston Island',
#  'Wake Island',
#  'Holquin Province',
#  'South Atlantic Ocean',
#  'Between Australia & Usa',
#  'Off Vanua Levu',
#  'Sharon',
#  'Off South American Coast',
#  'Gulf Of Suez',
#  'Cook Islans',
#  'Delta',
#  'Gulf Of Tadjoura',
#  'Ratak',
#  'Northwest Italy',
#  'Fife',
#  'Between Hawaii And U.S.A.',
#  '10S, 142E',
#  'Chatham Islands, East Of New  Zealand',
#  'Imperia Province',
#  'Kedah',
#  "L'Etang-Sal",
#  'Golfo Di Genova In The Ligurian Sea',
#  'Istanbul',
#  'Missouri',
#  'Panama Bay (Pacific Ocean)',
#  'Umm Al Qaywayan Province',
#  'Southern Cyprus',
#  'Roncador Bank',
#  'Yucatan Channel',
#  '300 Miles East Of St. Thomas (Virgin Islands)',
#  'Brittany',
#  'Rio San Juan',
#  'Marovo Lagoon',
#  'Muhafazat Hadramawt',
#  'South Coast, East New Britain',
#  'Pinas Bay',
#  "L'Etang-Sale",
#  'Gujarat',
#  'Tamilnadu',
#  'Off Ireland',
#  'Baatan',
#  'Wake Island (Enenkio)',
#  'Moluccas',
#  'Off Coast Of Ecuador',
#  'Granada',
#  'Kwajalein',
#  'North Palawan',
#  'Phang Nga Province',
#  'Alaska',
#  'Magdalena Department',
#  'Maluku Province',
#  'South Of The Equator',
#  'Zambesi River',
#  'Shefa Province',
#  'East Flores',
#  'Wakaya Island',
#  'Skagerrak Arm Of The North Sea',
#  'New Brunswick',
#  '5Aint-Denis',
#  'Batangas Province',
#  'Tafea Province',
#  'Northern (Oro) Province',
#  'Puntarenas Province',
#  'Western Luzon Island',
#  'Mindoro',
#  '40 Miles South Of Naples',
#  'Aulong Island',
#  'Off The Western Coast Of Peninsular Malaysia',
#  'KhNh HA Province',
#  'Norfolk Island',
#  '600 Nm West Of The Canary Islands',
#  'Ascension Bay',
#  '200 Nm Southeast Of Manila',
#  'North Pacific Coast',
#  'Salerno',
#  'Bay Of Bengal',
#  'Antibes',
#  'Baie De Sainte-Marie',
#  'Western Banks',
#  'Bayelsa State',
#  "3539 : 1658'",
#  'Central Philippines',
#  'Moorea',
#  'Jakarta Harbour',
#  'Nice & Marseilles',
#  'Worcestershire',
#  'Cape Coast',
#  'Isles Del Rosario',
#  'Easter Ross',
#  '60 Miles North Of San Domingo In The West Indies',
#  'Transvaal',
#  'Malaita Province',
#  'Makira-Uluwa Province',
#  'St. Anne',
#  'Rodrigues',
#  'Illinois',
#  'East New Britain',
#  'West Africa',
#  'Sfax',
#  'Tuamotos',
#  'Calvados Archipelago',
#  'Savona',
#  'Between Noumea & Sydney',
#  'Okinawa Prefecture',
#  'Ahirkapi Coast',
#  'Between Perth & Colombo',
#  'Between Comores & Madagascar',
#  'Herzliyah',
#  'Adana Province',
#  'Tavenui',
#  'Basrah City',
#  "South Ch'Ungch'Ong Province",
#  'New Ireland, Bismarck Archipelago',
#  'Between Timor & Darwin, Australia',
#  'Strait Of Malacca',
#  'CortS',
#  'East Yorkshire',
#  'Bwagaoia',
#  'Santa Cruz Island',
#  'South Korea',
#  'Liguaria',
#  'Pearl Islands',
#  'Santiago Island',
#  'Suez',
#  'Boa Vista Island',
#  'Telyakovsky Bay, Khasan,  Primorsky Krai (Far East)',
#  'North China',
#  'Quezon',
#  'East Of The Gulf Of Aqaba',
#  'Rangiroa',
#  'Mexico / Caribbean Sea',
#  'In Transit Between Tinian And Leyte',
#  'Cape Haitien',
#  'Turtle Bogue',
#  'Northwest Of Viti Levu',
#  'Near The Fiji Islands',
#  'Vancouver',
#  'North Region',
#  'Port Shelter',
#  'Bikini Atoll',
#  '400 Miles Southeast Of Sri Lanka',
#  'Clarendon',
#  'Argyllshire',
#  'Bay Of Biscay',
#  'Northwest Of Papua New Guinea',
#  'Costa Blanca',
#  'Alagoas',
#  'Bay Of Fundy',
#  'Bardestrand',
#  'Panama',
#  'Santa Isabel Province',
#  "L' Etang Sal-Les-Bains",
#  'Ganges-Brahmaputra Delta',
#  'Lau Province',
#  'South Pacific Ocean',
#  'Apolima Strait',
#  'Harare Province',
#  'Woodlark Islands',
#  'Masbate',
#  '18S / 50E',
#  'Lukovo',
#  'Maine',
#  'Island Of St. Thomas',
#  'Phuket',
#  'Amirante Islands',
#  'La Saline-Les-Bains',
#  'Antsiranana Province',
#  'Saipan',
#  'In The Gulf Stream',
#  'Abau Subdistrict,Central Province',
#  'Reggio Calabria Province',
#  'Halifax',
#  'Balearics',
#  'Namonuito Atoll',
#  'Bay Of Monaco',
#  'Tabuk Province',
#  'Lomaiviti Provine',
#  'Grand Turk Island',
#  'Elqui Province',
#  'Walkers Cay',
#  'Estuaire Province',
#  'South Chungcheong Province',
#  'Strait Of Messina',
#  'Kowloon Peninsula',
#  'Salinas Bay',
#  'Island Of Kos',
#  'Carabobo',
#  'Biserta',
#  'Gran Canaria',
#  'Madang (Wo)',
#  'Ryukyu',
#  'Central Tuamotu',
#  'Los Roques  Islands',
#  'North Devon',
#  'Line Islands',
#  'Andalucia',
#  'North Sumatra',
#  'Makora-Ulawa Province',
#  'Isle Of Man',
#  'Catalunya',
#  'Kwazulu-Natal Between Port Edward And Port St Johns',
#  'Teramo',
#  'Singapore Harbor',
#  'Cargados Carajos Shoals (St. Brandon)',
#  'Southern Japan',
#  'Mozambique Channel',
#  'Coquimbo',
#  'Brindisi Province',
#  'Lower San Juan River',
#  'South Devon',
#  'Mangaia Island',
#  'Valpariso Province']

# %%
# Same for location column

list(df["Location"].value_counts().index)

df['Location'] = df['Location'].str.title() 
df['Location'] = df['Location'].str.replace("�","")
df['Location'] = df['Location'].str.lstrip().str.rstrip()

# %%
# Check activity column

list(df["Activity"].value_counts().index)
# Out:
# ['Surfing',
#  'Swimming',
#  'Fishing',
#  'Spearfishing',
#  'Bathing',
#  'Wading',
#  'Diving',
#  'Standing',
#  'Snorkeling',
#  'Scuba diving',
#  'Body boarding',
#  'Body surfing',
#  'Swimming ',
#  'Pearl diving',
#  'Treading water',
#  'Kayaking',
#  'Boogie boarding',
#  'Free diving',
#  'Fell overboard',
#  'Windsurfing',
#  'Boogie Boarding',
#  'Shark fishing',
#  'Walking',
#  'Surf-skiing',
#  'Rowing',
#  'Floating',
#  'Surf skiing',
#  'Fishing ',
#  'Canoeing',
#  'Surf fishing',
#  'Fishing for sharks',
#  'Kayak Fishing',
#  'Sponge diving',
#  'Freediving',
#  'Diving for trochus',
#  'Sitting on surfboard',
#  'Sailing',
#  'Sea disaster',
#  'Fell into the water',
#  'Surfing (sitting on his board)',
#  'Skindiving',
#  'Spearfishing ',
#  'Floating on his back',
#  'Playing',
#  'Boating',
#  'Free diving for abalone',
#  'Paddle boarding',
#  'Diving for abalone',
#  'Murder',
#  'Spearfishing on Scuba',
#  'Kite Surfing',
#  'Surf skiing ',
#  'Sea Disaster',
#  'Fishing for mackerel',
#  'Dangling feet in the water',
#  'Paddleskiing',
#  'Hard hat diving',
#  'Freedom swimming',
#  'Boat',
#  'Shipwreck',
#  'Fishing on a boat',
#  'Spearfishing / free diving',
#  'Freedom Swimming',
#  'Seine netting',
#  'Fishing boat',
#  'Skin diving',
#  'Jumping',
#  'Splashing',
#  'Scuba diving (but on surface)',
#  'Paddling on surfboard',
#  'Body-boarding',
#  'Clamming',
#  'Diving for coins',
#  'Scuba diving (submerged)',
#  'Lifesaving drill',
#  'Jumped into the water',
#  'Wade Fishing',
#  'Stand-Up Paddleboarding',
#  'Competing in the Woodvale Atlantic Rowing Race',
#  'SCUBA diving',
#  'Spearing fish',
#  'boat capsized',
#  'Fishing for kob',
#  'Shark watching',
#  'Fishing for snapper',
#  'Escaping from Alacatraz',
#  'Body Boarding',
#  'Standing in knee-deep water',
#  'Scuba diving for abalone',
#  'Sitting on gunwale of boat',
#  'Wade fishing',
#  'Crayfishing',
#  'Sculling',
#  'Shell diving',
#  'Walking out of the water after surfing',
#  'Scuba Diving',
#  'Boat swamped',
#  'Spearfishing (free diving)',
#  'Fishing for bluefish',
#  'Tagging sharks',
#  'Feeding fish',
#  'Kite surfing',
#  'Surfing ',
#  'Surfing, paddling seawards',
#  '.',
#  'Floating on a raft',
#  'Hookah diving for abalone',
#  'Jumped overboard',
#  'Unknown',
#  'Diving ',
#  'Wreck of the schooner Pohoiki ',
#  'Wade-fishing',
#  'Crabbing',
#  'Playing in the surf',
#  'Kayaking / Fishing',
#  'Free diving & spearfishing',
#  'Diving for sponges',
#  'Spearfishing / Scuba diving (at surface)',
#  'Their 9 m launch was run down by a 25,000-ton Japanese freighter  on the night of 3-11-1977 & they drifted, clinging to an icebox for 2 days',
#  'S2N Navy scout plane went down, E.H. Almond & Lieut A.G. Reading in water',
#  'Spearfishing / Free diving',
#  '"Flying Tiger" transport plane went down with 5 men onboard',
#  'Kayak fishing',
#  'Diving for beche-de-mer ',
#  'Diving around anchored liner',
#  'Splashing ',
#  'Swimming from the New Venture ',
#  'Diving from canoe',
#  'Aircraft crashed into sea',
#  'Teasing a shark',
#  'Washing his feet',
#  'Jumped overboard ',
#  'Surfing, collided with shark',
#  'Beach seine netting',
#  'Shooting sharks ',
#  'Fishing for tuna',
#  'Standing / Surfing',
#  'Free diving / Spearfishing',
#  'Five men on makeshift raft after their 10 m fishing boat  capsized and sank in rough seas. Survivors rescued after  7.5 hours in the water',
#  'Floating on back',
#  'Boat capsized, swimming ashore',
#  'Knocked overboard',
#  'Cruising',
#  'Fishing for cod',
#  'Floating in inner tube',
#  'Sitting in shallows',
#  'Kayaking ',
#  'Swimming / Wading',
#  'Surfing (lying prone on his board)',
#  'Standing ',
#  'Diving for crayfish',
#  'Spearfishing using Scuba',
#  'Jet skiing',
#  'Fishing for lobsters',
#  'Swimming / escaping imprisonment ',
#  'Swimming after his hat',
#  'The Christie V sank on 11/6/1988, survivors were adrift on a dinghy',
#  'Hookah diving for sea urchins',
#  'Kite boarding',
#  'Diving for beche-de-mer',
#  'Air disaster',
#  'Suicide',
#  'Body surfing / treading water',
#  'Swimming / snorkeling',
#  'Playing in the water',
#  'Scuba diving & spearfishing',
#  'Attempting to kill a shark with explosives',
#  'Diving for lobsters',
#  'Standing in waist-deep water',
#  'Sitting in the water',
#  'Bathing ',
#  'Swimming, ducking for shells in water 0.9 m deep',
#  'Fishing (Seining)',
#  'Shark diving',
#  'Fishing for whiting',
#  'Swimming alongside NOAA research vessel Discoverer',
#  'Bathing in river',
#  'Kitesurfing',
#  'U.S. Airforce C124 enroute from Hickham Air Base to Japan went down. The 3 survivors fashioned raft from mailbags  & were rescued 3 days after the crash.',
#  'Shark tagging',
#  'HMAS Parramatta torpedoed & sunk by the U-559',
#  'Thrown overboard',
#  'Collecting shells',
#  'Finning the shark that bit him',
#  'Hoisting shark aboard fishing boat',
#  'Ocean racing',
#  'fishing boat exploded & sank',
#  'Diving into water',
#  'Diving off jetty',
#  'Dived for a coin',
#  'Kite Boarding',
#  'Spearfishing / Scuba diving',
#  'Diving?',
#  'Transatlantic Rowing',
#  'Fishing for squid',
#  'Free diving, Spearfishing',
#  'Air Disaster',
#  'Fishing from surf ski',
#  'Washing',
#  'Fishing for prawns',
#  'Swimming or surfing',
#  'Netting shrimp',
#  'Free-diving',
#  'Diving for trochus shell',
#  'Free diving / spearfishing',
#  'Swimming ashore from capsized boat',
#  'Swimming near jetty',
#  'Boat with 5 men capsized while returning to the Amerique',
#  'Paddling',
#  'Spearfishing Competition',
#  'Rowing ',
#  'Launching rowboat through the surf',
#  'Kiteboarding',
#  'Fishing for white shark',
#  'Fishing / washing bait off hands',
#  'Attempting to ride a shark',
#  'Steinhart Aquarium',
#  'Defecating in water beneath the docks',
#  'bathing ',
#  'Harassing a shark',
#  'Cargo ship El Gamil entroute Suez to Yemen (Aden) when her cargo shifted and she sank. 19 Egyption sailors jumped into the water and swam for several hours before being bitten by sharks',
#  'Fell from yardarm of British ship Rover',
#  'Observing a shark feeding on a carcass of a humpback whale',
#  'Diving (shell maintenance)',
#  'Boat stopped to repair electric pump',
#  'Swimming or Snorkeling',
#  'Standing in waist-deep water, helping his father tend a gill net containing dead fish',
#  "Scientific research (Dr. Sonny Gruber's student)",
#  'Floating face-down in knee-deep water',
#  'Attempting to retreive a dinghy',
#  "Swimming at surface through school of feeding 2.5' to 5� sharks",
#  'Diving for pearls',
#  'The Dwarka foundered',
#  'Watching the shark feeding on a dead pinniped',
#  'Swimming 10 m from shore',
#  'Exercising his dog in the shallows',
#  'The World Liberty and the tanker Mosli collided. The  Halcyon Breeze sent a lifeboat to the rescue, but it was smashed, throwing 6 men in the  water.',
#  '3-masted steel barque Glenbank foundered during a cyclone',
#  'Unknown, but it was said to be the "First known attack in Sydney Harbour"',
#  'M.V. Tropical sank. Sole survivor rode oil drums for 8 days without food or water.',
#  'Towing rubber dinghy',
#  'Lying in 2 feet of water',
#  'Murdered',
#  'The troopship Britannia was sunk by the German raider Thor',
#  'Swimming in the channel',
#  'Wading near a fishing net',
#  'Photographing fish',
#  'Surf fishing in waist-deep water',
#  'Fell overboard, prop slashed arm',
#  'Touching the mouth of a supposedly dead shark',
#  'Dutch merchant ship Zaandam torpedoed  by the U-174 amidships, sank & dozens of survivors took to rafts & boats. One man, Izzi, who drifted 83 days on a raft related that sharks attacked many men in the water when the ship went down',
#  'Loss of the schooner Nomad',
#  'Playing in the surf with his 2 dogs',
#  'Free diving / modeling',
#  "Fishing, caught a 15' shark & took it onboard",
#  'Colombian  (Avianca) DC-4 airliner plunged into the sea 5 minutes after takeoff',
#  'Fleeing across a river',
#  'Swimming with pod of dolphins',
#  'Abalone diving using Hookah (near calving whales)',
#  'Surfing, but treading water',
#  '"Crossing the river"',
#  'Swimming along a row of nets',
#  'Sitting on side of dinghy mending a net',
#  'Swimming with other crew near wharf',
#  'Reached out to disentangle rope & fell overboard',
#  'Freediving, inspecting Kaunakakai wharf construction after blasting & dredging ',
#  ' ',
#  'Skin diving for trepang but at surface next to the boat',
#  'Spearfishing, had fish on his spear',
#  'Fishing, holding fish in right hand',
#  'Paddling a surfboat',
#  'Inspecting teeth of supposedly dead (hooked & shot) shark',
#  'Floating with life buoy after pilot launch capsized',
#  'Swimming with goggles',
#  'Fishing in ankle-deep water',
#  'Swimming near pier',
#  'Fishing in knee-deep water',
#  'Removing shark from a trap',
#  'A junk foundered',
#  'Boat capsized, swimming to shore',
#  'Attempted to return injured shark to the sea',
#  'Sitting',
#  'seaplane Columbus ditched in the sea',
#  'Swimming off yacht',
#  'Swimming, after falling overboard',
#  'Boat capsized?',
#  'Swimming, using bundles of sticks as raft',
#  'Conducting a promotional film project for the Gemini space program (a practice astronaut recovery)',
#  'Oystering',
#  'Returning to shore, collided with shark',
#  'Bather',
#  'Floating near boat & observing bioluminesce',
#  'Shrimping',
#  'Commercial Salvage Diving',
#  'Thrashing the water / imitating the shark victim from "Jaws"',
#  'The 500-ton coastal trader Polurrian foundered ',
#  'The British steamer Caribbee foundered',
#  'Vessel caught fire & capsized, survivors in the water',
#  'Wreck of the 150-ton brig Maria',
#  'Wading to dinghy, carrying his son',
#  'boat from ship Josephine capsized in squall',
#  'In rubber dinghy with Captain Eddie Rickenbacker for 21 days. ',
#  'Free diving for trochus',
#  'Swimming or snorkeling',
#  'Swimming from shore to anchored sailboat',
#  'Hooking into a whale',
#  'Explosion & sinking of the USS Juneau after being torpedoed by the submarine  I-85',
#  '17 Maldivians adrift in open boat for 31 days',
#  'Fishing in waist-deep water',
#  'Swimming with fish attached to  belt',
#  'Swimming alongside the schooner Catherine Wilcox',
#  'Walking in surf',
#  'Catching a turtle',
#  'Gaffing netted shark',
#  'Swimming alongside yacht Mexico Fiesta',
#  'Attempting to net shark in shark channel',
#  'Swimming to avoid capture',
#  'Spent 8 days in dinghy',
#  'Playing with a frisbee in the shallows',
#  'Boarding a ship',
#  'Collecting ornamental fish',
#  'Chasing shark out of bathing area while riding on a surf-ski',
#  'Stamding',
#  'Paddle-surfing',
#  'Sitting in a boat',
#  'Air Disaster - Piper aircraft crashed into the sea, killing all on board',
#  'Unknown, their unoccupied yawlboat was recovered',
#  'Swimming to shore from capsized sailboat',
#  'Removing hook from shark',
#  'Wooden fishing boat',
#  'Fishing boat swamped in a storm',
#  'Swimming after falling overboard',
#  'She was on a ship that was torpedoes & was in the water awaiting rescue',
#  'Working on the bridge when he fell into the river',
#  'Dived from inner-tube',
#  'Capsized fishing boat',
#  'Swimming to shore from the Medic',
#  'Diving off wharf',
#  'Swimming, naked',
#  'male',
#  'Conducting research',
#  'Spearfishing, but swimming at surface',
#  'Standing, collecting bananas',
#  'Lifesaving exhibition',
#  'Dismantling cable buoys of the cable ship All America',
#  'Scuba diving, reportedly also spearfishing',
#  'Fishing for rock lobster',
#  'Swimming in waist-deep water ',
#  'A 75-ton  Japanese fishing ship was sunk by  Chinese Nationalist gunboat, shipwrecked men were clinging to debris',
#  'Swimming in canal',
#  'Snorkeling on surface',
#  'Swimming (using a float)',
#  'Walking in shallows',
#  'Surfing (or sailboarding)',
#  'Skindiving,',
#  'Sinking of the ferryboat      Don Juan',
#  'yachtsman in a zodiac',
#  'Swimming behind sailboat',
#  'Feeding mullet to sharks',
#  'Swimming, attacked at  surf carnival',
#  'Arsinoe, a French tanker',
#  "Attempting to lasso shark's tail",
#  'Fishing for snoek & yellowtail',
#  'Commercial fishing vessel, Ev-nn, struck object & sank. Ken Crosby and  Jame & Ann Dumas adrift on makeshift raft.',
#  'Scuba diving (ascending using scooter)',
#  'Free diving for molluscs',
#  'Surf fishing / wading',
#  'Wreck of the steamship Sultan of Bombay',
#  'Aircraft ditched in the sea, swimming ashore',
#  'Row boat (from the gunboat Elcano) was sinking, put finger in hole',
#  'Fishing / standing in waist deep water',
#  'Attempting to drive shark away from sailing regatta',
#  'Fell overboard, hanging onto lifebuoy',
#  'Fishing from prawn trawler',
#  'Spearfishing, but swimming on surface',
#  'Swimming & splashing',
#  "Filming 5' blue shark",
#  'Fell off aircraft carrier',
#  'Fishing from boat, Kaimamla',
#  'Anti-Aircraft cruiser USS Atlanta (CL,-05) travelling in convoy after the Battle of Midway, encountered a Japanese flotilla  (Battle of Guadalcanal) &, heavily damaged by gunfire, she was lost off Lunga Point. Victim was swimming when bitten.',
#  'Small boat with 2 men onboard hit a submerged coral formation. Men began swimming to shore',
#  'Crossing the bay at the ford',
#  '3,909-ton Panamanian freighter Chieh Lee sank in a typhoon',
#  'Diving for sinkers',
#  'Dived into a school of baitfish',
#  'Closed circuit diving (submerged). Diving to recover jettisoned packets of opium for police',
#  'Anti-sabotage night dive exercise alongside destroyer (Scuba diving)',
#  'Surfing, fell off surfboard',
#  'Went to aid of child being menaced by the shark',
#  'Fishing, hauling in net, shark in net',
#  'Air/Sea Disaster Pan-American Airlines Stratocruiser with 44 people onboard crashed into the sea',
#  'Body surfing or body boarding',
#  'Free diving , but surfacing',
#  'Sailboarding, fell into water 100 yards outside the breakwater',
#  'Swimming after boat became disabled',
#  "Boat capsized between O'ahu & Molokai",
#  'Torpedoed & burning British  light cruiser with a crew of 450 men',
#  'Fishingat',
#  'Dragging stranded shark ashore',
#  'The 6015-ton British ship Empire Avocet was torpedoed by the German submarine U-125. ',
#  'Steamer Una wrecked with 75 laborers onboard. Survivors took to rafts & lifeboats.',
#  'Free diving & spearfishing (ascending)',
#  'The shrimper Loless Maurine capsized in heavy seas & the men were swimming ashore  ',
#  'Swimming to shore from capsized kayak',
#  'Netting pilchards',
#  'Free diving for shell',
#  'Swimming with speared fish',
#  'Collecting fish in military trap when bitten by captured shark that had been shot by soldiers with Garten',
#  'Free diving for abalone (ascending)',
#  'boat from the Austrian ship Elizabeth',
#  'Plane crashed in water, men in life raft',
#  'Swimming out to porpoises ',
#  'The steamships Thingvalla and Geiser collided',
#  'Filming & feeding captive sharks',
#  'Fishing, Struck by another shark when removing shark from line',
#  'Trailing hand in the water',
#  'Canoe capsized by shark',
#  'USS Hoel DD 533 sunk on 10/24/1944 in the Battle off Samar. 2 crewmen were swimmng alongside a floater net &',
#  'Diving, retrieving film package from Titan 3C rocket',
#  'Surfing or body surfing',
#  'Fishing, standing in water washing fish',
#  'Light aircraft ditched at sea',
#  'Fishing, holding fish',
#  'Trying to catch a wounded bird',
#  'small boat',
#  'Lying atop surfboard',
#  'Fishing, one of three fishermen swept into the sea by a large wave ',
#  'Free diving for abalone from Zodiac (submerged)',
#  'His balloon crashed in the harbor',
#  'U-177 torpedoed & sank the troopship Nova Scotia',
#  'Swimming / floating on his back',
#  'Fishing from shore, washed into the sea',
#  'Accidentally thrown overboard & treading water while awaiting rescue',
#  'Helmet diving, collecting trochus shell',
#  'Net fishing, fell into the water',
#  'Fishing trawler Flavio Gioia ',
#  'Lifeboat capsized',
#  'Boogie boarding or Surfing',
#  'Swimming underneath house on pilings',
#  'Wading or swimming',
#  'Swimming, when caught in heavy seas',
#  'Surfing, but lying prone on his board',
#  'Inebriated, woke from sleep and fell off deck into the water ',
#  'Shark fishing, knocked overboard',
#  'yachting accident',
#  'Fishing, two large sharks passed. He speared one and it bit him',
#  'Italian liner Principessa Mafalda sank',
#  'Spearfishing, shot shark, hauled it onto boat',
#  'Bathing alongside the American ship Thomas W. Sears',
#  'Sea Disaster, sinking of the  SS Vestris',
#  'Japanese POW ship Arisan Maru with 1800 American prisoners of war on board bound for slave labor camps was torpedoed by an American submarine',
#  'Playing / standing',
#  'Swept out to sea by the tsunami, she clung  to a log for 24 hours',
#  'Spearfishing / scuba diving',
#  'Finning the shark',
#  '1446-ton Norwegian barque Errol, bound from Peru to Newcastle with 22 on board wrecked. Survivors shelterd on the wreck of the Annasona. Subsequently the Master, his wife & 4 children perished along with several crew. Survivors (5) were rescued 7/12/1909',
#  'Standing alongside surfboard',
#  'Sea Disaster, sinking of the motorship Wingate',
#  'Spearfishing, but walking carrying fish on end of speargun',
#  'Paddle Boarding',
#  'Splashing in water ',
#  '"Boat accident"',
#  'British patrol boat 1250-ton HMS  Valerian foundered in a hurricane',
#  'Surf fishing, wading ',
#  'Free diving / photography, kneeling on sand',
#  'Filming a documentary',
#  'Air disaster: crash of Air France Super Constellation ',
#  'Scuba diving & U/W photography',
#  'Fishing for snappers & cleaning mullet. Put mullet over side of boat to wash it',
#  'Attempting to chase shark out to sea',
#  'Leaving the water',
#  'Shark Fishing',
#  'Swimming ashore from fishing boat swamped and sunk by a squall',
#  'Commercial spearfishing',
#  'Sailing on catamaran & fell into the water',
#  'Fishing, on charter boat Silver Dollar',
#  'Picking up shark by the tail',
#  'Bathing / standing',
#  'Bottom fishing for lingcod & had hooked a fish',
#  'Testing anti-shark cage',
#  'Standing, holding shark pup',
#  'Knocked into the water',
#  'Scuba Diving for scallops',
#  'Resting on body board',
#  'Survived US Naval aircraft crash, climbing onboard rescue vessel when he fell back into sea ',
#  'Clinging to shipwrecked junk',
#  'Helping friend land hooked shark',
#  'Boat of a Hawaiian brig was stove in by  whale',
#  'Steamer Durao struck rock & filled, boats capsized, passengers & crew tried to swim to shore',
#  'Snorkeling (filming the sardine run)',
#  'Fell overboard from sponge vessel',
#  'Wading to shore from his boat',
#  "A man's head found in a shark caught by British steamer Syria",
#  'Boat capsized',
#  'Paddle-boarding',
#  'Floating in tube',
#  'S2F-1 airplane crashed immediately after carrier take-off',
#  'Lying prone on surfboard',
#  'Swimming or wading out  to warn bathers that a shark had been seen',
#  'Fishing for squid aboard the trawler Shikishima-Maru when the shark leapt into the boat',
#  'Bathing alongside US Naval ship',
#  'Trailing the field in a surf race',
#  '"Swimming vigorously"',
#  'Shipwrecked; adrift on raft for 2 days & 2 nights',
#  'Taking wife to beach & about 1 m from the shore',
#  'SCUBA Diving',
#  'Fell overboard?',
#  'Swimming, after sailboat capsized',
#  'Attempting to rescue crew after whale upset their boat',
#  'Diving alongsidethe steamship Ranelagh ',
#  'Fishing, speared shark upset canoe & man fell in water',
#  'Floating ',
#  'Scuba diving, attempting to catch a captive shark',
#  'Sinking of the ferryboat Dumaguete ',
#  'Walking in chest-deep water',
#  'Taking catch from a fish weir in which the shark was snared',
#  'Floating on his back in an inner tube',
#  'Wading / fishing & carrying a bag of fish',
#  'R5D aircraft went down with 29 on board',
#  'Helping angler land a shark',
#  'Among 31 survivors of crew from the sampan Fukulya Maru (which reached Thursday Island in rowing boat) was a man whose arm had been bitten off by shark. The sampan wrecked west of McArthur island ',
#  'Diving (Helmet) for sponges',
#  'Spear fishing',
#  'Wreck of the 1308-ton Norwegian ship Auckland',
#  'Lost his footing & fell overboard',
#  'Adrift in a life jacket',
#  'Hunting turtle',
#  'Diving for pearl shell',
#  'Riding a horse',
#  'Netting menhaden, sharks caught in net',
#  'Crossing the river mouth',
#  "Spearfishing, holding 5' speared fish",
#  'Fishing with hand line tied to wrist & was pulled into the water',
#  'Kayaking (returning from spearfishing)',
#  "On board 51' fishing vessel One Ki",
#  'Hauling in net with shark in it',
#  'The 6711-ton American freighter & troop transport Cape San Juan was torpedoed by the Japanese submarine I-21',
#  'Chumming for sharks',
#  'Fishing for bluefish, shark leapt into dory',
#  'Jumped overboard and swimming',
#  "Onboard 21' powerboat that capsized in rough seas",
#  "a corsair's boat was overturned",
#  'Swimming on sandbar adjacent to channel',
#  'Wreck of the tug Magellan',
#  'C47 aircraft carrying 5,000 lbs of ice ditched in the sea',
#  'Body boarding ',
#  'Playing soccer in the water',
#  'Swimming in pool formed by construction of a wharf',
#  'Fishing (rod & line)',
#  'Swimming, carrying tin can with mail to steamer',
#  'Fishing, casting in the surf',
#  'SUP Foil boarding',
#  'Chumming for white sharks',
#  'Free diving with a pod of dolphins',
#  'Wading after stray fish from seine netter�s catch',
#  'Fishing for yellowtail, Seriola quinqueradiata',
#  'A barque wrecked',
#  'Free diving, working on U/W scenes for motion picture',
#  'Surfing & dangling foot in water amid baitfish',
#  'Collecting fish by lamplight in gully',
#  'Free diving for abalone (surfacing)',
#  'Fishing, shark caught in his net',
#  'Free diving for scallops',
#  'Sight-seeing',
#  "Explosion destroyed 28' boat, survivors in the water ",
#  'Body surfing or Boogie boarding',
#  'Killing  sharks',
#  'Bending over',
#  'Swimming, poaching perlemoen',
#  'Slipped off rocks and fell into the water',
#  'Wading to shore after surfing',
#  'Fishing, standing in waist-deep water',
#  'Rowing an inflatable dinghy',
#  "Captured Allied soldiers were squeezed into 3' bamboo pig baskets & fed to waiting sharks",
#  'Free diving, collecting sand dollars',
#  'Swimming naked near a date palm where many dates fell into the water',
#  'Fishing with a cast net',
#  'Scuba Diving for lobster (at surface)',
#  'Taking boat from California to Florida when it ran aground & he was swimming back to boat',
#  'Skindiving, fish at belt',
#  'Launching a boat',
#  'Wreck of the USS Somers',
#  'Paddling on surfboard or body board',
#  'Bathing close inshore',
#  'Yacht Gooney Bird foundered, 4 survivors on raft',
#  'Pearl diving from lugger',
#  'Swimming after harpooned whale capsized boat',
#  'Diving from lugger',
#  'native boats sunk in storm',
#  'Standing / fishing',
#  'Fishing from a small boat & put his hand in the water while holding a dead fish',
#  'Body surfing & treading water',
#  'Hauling dead shark aboard, when another shark leapt out of the water & bit him',
#  'Removing shark from tank in nightclub ',
#  'Diving (Hookah)',
#  'Fishing (big game)',
#  'The cutter Francis Adams foundered',
#  'p�cheur de bichiques',
#  'On fishing boat & trailing hand in the water',
#  'Fishing for the shark that killed George Lundberg',
#  'Surfing, but swimming to his board',
#  'Abandoning burning steamship Don Juan',
#  'Canoe with 3 men onboard sank',
#  'Foundering of the Israeli freighter Mezada',
#  'Free diving & spearfishing ',
#  'Hauling in net',
#  'Testing classified underwater electronic gear for Raytheon Corporation, vessel torn apart by explosion',
#  'Disappeared 11 days earlier, probable homicide victim',
#  'Washed overboard into school of fish',
#  'Fishing for tarpon',
#  'Hand lining for shad',
#  'Swimming to shore after boat capsized by a squall',
#  'Washing clothes on stairs',
#  'Fell overboard from SS Ripley Castle',
#  'Swimming & snorkeling',
#  'Fishing & spearfishing',
#  'Fishing for octopus',
#  'In deep water about 100 yards from his ship',
#  'Checking fish traps, fell into the water',
#  'Placed hand in disemboweled shark�s jaws',
#  'Air/Sea Disaster involving C-54 Air Force Transport No. 2686 with 37 on board',
#  'Spear fishing, removing fish from spear',
#  'Ditched aircraft, 3 men in the water. Swam for 31 hours',
#  'Bathing in knee-deep water',
#  'Swimming ashore from a "filibuster"',
#  'Went overboard',
#  'Trochus diving, but floating on surface',
#  'Motor launch Baby Princesa capsized with 22 people on board',
#  'Ship lay at anchor & man was working on its rudder',
#  'Fishing for white sharks',
#  'Swimming, after single-engine aircraft went down in the sea',
#  'Towing her sister on plastic ski board',
#  'Wading / Surfing',
#  'Body found floating next to his ship',
#  'Playing volleyball with friends',
#  'Diving for pearl',
#  'Spearing a shark',
#  "Competing in U/W endurance record, standing beside drum in 10' of water",
#  'Fell oveboard from steamer Wanderer',
#  '3.3 m fishing boat sank. Treveluwe & Peter Hodgson (wearing lifejackets) were drifting in the current',
#  'Surfing, paddling shorewards',
#  'The cutter yacht Cutty Sark sank',
#  'Treading water/ Surfing',
#  'Attempting to illegally enter the USA',
#  'Commercial diver (submerged or treading water)',
#  'Floating on inner tube after diving for lobster',
#  'British cruiser Dunedin torpedoed & sunk by the U-124',
#  '3 men & 2 boys picked up wearing life jackets and with inner tube',
#  '25-foot cabin cruiser Happy Jack sank in heavy seas',
#  'Washing his pig in preparation for a religious ceremony',
#  'Spearfishing, Smith  & Walker touched shark with tip of their guns',
#  'Surfing / Swimming',
#  'Photographing the shark',
#  'Spearfishing & lassoed shark',
#  'On inflatable raft',
#  'Fishing, slipped on rocks & fell into sea',
#  'Surfing with dolphins',
#  'Spearfishing on scuba',
#  'Washing sand off a speared fish',
#  'A group of survivors on a raft for 17-days',
#  'Carrying a supposedly dead shark by its mouth',
#  'Dog paddling or standing',
#  'Attempting to escape by swimming to shore',
#  'Feeding a shark',
#  'Pulling shark from the water',
#  'Oyster fishing',
#  'Surfing, but standing in water alongside board',
#  'Wreck / Technical diving',
#  'Standing / Bathing',
#  'Attacked shark with fists',
#  'Collecting fish ',
#  'Swimming alongside warship   Tsingt-ao',
#  '"Climbing up to ship after repairing the stern in water"',
#  'Fishing, attempted to take a netted shark',
#  "Adrift, hanging onto cushion, after his 17' skiff ran out of gas & capsized 3 miles from shore",
#  'Surfing, sitting on board',
#  'Jumped into the water from a cliff',
#  'British ship, Britannia,  was loading lumber. He was bathing',
#  'Splashing / wading',
#  'Marathon swimming',
#  'Free diving for lobster',
#  'After rowing skiff was holed by shark, he was attempting to swim ashore',
#  'Fishing (Drowned 2-Apr-2002)',
#  'Fell overboard & swimming',
#  'Murdered by Thai pirates',
#  'Skindiving for specimens',
#  'Fell overboard from USS cruiser Tacoma',
#  'Fell oveboard',
#  'Surfing, fell off surfboard & stepped on the shark.',
#  'Sinking of the dredge World Atlas',
#  'Resting on surfboard',
#  'Swimming in strong current with 3 others when he disappeared',
#  'Spearfishing & diving for paua',
#  'Spearfishing (Free diving)',
#  'NSB Meshing',
#  'Helmet diving',
#  "Lying on the bottom of a 16' dinghy",
#  'Sleeping in anchored boat',
#  'Pacific Seafarer of US Navy',
#  'The 2379-ton French steamer La Seyne collied with British steamer Onda & sank in minutes. Passengers jumped overboard expecting to be picked up by Onda�s boats',
#  'Holding shark on leader & dangling it above the water',
#  'Fell or jumped overboard from the liner Rhynland',
#  'Sponge divers',
#  'The Cuban freighter Libertad was torpedoed and sunk by the German submarine U-129',
#  'Free diving for trochus shell, swimming to dinghy',
#  'Bathing with sister',
#  'Floating on raft',
#  'Wreck of the steamship Birkenhead',
#  'Snorkeling, carrying a speared fish in her hand',
#  'Splashing in surf',
#  'Removing shark from a net',
#  'Body found on deserted luxury yacht, 38� Christine',
#  'Swimming near canoe',
#  'Floating or standing',
#  'Cleaning the side of a ship',
#  'Free diving with seals',
#  'Treading water while alongside capsized yacht',
#  'The 240-ton motor vessel Pilar II with 100 people on board capsized in high winds & rough seas',
#  'Fishing with dynamite',
#  'Air/Sea Disaster',
#  'Free diving  & spearfishing (submerged)',
#  'Swimming, towing a kayak',
#  'Dragging stranded shark into deeper water',
#  "12 of the Penang's crew were returning to the ship when their 12' dinghy capsized",
#  'Photographing sharks underwater using Scuba',
#  'Fishing for tunny',
#  'Boogie-boarding / swimming',
#  'ship M.V. Rizal sank during typhoon',
#  'Paddle Skiing',
#  'Floating on an inflatable raft',
#  'Adrift after the sinking of the motor yacht Princess Dianne',
#  'Crossing river on a raft',
#  'Swimming from makeshift raft  to life vest after fishing boat sank',
#  'Standing in chest-deep water',
#  'Fishing  (trawling)',
#  'Dress diving',
#  'Board sailing',
#  'Measuring sharks',
#  'Fleet of canoes caught by a squall and charged by sharks.',
#  'Watching seals',
#  'Diving, gathering shellfish',
#  "Skin diving. Grabbed shark's tail; shark turned & grabbed diver's ankle & began towing him to deep water",
#  'Fishing boat swamped in storm',
#  'Cleaning fish',
#  'Fishing (trolling)',
#  'Attempting to rescue an injured & beached shark',
#  'Spearfishing, carrying fish on belt',
#  'Washing cooking pans',
#  'Helmet diving in Miami Seaquarium',
#  'Playing on a sandbar',
#  '14 m prawn trawler New Venture capsized  & sank in heavy seas Three people in the water',
#  'Free diving, collecting shells',
#  'Free diving & spearfishing (descending)',
#  'Scuba diving (submerged riding a scooter)',
#  'Rowing toward snapper grounds',
#  'Copra vessel with 19 on board was wrecked in a squall',
#  'Fishing, hauling in a set line',
#  'Conch diver',
#  "Zosimo & his son, Jeffrey Popa, failed to return from overnight fishing trip in a 14' boat, Boat apparently sank, debris recovered but his son & boat were never found",
#  'Fishing for albacore',
#  'Bathing or body surfing ',
#  'Swimming outside the safety enclosure attempting to retrieve a tennis ball drifting toward midstream ',
#  'Bringing hooked, harpooned shark onboard boat',
#  'Washed into sea while picking opihi & attacked by 2 large sharks ',
#  'Scallop diving (using surface-supplied air & a POD) ',
#  'SS Ethel Skakel foundered in Central America Hurricane of 1941',
#  'Adrift on life raft',
#  'Jumped off rocks into white water',
#  'Attempting to free the shark',
#  "Fishing, stepped on hooked shark's head",
#  'On December 28, 1908, an earthquake, followed by tsunamis, destroyed coastal towns in Silcily and southern Italy, killing more than 100,000 people',
#  'Ditched plane in the sea & were adrift on a rubber life raft. ',
#  'The passenger ship Kapuna was run down the ore carrier Ada Melmore',
#  'Floating, holding onto an oar after dory capsized',
#  'Scooping prawns',
#  'U.S. Airforce crewman reported missing after bailing out of jet',
#  'Fishing / cleaning fish, dived into water to retrieve a lost fish',
#  'Swimming back from anchored sailboat',
#  'Swimming, towing the shark',
#  'SUP',
#  'Thrown into water from fishing dinghy',
#  'Attempting to drive shark away from the beach',
#  'Hookah Diving',
#  "Fell from his father's back into the water",
#  'boat from City of Naples capsized',
#  'British ship Macedon was thrown on her beam ends by a sudden squall',
#  'Fishing, lifting shark out of craypot',
#  'Walking, carrying surfboard & stepped on shark',
#  'Wakeboarding',
#  'Competing in spearfishing championship & towing dead fish',
#  'Fishing, standing in water next to purse net',
#  'Skin diving ',
#  'Swimming to canoe',
#  'Swimming / treading water',
#  'Dived into sea from launch & bitten immediately',
#  'Washing clothes',
#  'Surf paddling',
#  'On a float',
#  'Diving / Filming',
#  'Fishing for blue sharks',
#  "Diving in Sharkey's Reef restaurant�s aquarium",
#  'ship William Penn grounded & broke apart',
#  'Scuba diving, but swimming on surface',
#  'Jumped overboard after murdering 2 shipmates',
#  'Adrift on refugee raft',
#  'Swimming ashore from swamped 13-ft boat',
#  'Floating on a small orange raft ',
#  'Swimming after a tennis ball',
#  'Spearfishing on scuba & transferring fish onto a stringer',
#  'Netting sharks',
#  'On a "shark hunt"',
#  'Swimming from fishing boat setting nets',
#  'Bitten while cutting shark from net',
#  'Floating in creek',
#  'Freediving for trochus shell (submerged)',
#  'Fishing for sharks when he became entangled in net & fell overboard',
#  'Bitten after dhow shipwrecked',
#  'Racing ski',
#  'Longline fishing',
#  'Swimming between  anchored  pearling luggers',
#  'Two canoes with 14 aboard blown to sea in a storm. While adrift for 3 week, one person fell overboard and was killed by a shark',
#  "Bathing in 5' of water",
#  'Fell off banana boat',
#  'Shipwrecked',
#  'Fisherman',
#  'Removing shark from net',
#  'Washed off freighter Huncliff by a freak wave',
#  'Swimming with dolphins',
#  'Crawling',
#  'Cleaning hull of ship ',
#  'Hunting sharks',
#  "Fell off surfboard 20' from shore",
#  'Swimming from capsized pirogue',
#  'Standing on sandbank',
#  'Collecting dynamited fish',
#  'Tzenny Chandris, a Greek freighter laden with scrap iron, foundered in heavy weather',
#  'Treading water, waiting for a wave',
#  'Boogie boarding / wading',
#  'Fishing for red fish',
#  'Sinking of the ferryboat Bongbong 1',
#  'Surfing (or body boarding)',
#  'Swimming / Body surfing',
#  'Accidentally dragged overboard from the sampan Holokahana into school of yellowfin tuna',
#  'Swimming, wearing black wetsuit & swim fins',
#  'Jumped overboard from Norwegian steamship Venator',
#  'Hard hat diving, laying some charge of powder',
#  'Swimming with boogie board',
#  'Filming underwater, carrying powerhead',
#  'HBM Magpie foundered in a squall',
#  'Schooner sank during a storm',
#  'Swimming /  Whale Watching',
#  'Washing horses',
#  'Hookah diving for abalone (descending)',
#  'Swimming from capsized boat',
#  'Plane forced down, 3 men on rubber life raft. Put hand over side to feel drift of boat ',
#  'Diving off pier & treading water',
#  'Wading, netting fish',
#  'Swimming with mask & snorkel',
#  'The 21,516-ton troopship Empress of Canada torpedoed and sunk by the Italian submarine Leonardo da Vinci',
#  'Spearfishing, Scuba diving',
#  'Diving from dinghy for trochus shell',
#  'Fly fishing',
#  '13 men in the water after sailboat capsized & sank',
#  'Boat Miss Becky  sank 12 miles from shore',
#  'Sea Disaster Sinking of ferryboat Christina',
#  'Surfing on air mattress',
#  'Dived onto shark from floating stage',
#  'Boat capsized, clinging to line',
#  "Sitting in bow of her father's 5 m boat",
#  'Motor boat Rebel Belle lost',
#  'Fell overboard  from the Taiwanese fishing trawler Lien Cheng Feu ',
#  'Fishing from shore',
#  'Diving for sand dollars',
#  'Diving for trepang',
#  'Small boat swamped, 4  people swimming to shore but he fell behind the other 3 and vanished',
#  'Swimming around anchored ship',
#  'On life raft tethered to lifeboat. A seaman put hand over side to rinse a cup',
#  'Spearfishing, dived to pick up a float line',
#  'Attempting to set underwater endurance record',
#  'Jumping in the waves',
#  'Fell overboard from US Navy PC boat',
#  "Lying prone in 2' of water",
#  'Swimming / floating',
#  'Free diving / spearfishing, ',
#  'In water with diving seabirds',
#  'Free diving or wading back to shore',
#  'Hookah diving',
#  'Dragging a shark',
#  'Lying on surfboard',
#  'Swimming near life raft',
#  'Flying Fortress bomber aircraft went down after daytime raid on Naples. He was swimming on the surface',
#  'Hookah diving for pen shells ',
#  'The steamer Tahiti collided with the ferry Greycliffe',
#  'cargo ship Southern Isle sank at 04h00',
#  'Net fishing, picking catch from the net',
#  'Fell overboard from the Malacca',
#  'Paddling rescue ski',
#  'Petting captive sharks',
#  'Swimming with board',
#  'Spearfishing (but on surface)',
#  'Hurricane & Tidal Wave',
#  'Diving in tuna net',
#  'Investigating shark sighting',
#  'Washed overboard from the barque Mary Eady',
#  'Walking on reef',
#  'Swimming / Body Surfing',
#  "63' fishing boat Sno' Bay foundered",
#  'Water-skiing',
#  'Wading in school of baitfish',
#  'Free diving Spearfishing',
#  'Aircraft exploded',
#  'Diving on a wreck',
#  'Canoe capsized with 10 occupants, 8 survived,  Hamilton swam off to seek help',
#  'Ferry boat sank',
#  'Spearfishing & holding catch',
#  'Canoe swamped, swimming back to canoe',
#  'Abandoning burning ship Captain George in raging seas',
#  'Gathering fish stunned by dynamite',
#  'Scuba diving for bivalves',
#  'Wading, knocked down & swept away by large waves',
#  "Bathing in 3' to 4' of water",
#  'Swimming after falling overboard from the sealing ship Vesper',
#  'Known as The Battle of the Bismarck Sea :  8 Japanese destroyers guarding a convoy of 8 transports were attacked by 129 Allied fighters, 207 bombers & 3 squadrons of the Royal Australian Air Force. ',
#  'Put foot inside mouth of supposedly dead shark',
#  'Swimming near anchored ship',
#  'Fishing / diving',
#  'Fishing, thrown into water by heavy sea, clinging to rocks at the water line',
#  'Swimming from camp',
#  'Swimming to shore from boat or kayak',
#  'Attaching a line at sea',
#  'Diving for sea urchins',
#  'Pleasure boating',
#  'Fell from the jetty',
#  'Fishing for trout ',
#  'S.S. Ramos foundered in a hurricane. Captain & 14 crew in water-logged lifeboats. ',
#  'Free diving for sponges',
#  'Standing / Wading',
#  'Put foot inside a landed & supposedly dead shark',
#  'Swimming from naptha launch after a day of fishing',
#  'Sea disaster, foundering of the cargo vessle M/V Dorolonda',
#  'Bodyboarding',
#  'Standing / Snorkeling',
#  'Feeling the shark�s teeth',
#  'Boat exploded',
#  'Casting a net',
#  "Diving for trochus  from dinghy when seized by shark 6' below the surface",
#  'Canoe swamped',
#  'Jumped overboard to rescue companion',
#  'Paddling on kneeboard',
#  'Bathing in waist-deep water',
#  'Fishing from launch, fell into net with shark',
#  'Fishing boat with 4 men on board was rammed & capsized by  a shark, throwing all occupants into the water',
#  'Diving from the lugger San, operated by the Protector of the Aborigines',
#  'Angling',
#  'Surf bathing',
#  'Fell off surf ski',
#  'Hunting lobsters in 2.4 m of water',
#  'Touching sharks',
#  '90 European civilians, many women & children, were placed on the deck of a Japanese submarine that submerged when it was well offshore',
#  'Grabbed shark & threw it on deck',
#  'Snorkeling, possibly holding a fish',
#  'Swimming underwater from crayfish cage to a fishing bait',
#  'Shipwrecked pearling schooner',
#  'Yacht race',
#  'Dragging banana seeds through the shallows',
#  'Lashing logs together when he fell into the water',
#  'Fishing (trolling)  from canoe',
#  '   ',
#  'canoeing',
#  'Swimming with motor tube',
#  'Spearfishing (but treading water on the surface)',
#  'Standing on sandbar',
#  'Washed off catamaran in the surf',
#  'The Pacquebot Laconia, enroute to Liverpool with 600 Italian prisoners onboard, was torpedoed by the German submarine  U-156 and only 2 rafts were launched before the ship went down. Unable to board an overcrowded raft, he was swimming.',
#  'Harpooning turtles',
#  'The passenger ship Pioneer Cebu  capsized & sank in Typhoon Irma',
#  'Pulling raft out to ride to shore',
#  'Working prawn net',
#  'Wading & pushing dinghy toward  the shallows',
#  'Portuguese Airliner with 9 people aboard went down. ',
#  'Standing, watching seine netters',
#  'Surfing on "chest board" (boogie board?)',
#  'Riding floatation device',
#  'Hand feeding sharks',
#  "Sitting in 3' of water",
#  'Fishing, holding fish in his left hand',
#  'The inter-island ferry Vula sank in heavy weather',
#  "Diving to untangle a crab trap line from boat's propeller",
#  'Landing hooked shark in boat',
#  'The USS Wahoo torpedoes & sank the Japanese troop transport Buyo Maru',
#  'Swept off deck of S.S.Frontenac enroute from West Indies to US',
#  '"Riding waves on a board"',
#  'Swimming near shore',
#  'Fishing, when line became snagged on rock & he dived into water to free it ',
#  'Swimming / jumping off a jetty',
#  'Attempting to rescue woman seized by shark',
#  'Coming ashore on a hawser',
#  'Attempting to anesthetize shark',
#  'Playing on rock, slipped & fell into the water',
#  'Diving / fishing',
#  ...]

# %%
# Rename sex column

df = df.rename(columns={"Sex ": "Sex"})

# %%
# make Sex column to only M and F
df.loc[df["Sex"] == "M ", ["Sex"]] = "M"
df.loc[df["Sex"] == ".", ["Sex"]] = ""
df.loc[df["Sex"] == "lli", ["Sex"]] = ""
df.loc[df["Sex"] == "N", ["Sex"]] = ""
df.loc[df["Sex"] == "", ["Sex"]] = np.nan

# %%
# Make sex column binary

df["Sex"] = df["Sex"].str.replace("M","1").str.replace("F","0")

df = df.rename(columns={"Sex": "Sex_Male"})

# %%
# Check injury column

list(df["Injury"].value_counts().index)
# Out:
# ['FATAL',
#  'Survived',
#  'Foot bitten',
#  'No injury',
#  'Leg bitten',
#  'Left foot bitten',
#  'No details',
#  'Right foot bitten',
#  'Hand bitten',
#  'Thigh bitten',
#  'No injury, board bitten',
#  'FATAL, body not recovered',
#  'Minor injury',
#  'Foot lacerated',
#  'Calf bitten',
#  'Right leg bitten',
#  'Arm bitten',
#  'Lacerations to foot',
#  'Ankle bitten',
#  'Right calf bitten',
#  'Lacerations to right foot',
#  'Lacerations to left foot',
#  'No injury to occupants',
#  'Heel bitten',
#  'Left leg bitten',
#  'No injury, surfboard bitten',
#  'Left arm bitten',
#  'Foot severed',
#  'Right thigh bitten',
#  'Leg lacerated',
#  'Leg severed',
#  'Minor injuries',
#  'Left calf bitten',
#  'FATAL, leg severed ',
#  'Leg injured',
#  'Thigh lacerated',
#  'Legs bitten',
#  'Lacerations to right leg',
#  'Lacerations to leg',
#  'Probable drowning & scavenging',
#  'Left foot lacerated',
#  'Lacerations to lower leg',
#  'Lacerations to right hand',
#  'Laceration to left foot',
#  'Left hand bitten',
#  'Right foot lacerated',
#  'Puncture wounds to foot',
#  'Knee bitten',
#  'Lacerations to hand',
#  'No injury, kayak bitten',
#  'Lacerations to left calf',
#  'Arm severed',
#  'Arm lacerated',
#  'Hand lacerated',
#  'Laceration to leg',
#  'Lacerations to left leg',
#  'No injury, ski bitten',
#  'Forearm bitten',
#  'Leg bitten, surgically amputated',
#  'No injury, shark bit surfboard',
#  'FATAL, legs bitten ',
#  'Left arm lacerated',
#  'Lacerations to fingers',
#  'Lacerations to arm',
#  'Lacerations to thigh',
#  'FATAL ',
#  'Torso bitten',
#  'Left thigh lacerated',
#  'Lacerations to left forearm',
#  'FATAL, thigh bitten ',
#  'Lacerations',
#  'Right hand lacerated',
#  'Swim fin bitten',
#  'Right calf lacerated',
#  'Hand severed',
#  'Laceration to right foot',
#  'Shoulder bitten',
#  'FATAL x 2',
#  'Puncture wounds to right foot',
#  'Foot & ankle lacerated',
#  'Right foot & ankle lacerated',
#  'Leg severely bitten, surgically amputated',
#  'Calf lacerated',
#  'Lacerations to left hand',
#  'Elbow bitten',
#  'No injury, board damaged',
#  'Finger bitten by hooked shark PROVOKED INCIDENT',
#  'Hip bitten',
#  'Right hand bitten',
#  'Right leg lacerated',
#  'Shark involvement prior to death unconfirmed',
#  'Minor injury to leg',
#  'Laceration to left thigh',
#  'No injury, swim fin bitten',
#  'Laceration to thigh',
#  'Laceration to left hand',
#  'Lower leg bitten',
#  'Buttocks bitten',
#  'PROVOKED INCIDENT',
#  'Right arm bitten',
#  'Recovered',
#  'Right hand severed',
#  'Hand injured',
#  'Right thigh lacerated',
#  'Thigh & calf bitten',
#  'Probable drowning / scavenging',
#  'Left thigh bitten',
#  'Left calf lacerated',
#  'Lower right leg lacerated',
#  'Laceration to calf',
#  'FATAL, body was not recovered',
#  'Left ankle bitten',
#  'Probable drowning with post-mortem bites',
#  'Shark involvement prior to death was not confirmed',
#  'Laceration to right lower leg',
#  'Torso lacerated',
#  'Lacerations to calf',
#  'Minor injury to left foot',
#  'Death may have been due to drowning',
#  'No injury, board bumped by shark',
#  'No injury to occupants, shark bit boat',
#  'Laceration to right leg',
#  'Lacerations to lower left leg',
#  'Right hand bitten by hooked shark PROVOKED INCIDENT',
#  'Lacerations to right calf',
#  'Buttock bitten',
#  'No Injury',
#  'FATAL, torso bitten ',
#  'Laceration to foot',
#  'No Injury, board bitten',
#  'Left leg lacerated',
#  'Puncture wounds to right thigh',
#  'Left forearm bitten',
#  'Lower leg lacerated',
#  'Lacerations to head',
#  'No injury, shark bit board',
#  'Foot injured',
#  'Human remains found in shark',
#  'Leg bitten ',
#  'Minor lacerations to foot',
#  'Big toe bitten',
#  'Presumed FATAL, body not recovered',
#  'FATAL, but shark involvement prior to death unconfirmed',
#  'Shin lacerated',
#  'Minor injuries to foot',
#  'Ankle & foot lacerated',
#  'No injury, knocked off board',
#  'FATAL, right thigh bitten ',
#  'FATAL, left leg severed',
#  'Minor injuries to hand',
#  'Abdomen bitten',
#  'Minor injury to calf ',
#  'Shark involvement not confirmed',
#  'Ankle lacerated',
#  'Thigh bitten, FATAL',
#  'Non-fatal',
#  'Presumed FATAL',
#  'No injury to occupant',
#  'Ankle & foot bitten',
#  'Arm bitten by hooked shark PROVOKED INCIDENT',
#  'Right ankle & foot bitten',
#  'Puncture wounds on right foot',
#  'Severe laceration to foot',
#  'Leg bitten by hooked shark PROVOKED INCIDENT',
#  'No injury, shark bit kayak',
#  'Left forearm bitten PROVOKED INCIDENT',
#  'Laceration to left leg',
#  'Knee & calf lacerated',
#  'Lower left leg bitten, surgically amputated',
#  'Arm bitten by captive shark PROVOKED INCIDENT',
#  'Lacerations to legs',
#  'Lower left leg & foot bitten',
#  'Missing, believed taken by a shark',
#  'Left ankle & foot bitten',
#  'No injury, rammed by shark',
#  'Right forearm lacerated',
#  'No Injury to occupants',
#  'Abrasions',
#  'Abrasion',
#  'Heel lacerated',
#  'Minor injury to ankle',
#  'Shark bites were post-mortem',
#  'No injury to occupants, shark bit propeller',
#  'Left leg severely bitten',
#  'Lacerations to right forearm',
#  'Right ankle bitten',
#  'Lacerations to knee',
#  'FATAL, "bitten in two"',
#  'FATAL, leg bitten ',
#  'Leg bitten by netted shark PROVOKED INCIDENT',
#  'FATAL, multiple bites ',
#  'Knee lacerated',
#  'Chest lacerated',
#  'FATAL, but shark involvement prior to death was not determined',
#  'Minor injury to foot',
#  'Leg severed at knee',
#  'Left foot severed',
#  '2 toes bitten off ',
#  'No injury to occupants, boat damaged',
#  'Right knee lacerated',
#  'Foot bitten by landed shark PROVOKED INCIDENT',
#  'Upper left arm bitten',
#  'Minor laceration to hand',
#  'No injury to occupants, shark rammed boat',
#  'FATAL?',
#  'Small lacerations on right lower leg',
#  'Hand injured PROVOKED INCIDENT',
#  'Lacerations to thigh & buttocks',
#  '2-inch laceration to upper left arm',
#  'Arm bitten, surgically amputated',
#  'No injury, paddleboard bitten',
#  'Lacerations to buttocks & thigh',
#  'Thought to have been taken by a shark',
#  'No injury. Hull bitten, tooth fragment recovered',
#  'Shin bitten',
#  'Lacerations to forearm',
#  'Right leg severed',
#  'Right leg severely bitten',
#  'Thigh gashed',
#  'Lacerations to left lower leg',
#  'Multiple lacerations',
#  'No inury to occupants, shark struck boat',
#  'Laceration to toe',
#  'Toe bitten',
#  'Lacerations to lower leg & ankle',
#  'Buttock & leg bitten',
#  'No injury, shark made a threat display',
#  'No injury, bumped off board by the shark',
#  'FATAL, some were taken by sharks',
#  'Laceration to right heel',
#  'Right arm severely bitten',
#  'Left shoulder bitten',
#  'Thought to have been taken by a shark. Body was not recovered',
#  'Puncture wounds to left foot',
#  'Lower legs bitten',
#  'Hands severed',
#  'FATAL, leg severed',
#  'Puncture wounds to right calf',
#  'FATAL, leg severely bitten',
#  'Recorded as PROVOKED INCIDENT',
#  'FATAL PROVOKED INCIDENT',
#  'Arm severely lacerated',
#  'Severe injury to arm',
#  'Lower leg & foot bitten',
#  'Missing, thought to have been taken by a shark',
#  'Lower right leg bitten',
#  'Severe lacerations to left foot',
#  'Left forearm lacerated',
#  'Posterior thigh bitten',
#  'Foot nipped',
#  'FATAL, thigh bitten',
#  'Hand bitten ',
#  'Laceration to arm',
#  'Leg severely bitten',
#  'Severe lacerations to arm',
#  'Right ankle & foot lacerated',
#  'Hooked shark bit boat PROVOKED INCIDENT',
#  'Buttocks & hip bitten',
#  'Bitten by harpooned shark PROVOKED INCIDENT',
#  'Arm injured',
#  'FATAL,  beaten & thrown overboard by smugglers, they  were killed by sharks',
#  'No injury, surfboard leash severed',
#  'Finger severed',
#  'Left hand severed',
#  'Laceration to leg by hooked shark  PROVOKED INCIDENT',
#  'Death resulted fom drowning; shark bites were post-mortem',
#  'Left calf injured',
#  'FATAL, legs severed  ',
#  'No injury, shark bumped surfboard',
#  'Lacerations to right arm',
#  'Shark leapt onto surfboard; surfer uninjured ',
#  'Laceration to forearm',
#  'Toe severed',
#  'Left knee lacerated',
#  'Thigh & foot bitten',
#  'Left foot & ankle lacerated',
#  'Left arm severed',
#  'Fatal or drowning or scavenging',
#  'Calf & foot lacerated',
#  'No injury to occupant, shark bit boat',
#  'Probable drowning ',
#  'Leg severed below knee',
#  'Lacerations to  foot',
#  'Foot & ankle bitten',
#  'FATAL  ',
#  'Lacerations to left ankle',
#  'Laceration to back',
#  'Shark involvement prior to death not confirmed',
#  'Leg abraded',
#  'Head bitten',
#  'Right leg severed, left leg lacerated',
#  'Leg severed, but survived',
#  'Lacerations to hip and leg',
#  'Leg & foot bitten',
#  'FATAL, leg severed  ',
#  'No injury to occupant, shark/s holded  kayak',
#  'Left thigh severely bitten',
#  'Left foot bitten ',
#  "Shark's tail broke his leg. PROVOKED INCIDENT",
#  'FATAL, PROVOKED INCIDENT',
#  'Punctures on left thigh',
#  'Arm bitten PROVOKED INCIDENT',
#  'Left elbow bitten',
#  'Minor injury to thigh',
#  'Back bitten',
#  'Shark bites post mortem',
#  'No injury, no attack',
#  'Arm bitten PROVOKED INCIDENT ',
#  'FATAL, leg bitten',
#  'No injury, board bumped',
#  'Thigh severely lacerated',
#  'Wrist bitten',
#  'No injury, ski bumped',
#  'Laceration to left ankle',
#  'Forearms lacerated',
#  'Laceration to ankle',
#  'Lacerations to left arm',
#  'Laceration to right hand',
#  'Probable drowning',
#  'Right forearm bitten',
#  'FATAL, but shark involvement uncomfirmed. Death may have been due to drowning.',
#  'Left foot & ankle bitten',
#  'No injury, kayak damaged',
#  'Fatal, but death may have been due to drowning',
#  'Laceration to right ankle',
#  'No injury, shark damaged surfboard',
#  'Cuts on right foot',
#  'Right foot & ankle bitten',
#  'Right thigh punctured',
#  'FATAL, hand severed, both legs & arms bitten & nearly severed ',
#  'Upper right thigh bitten',
#  'Lacerations to right thigh',
#  'Leg & surfboard bitten',
#  'No injury ',
#  'Disappeared, but shark involvement unconfirmed',
#  'Right ankle lacerated',
#  'Arm severely lacerated, surgically amputated',
#  'bite to lower leg',
#  'Lacerations to arm & leg',
#  'FATAL, right buttock & thigh bitten ',
#  'Minor lacerations to right foot',
#  'Right foot severed',
#  'Minor injury to left lower leg & heel',
#  'Left foot lacerated ',
#  'Top of left foot bitten',
#  'Ankle injured',
#  'Laceration to right arm',
#  'Lacerations to face and neck',
#  'Laceration to heel',
#  'Shark bumped boat, no injury to occupants',
#  'FATAL, multiple injuries to both legs  ',
#  'Calf nipped in each case',
#  'Minor injury to torso',
#  'Right thigh bitten ',
#  'Drowned, body scavenged by shark',
#  'Lacerations to right foot and ankle',
#  'No injury, surfboard dented',
#  'No injury, shark rammed surfboard',
#  'Left forearm bitten ',
#  'FATAL, but shark involvement prior to death was not confirmed',
#  'Lacerations to right thigh and knee',
#  'Lacerations to right arm & thigh',
#  'Right leg severely lacerated',
#  'Lacerations to buttocks',
#  'No injury to occupant, shark rammed boat',
#  'No injury, knocked off surfboard',
#  'Lacerations to calf by hooked shark PROVOKED INCIDENT',
#  'Left foot & leg bitten',
#  'Toes lacerated',
#  'Forearm bitten by hooked shark PROVOKED INCIDENT',
#  'Minor bite to ankle',
#  'Leg & arm bitten',
#  'Shark bites may have been post mortem',
#  'Possible drowning victim, remains retrieved from shark caught by fishermen on 28-Apr-1976',
#  "No injury to occupant, hooked shark bit boat's rudder PROVOKED INCIDENT",
#  'Forearm, abdomen & upper leg lacerated',
#  'Recovered at Thursday Island Hospital',
#  'Left inner thigh',
#  'Left thigh bitten, chest lacerated  & defense wounds on foot, fingers and hands',
#  'Lower porton of body recovered 3 days later. Note: rare sighting of shark made at same beach on 11-5-1989 ',
#  'FATAL, arm severed, leg bitten',
#  'FATAL, left thigh, buttocks, back of spine, abdomen & chest bitten  ',
#  'FATAL, thigh lacerated, femur exposed ',
#  'FATAL, abdomen severely bitten. Airplane summoned from Corregidor & injured man was lashed to wing, but he died  ',
#  'Hands bitten',
#  'FATAL      Torso bitten',
#  'Knee bitten by boated shark PROVOKED INCIDENT',
#  'Right leg injured by hook and hooked shark PROVOKED INCIDENT',
#  'Abrasions to left leg',
#  'FATAL & some of the survivors were bitten by sharks  ',
#  'Leg bitten, FATAL',
#  'Minor injury to head',
#  'Lacerations to thighs',
#  'Groin bitten',
#  'Multiple injuries, left leg surgically amputated at knee',
#  'Navy personnel recovered 19 shark-scavenged bodies',
#  "White shark, 3.7 m [12']  made threat display. No injury, no attack",
#  'Minor injury; puncture wounds to calf',
#  'Lacerations and puncture wounds to leg and foot',
#  'FATAL, leg bitten from thigh to ankle',
#  'No injury, shark pushed canoe from jetty to a point 100 m away',
#  'Minor puncture wounds to foot',
#  'Abdomen bitten & leg severed  FATAL',
#  'FATAL, hip & thigh bitten with  tissue removed, including bone ',
#  'Right sole & toes lacerated',
#  "Possible drowning & scavenging. Remains were recovered from a 15' shark's gut",
#  'Left leg bitten, surgically amputated below the knee',
#  'No injury to occupants, hydrofoil of outboard motor bitten ',
#  'Disappeared, body recovered with large bite on thigh',
#  'Righ thigh severely bitten',
#  'FATAL, gave sudden shriek & disappeared, body found in shark caught off Kahuka',
#  'Right foot & heel lacerated',
#  'Bodies of 5 of the 6 men on board were bitten by by sharks. Sharks may have contributed to the death of some of them.',
#  'Cause of death was drowning & preceded shark involvement',
#  'Left leg & foot bitten  by shark brought onboard. PROVOKED INCIDENT',
#  'FATAL, abdomen & thigh bitten',
#  'Thigh  severely bitten',
#  'Face & thorax bitten',
#  'Lassoed shark bit his hand PROVOKED INCIDENT',
#  'Right arm severed, right leg bitten, not known if he survived',
#  'Right shoulder blade  & back lacerated',
#  'Shark and boat collided. No injury to occupants',
#  'No injury, swim fin damaged',
#  'Lower left leg amputated',
#  'Minor cut on finger',
#  "Legs nipped & he bit shark's snout",
#  "Lombard's thigh was lacerated by shark that leapt into boat ",
#  'Jumped off cliff',
#  'Right thigh & ankle injured',
#  'Injuries to chest',
#  'Tip of finger amputated PROVOKED INCIDENT',
#  'Abrasion to forearm',
#  'Lacerations knee to ankle',
#  'Puncture wounds & 3-inch laceration to right calf',
#  'FATAL, left arm severed above elbow, lacerations on chest, right thumb severed, left thigh lacerated to bone, abrasions  ',
#  'Tissue of right thigh removed to the bone, both thumbs & some fingers severed ',
#  'Calf bitten & both hands injured',
#  'Abrasions and lacerations to lower right leg',
#  'Shark rammed boat PROVOKED INCIDENT',
#  'Lacerations to right hand PROVOKED INCIDENT',
#  'Hooked shark bit his leg, knee to ankle PROVOKED INCIDENT',
#  'Arm severely injured, surgically amputated',
#  'FATAL, arm bitten ',
#  'Foot severely injured',
#  'Left forearm bitten, surgically amputated',
#  "Forearm  & hand bitten; tooth fragments of the shark were recovered from the surfer's hand",
#  "No injury, surfboard 'attacked'",
#  'FATAL, Drowned or crushed when harpooned shark smashed their boat PROVOKED INCIDENT',
#  'No injury, tank scratched by shark',
#  'Leg bitten, but survived',
#  'Left knee, calf & heel bitten by shark trapped in the net PROVOKED INCIDENT',
#  'Laceration & puncture wounds to foot',
#  'No injury, no attack; sharks ate their food tied to a line over the side of the raft',
#  'Lacerations to little finger of left hand',
#  'Foot & swimfin bitten',
#  'Torso bruised & abraded ',
#  'Minor injury to arm. Possibly caused by smalll nurse shark',
#  'FATAL, groin bitten ',
#  'Lacerations to thigh & torso',
#  'No injury to occupants, boat scratched by shark',
#  'Possible drowning / scavenging',
#  'FATAL, calf bitten twice',
#  ' "Struck across loins" but no injury. According to witnesses, incident involved a bottlenose dolphin.',
#  'Found at 21h30 by searchlight. Had been constantly harassed by sharks & had numerous lacerations',
#  '4 punctures in left foot',
#  'Of the 1346 on board, 392 perished including 90 women & 44 crew. 1 person known to have been fatally injured by a shark.',
#  'Lacerations to hand, knee & thigh ',
#  'FATAL, leg & buttocks removed ',
#  "No injury, shark became tangled in hose & towed him 100'",
#  'Calf / knee injured?',
#  'Injuries to arm and shoulder',
#  'Lacerations to right torso & ankle',
#  'Finger or toe severed',
#  'Lacerations to lower left leg, puncture wounds to sole of left foot',
#  'Hip bumped by shark, no Injury',
#  'Abrasions to shins',
#  'Small puncture wounds to the heel of left foot',
#  'PROVOKED INCIDENT?  ',
#  'No attack,  no injury',
#  '2-inch cut on dorsum of left foot',
#  'Leg bitten by shark taken aboard Japanese trawler PROVOKED INCIDENT',
#  'FATAL, left arm & left buttock severed ',
#  'Abrasions to arm',
#  'No injury, no attack, shark made threat displays',
#  'No injury to occupant, canoe struck several times by shark ',
#  'Survived. questionable incident',
#  'One man was lost, but he may have drowned',
#  'Left heel lacerated',
#  'Minor laceration to leg',
#  'Lacerations to left ankle and foot',
#  'Minor laceration on left leg',
#  'Ankle lacerated, lower left leg severely abraded ',
#  'Minor lacerations on right ankle & foot',
#  'Hooked shark gashed right leg      PROVOKED INCIDENT',
#  'Thigh injured',
#  'Severe bite to right leg FATAL',
#  'Minor bite on foot & swimfin',
#  '"Light scratch on hand/wrist area"',
#  'Shoes & human remains found in a shark',
#  'Coroner determined the man was killed by a boat propeller, not a tiger shark',
#  'Leg severed at mid-thigh',
#  'No injury, knocked off ski',
#  'Hand nipped PROVOKED INCIDENT',
#  'Head bitten by captive shark PROVOKED INCIDENT',
#  '8 shark-bitten bodies washed ashore',
#  'Right shoulder, arm & hand bitten',
#  'Quadriceps lacerated, femur exposed',
#  'Minor injury to arm and hand',
#  'Shark bumped dinghy twice',
#  'Puncture wounds to left foot & calf',
#  "4 finger severed by 'dead' shark. PROVOKED ACCIDENT",
#  'FATAL, arm severed, thigh severely bitten  ',
#  'Lacerations to thigh by netted shark PROVOKED INCIDENT',
#  'FATAL, leg severed, other leg lacerated ',
#  'Left forearm grazed & puncture marks in wetsuit',
#  'Both hands & heel of left foot lacerated, right foot severed',
#  'PROVOKED INCIDENT Hooked shark pulled onboard bit his arm  ',
#  'FATAL, right thigh severely bitten, left arm lacerated ',
#  'No injury, shark bit rear of paddleboard',
#  'remains of one of the crew found in shark',
#  'No injury, board bumped & fin damaged',
#  'Left arm amputated at elbow & severe injury to leg',
#  'Lacerations to  arm',
#  'Details unknown, possibly a PROVOKED INCIDENT',
#  ' FATAL. Shark bite was minor injury, but he suffered a heart attack afterwards and died 6 hours later',
#  'Leg severed mid-thigh, hand severed, arm above elbow and part of buttocks. Not known if he survived',
#  'Arms & legs severed',
#  'FATAL, but shark involvement not confirmed',
#  'No injury to occupants; oar & rudder bitten',
#  'Body not recovered. 3 days later some of his equipment was found on seabed appeared damaged by a shark ',
#  'No injury, shark slammed into boat',
#  'Disappeared whiile swimming alone, body parts recovered, but shark involvement prior to death unconfirmed',
#  'Severe injuries to head, neck, shoulder & upper left arm',
#  'Tiny cuts & bruises on neck  ',
#  '4 irregular lacerated wounds on right arm',
#  'Left leg severely lacerated, superficial lacerations of right leg,  board damaged',
#  'Right lower leg bitten & defense wounds to hand',
#  'Calf lacerated. He was rescued by German submarine, which sunk. Rescued by Italian submarine, which sunk. Managed to reach Dakar',
#  'Bruises & minor cuts',
#  'FATAL, left thigh & knee bitten ',
#  'Lacerations to arms',
#  'No injury to occupants, toothmarks on bottom & side of dinghy',
#  'Hand lacerated by speared shark PROVOKED INCIDENT',
#  'Lacerations and puncture wounds to right foot',
#  'Minor injury to right hand & thigh',
#  'Right Leg bitten',
#  'Laceration to left thigh & left hand',
#  'Fingers lacerated',
#  'Lacerations to lower leg & foot',
#  'Minor injury to hand by hooked shark   PROVOKED INCIDENT',
#  'Hooked shark bit stern  PROVOKED INCIDENT',
#  'No injury to occupants, shark shook boat "stem to stern"',
#  '3 fingers severed when he used his hand as bait',
#  'Body recovered  from shark but death due to shark bite was not confirmed',
#  "Speared shark bit Davy's ankle &  Pierpont's right leg  PROVOKED INCIDENT",
#  'Minor cuts to foot',
#  'Lacerations to 3 fingers of left hand ',
#  'No injury to occupants, hooked shark, snapped at rudder & then attacked boat PROVOKED INCIDENT',
#  'Shark caught 9 days later contained human remains thought to be those of Canham',
#  'No injury to occupants, shark struck boat',
#  "FATAL               Of 38 people in the water, 8 were killed by sharks & 1 man's leg was severed",
#  'FATAL, arm & leg severed ',
#  'No injury, kayak capsized',
#  'Minor lacerations to right shoulder',
#  'Lacerations to back',
#  'Puncture wounds to dorsum of right foot',
#  'FATAL, pulled off float by shark, body not recovered ',
#  'Deep lacerations to calf & ankle',
#  'Lower leg nipped, arm bruised when he landed in boat',
#  '5 people killed by sharks, 30 others injured',
#  'Shoulder, back & leg bitten',
#  'Dorsum of right hand bitten',
#  'Badly bitten by a shark dragged onboard PROVOKED INCIDENT',
#  'Puncture wounds on  right thigh',
#  'No injury to occupants; shark rammed boat 4 times, bit engine & cracked the hull',
#  'Injury to hip/leg',
#  'Injuries to left thigh',
#  'Death due to drowning. Shark bite may have been postmortem',
#  'Knee bitten after diver poked shark PROVOKED INCIDENT',
#  'Toothmarks on head & neck',
#  '10" laceration on leg',
#  'Lacerations to hand, face and torso',
#  'Lacerations to wrist',
#  'Hips & thighs bitten',
#  'Survivors on life rafts were harassed by sharks',
#  'FATAL, right thigh lacerated, femoral artery severed ',
#  'Foot bitten PROVOKED INCIDENT',
#  'Right thigh and leg lacerated',
#  'Leg bitten & femur fractured',
#  'No injury, after kayak collided with the shark, it bit the rudder  PROVOKED INCIDENT',
#  'Shin & calf bitten',
#  'Left elbow or hand bitten PROVOKED INCIDENT',
#  'Buttocks injured by fin or a bump ',
#  'Leg bitten 3 times',
#  'Leg severely bitten by netted shark. Lower leg surgically amputated PROVOKED INCIDENT',
#  'FATAL,            Fell overboard and were killed by shark',
#  'FATAL. His brother speared a shark which then attacked Jose & severed his leg at knee. PROVOKED INCIDENT  ',
#  'Injured by harpooned shark PROVOKED INCIDENT',
#  'FATAL, thigh and abdomen bitten ',
#  'Next day 2 bodies recovered from sharks',
#  'FATAL, hooked shark pulled him into the water PROVOKED INCIDENT',
#  'PRESUMED FATAL, body not recovered',
#  'FATAL, chest & leg bitten ',
#  'No injury. Shark grabbed fish attached to his belt & towed him seaward.  ',
#  'FATAL,  partial remains recovered from shark�s gut',
#  'FATAL, right hand severed, large lacerations on thigh',
#  'Foot bitten, crescent of bitemarks in both sides of board',
#  'No injury to surf-skiier, shark holed ski',
#  '2 bites behind knee',
#  'No injury to occupants, shark holed the transom-mounted livewell ',
#  'Right foot: Toes and back of foot, minor injury',
#  'Lacerations to left foot & right shin',
#  'FATAL. His body not recovered',
#  'No injury to occupants. Gaffed shark capsized boat PROVOKED INCIDENT',
#  'Left elbow and bicep bitten',
#  'No injury to occupants, boat holed by shark',
#  'No injury, shark bit trolling motor',
#  'Injuries caused by coral, not the  shark',
#  'U.S. destroyer John W. Weeks, 6 miles offshore, demonstrating guns & bombs for Mexican officials was thought to have driven the shark into the shallows where it bit the bather before other bathers drove it away with sticks & clubs.',
#  'Left leg & right testicle bitten',
#  'Bruised, when shark struck scull & catapulted her into the water',
#  'No injury, chunk missing from surfboard',
#  'Lacerations to left calf and both feet ',
#  'Hooked shark bit his leg PROVOKED INCIDENT',
#  'Hand & right shoulder lacerated',
#  'Left leg biten',
#  'Right leg severely lacerated. Surgically amputated',
#  'No injury to occupants, shark buckled prop shaft',
#  'Lower part of body found 6 days later, x-rays revealed teeth marks in femur & tibia',
#  'Fishermen were cut & bruised by netted, harpooned and gaffed  sharks PROVOKED INCIDENT',
#  'Hooked shark bit his nose, arm and leg PROVOKED INCIDENT',
#  "No injury, shark snagged its teeth in diver's suit",
#  'Bitten by captive sharks PROVOKED INCIDENTS',
#  'Right leg bruised & abraded',
#  'Presumed drowned & bodies taken by sharks',
#  'Puncture wounds on knee',
#  'Shark leapt into & damaged the dinghy but no injury to occupants',
#  'Swept out to sea by strong currents, his remains found in shark caught off Barber�s Point',
#  'No injury, shark bit boot',
#  'No Injury, Kayak holed',
#  'FATAL, legs & torso bitten ',
#  'Left calf & hand lacerated',
#  'Sharks attacked raft & consumed the body of Ericsson after he died',
#  'Feet bitten, surgically amputated FATAL',
#  'Small lacerations on left foot',
#  ' Forced at gunpoint to jump overboard. Presumed fatal; shark involvement probable but not confirmed ',
#  'Left hand and arm bitten',
#  'Lacerations to left arm from shoulder to wrist',
#  '2 lacerations on lower back, punctures on buttock',
#  'Lower left leg lacerated',
#  'FATAL, severe abdominal injuries ',
#  'FATAL, only his legs, still in sea-boots, were recovered ',
#  'Puncture wounds on heel, legs and buttocks',
#  "No injury, speared shark towed Gilles 200 yards & tore hole in diving suit, and hit Dowswell's back with its tail PROVOKED INCIDENT",
#  'FATAL, large gash to thigh',
#  'Sharks attacked the swimmers. The sole survivor lost his arm & foot & died of his injuries shortly after being picked up  by Javanese fishermen. The incident became known as the Cheribon Atrocity',
#  "Injury to forearm from shark's spine PROVOKED INCIDENT ",
#  'FATAL, right thigh & calf bitten ',
#  'Bitten on leg',
#  'Disappeared after diving in �deep hole�, body not recovered, �presumed taken by a shark� ',
#  'Knocked off board, shark bit nose off surfboard',
#  'FATAL, large wound on thigh',
#  'FATAL, left foot & right leg bitten, later surgically amputated  ',
#  '"lost part of a finger"',
#  'No injury to occupants, shark leapt into boat',
#  '8-inch bite on calf',
#  'Legs & torso injured',
#  'No injury, shark bit her bathing suit',
#  'FATAL Laceration to chest',
#  'Shark bit canoe in half & bit man. Note: There is an earlier story of FATAL shark attack in same river',
#  'Wrist & hand lacerated',
#  'Left ankle, calf, thigh and abdomen bitten',
#  'No injury, shark rammed boat & bit motor',
#  '130 perished; 136 survived  including a man whose foot was severed by a shark',
#  'Laceration to right hand and cuts on fingertips',
#  'FATAL, disappeared, then shark caught with head and body of man, from waist down minus leg, in its gut',
#  'Bones recovered by fishermen in 300-kg [662-lb] white shark�s gut',
#  'No injury to occupants, After shark was harpooned & shot, it holed the boat PROVOKED INCIDENT',
#  'Five cuts on his heel',
#  'Left hand, arm & leg lacerated, & shark bit chunk out of his surfboard',
#  '3 puncture wounds on each side of her left  hand',
#  'Small lacerations to right foot',
#  'Injured by shark',
#  'Thigh lacerated PROVOKED INCIDENT',
#  'Severe laceration to left buttock & thigh',
#  'Buttock removed',
#  'Thigh lacerated & abraded  PROVOKED INCIDENT',
#  'Leg bitten by gaffed shark PROVOKED INCIDENT',
#  'Leg bitten just above ankle',
#  'Lacerations to right arm & chest',
#  'No injury, shark made threat displays & diver fended it off with his speargun',
#  'Back of left thigh bitten',
#  'No injury, surf ski bitten',
#  'Scratches on right upper arm',
#  'Right foot & toes lacerated',
#  'FATAL, due to drowning PROVOKED INCIDENT',
#  'No injury to occupant, shark holed boat',
#  'Severe bump & few superficial wounds ',
#  'Minor laceration & 3 punctures to right foot',
#  'Stingray envenomation, not a shark',
#  'No injury to surfer, surfboard bitten by the shark',
#  'Lacerations to left leg & foot',
#  'Minor injury, speared shark lacerated his kneecap & leg PROVOKED INCIDENT',
#  'FATAL, arm/shoulder severed ',
#  'Attempted to frighten shark by smacking water with paddle. Shark bit paddle.  No injury to surf-skier PROVOKED INCIDENT',
#  'Laceration to right hand/wrist',
#  "Left hand bitten as he tried to put rope around shark's tail PROVOKED INCIDENT",
#  'No injury, shark holed boat',
#  'Five men were said to have been killed by sharks ',
#  'No injury to occupants, two 5-foot observation windows shattered',
#  '2 lacerations to ankle',
#  'No injury, but shark removed the heel & part of his left shoe',
#  'Calf removed, not known if he survived ',
#  'Right thigh, back & hand lacerated',
#  'Abrasion & 6 puncture wounds on chest after grabbing the shark by its tail PROVOKED INCIDENT',
#  'Shark nudged board, no injury',
#  'No injury to occupants, shark bit 45 cm hole in hull',
#  'When survivors werer rescued on 10/27/1944 by PC 623 there were many sharks in the area',
#  'Forehead bitten, but shark involvement questionable',
#  'Left arm lacerated when shark grabbed scooter',
#  'Minor injury from captive shark PROVOKED INCIDENT',
#  'Calf bitten by shark caught in net PROVOKED INCIDENT',
#  '8" laceration on left calf',
#  'FATAL, right thigh bitten, femur exposed  ',
#  'Abrasions to lower leg Recorded as PROVOKED INCIDENT',
#  '2 minor lacerations in foot',
#  'Left leg & hand bitten',
#  'Right cheek bitten',
#  'Lower leg bitten & foot severed, leg surgically amputated below knee',
#  'Left thumb severed',
#  'Right arm & side bruised',
#  'No injuries to occupants, Hooked shark bit boat  PROVOKED INCIDENT',
#  'Hand & wrist bitten',
#  'Swept off rocks & presumed to have drowned, shark seen in area',
#  'No injury, grabbed byshark after he pulled its tail PROVOKED INCIDENT',
#  'FATAL, leg severely bitten, surgically amputated PROVOKED INCIDENT',
#  'Fingers, hand & arm bitten',
#  'Remains recovered, probable drowning and scavenging',
#  'Minor laceration to foot',
#  'Knee bitten by shark that his dive buddy had shot  PROVOKED INCIDENT',
#  'Head, neck & shoulder bitten (In 1918, he was also bitten by a shark off Cairns)',
#  'No injury to occupants, propeller shaft damaged',
#  'No injury to occupant, shark grabbed anchor rope, pulling bow of boat downward & then bit bow of boat',
#  'Bitten on ankle',
#  'Puncture wounds on chest',
#  'Finger bitten',
#  'Multiple bites to foot after jumping off surfboard onto shark PROVOKED INCIDENT',
#  'Leg bitten by shark that he had speared  PROVOKED INCIDENT',
#  'Left arm bitten, developed gangrene, surgically amputated',
#  'Torso bitten ',
#  'Sharks reportedly bit legs & fins ',
#  'No injury, shark approached the boat, he hit it with and oar and fell into the sea PROVOKED INCIDENT',
#  '6 puncture wounds to left ankle',
#  'Body recovery efforts were hampered by large sharks but sharks did not cause the deaths. ',
#  '32 survived, 5 perished; sharks fed on the dead but did not bite the survivors',
#  'Lacerations to right thumb and knee',
#  'When picked up by the USS Boyd DD 44 on 6/23/1944 his raft was "surrounded by sharks"',
#  'No injury to occupants, shark lifted boat',
#  '"Severely bitten" but survived',
#  'Small lacerations to arm',
#  'Shark became tangled in his surfboard leash. The surfer was not injured',
#  'Right forearm severed surgically amputated above elbow',
#  'Bitten on left calf & foot',
#  "Right foot bitten when he walked into shark's head PROVOKED INCIDENT",
#  'Reported to have been killed by a shark but 2 years later he was found very much alive',
#  'Calf injured Recorded as PROVOKED INCIDENT',
#  'Severe lacerations to abdomen & thighs',
#  'No injury to occupants, shark bumped boat repeatedly',
#  'Laceration to foot from dead shark PROVOKED INCIDENT',
#  'Bathing suit torn & "imprints of the shark\'s teeth on his body"',
#  '3 lacerations to forearm',
#  'FATAL, 3 passengers & 14 crew taken by sharks, captain, 1 passenger & 2 crew survived',
#  'Puncture marks on left foot',
#  'FATAL, leg severely bitten     ',
#  'Swept out to sea, feared taken by shark',
#  'Glancing bite to wrist from netted shark PROVOKED INCIDENT',
#  'No injury to occupants. Shark chasing fish struck boat',
#  'No injury, shark struck board & spun it around',
#  'No injury to occupants, shark hit boat, lifting it from the water, bit & dented propeller',
#  'Hit by tail of speared shark, fell & hit head on rock & out cold for 30 minutes  PROVOKED INCIDENT',
#  'Left arm severed below shoulder',
#  'Foot & calf lacerated',
#  'FATAL, hand & leg severely injured by shark that leapt into boat  ',
#  'Right leg  severed FATAL',
#  'Slipped off rocks & was treading water when he disappeared, body mutilated by shark/s',
#  'Lacerations to left elbow',
#  'Lost left arm',
#  'No injury to occupant, shark leapt inside boat',
#  'Punctures & lacerations on lower leg',
#  'Disappeared, thought to have been taken by a shark',
#  'No injury to occupants; shark rammed boat repeatedly',
#  'Bitten on legs & buttock',
#  'Found to be a hoax',
#  'No injury to occupants. shark bit oar',
#  '7 lacerations to right foot',
#  'Right arm bitten. Left leg bitten, surgically amputated ',
#  'Right hand bitten  PROVOKED INCIDENT',
#  '2 life preservers had been bitten by sharks',
#  'Dorsum of foot lacerated & toe severed',
#  "Man's leg recovered from 800-lb shark",
#  'Leg & ankle bitten',
#  'Left leg bitten by captive shark                   PROVOKED INCIDENT',
#  'Right lower leg bitten',
#  'Lost hand',
#  'FATAL (presumed), pieces of shark-bitten wetsuit washed ashore but no body was recovered',
#  'Lacerations & abrasions, board bitten in half',
#  'FATAL, buttocks, lower abdomen & genitalia removed  ',
#  'Presumed fatal, no body recovered, shark mutilated wetsuit & harness recovered ',
#  'Minor lacerations to hand, 15" crescent-shaped piece removed from surfboard',
#  'Gaffed shark bit his ankle PROVOKED INCIDENT',
#  'Injuries to arm & leg by hooked shark   PROVOKED INCIDENT',
#  'Lacerations & punctures to lower right leg',
#  'Lower left leg injured PROVOKED ACCIDENT',
#  'No injury, shark bumped & damaged board',
#  'Two feet found in shark, postmortem scavenging',
#  'Scavenged or FATAL (may have involved foul play)',
#  'Although listed as  an uprovoked fatal attack by SAF, he was killed by the explosion. The shark bites were post-mortem ',
#  'Buttock bitten, hands lacerated',
#  'FATAL, right arm  severely bitten & surgically amputated, died 12 to 14 hours later   ',
#  'FATAL, bitten on arms, chest & legs',
#  'PROVOKED INCIDENT Right hand severed by hooked shark',
#  'Puncture wounds to right hand',
#  'Severe lacerations to left hand',
#  'Lacerations to forearm from hooked shark PROVOKED INCIDENT',
#  'Gash on ankle',
#  'Most of the men drowned & some were taken by sharks. Only only nine men survived',
#  'Foot bitten when he accidentally jumped onto the shark PROVOKED INCIDENT',
#  'No injury to occupants; shark bit propeller',
#  'Human head recovered from shark�s gut, probable drowning / scavenging',
#  '9" laceration to right forearm ',
#  'FATAL, disappeared while diving, lower portion of body recovered',
#  'FATAL, shoulder bitten ',
#  'No injury to occupants, 6 sharks charged boat',
#  'Nipped on shoulder by captive shark PROVOKED INCIDENT',
#  'Lacerations to right ankle ',
#  'No injury. They were chased by three sharks, one of which rammed their boat',
#  'Superficial injuries to upper leg may have been caused by surfboard fin',
#  'PROVOKED INCIDENT    Knee bitten by shark trapped in net',
#  'All 16 onboard perished, recovery efforts hampered by sharks',
#  'Leg bitten by shark that had been shot in the head by another diver PROVOKED INCIDENT',
#  'No injury, teethmarks in board & torn wetsuit',
#  'Arm severed, but survived. Note: Some weeks later he was swimming at the same spot when a shark severed his right foot.',
#  '"Tooth marks" in left leg',
#  'FATAL, severely bitten genitals & thighs ',
#  'Laceration on right ankle & heel',
#  'No injury,     Shark landed on top of him, knocked him back down 3 times',
#  'Ankle bitten, hand injured while striking shark',
#  'Left ankle lacerated',
#  'FATAL, both thighs lacerated, right foot, fingers and knee abraded, died of sepsis',
#  'No injury to occupants, shark rammed boat for 15 minutes',
#  '3 lacerations on leg',
#  '"Serious"',
#  ' His gold watch was later found in a shark but death may have been due to drowning',
#  'Right knee bitten',
#  'After diver shot shark attempting to take his catch, shark bit right arm & tore wetsuit  PROVOKED INCIDENT',
#  'Head bitten by netted shark PROVOKED INCIDENT',
#  'FATAL, disappeared while swimming  ',
#  'Remains of 3 humans recovered from shark, but shark involvement prior to death unconfirmed',
#  'No attack, no injury',
#  'Arm lacerated (shark made 3 strikes)',
#  'Right leg & left foot lacerated',
#  'Bodies of  hurricane victims bitten by shoals of sharks, post mortem scavenging',
#  'Back of left hand gashed',
#  'Laceration to hand  ',
#  'Fatal or drowned & remains scavenged by shark',
#  'Minor injuries from shark that leapt aboard their boat',
#  'Several broken ribs',
#  '2 lacerations to the thigh',
#  "No injury, chased by 4.6 m [15'] oceanic whitetip sharks",
#  'Foot bitten, tendons damaged',
#  'Severely bitten on lower leg ',
#  'Disappeared while fishing from shore. Leg found 7 days later wedged in rocks 150 yards offshore',
#  'No injury to occupants, shark almost wrenched oar from aborigine',
#  'No inujury ',
#  'Bitten on left calf and ankle',
#  'Left knee & leg bitten',
#  'No injury, shark bit nose of surfboard',
#  '5.5-inch laceration on calf',
#  'Disappeared, surfboard washed ashore, marks on leash suggested shark involvement ',
#  "No injury, shark's teeth embedded in boat",
#  'Laceration to foream',
#  'Shark holed and sank boat, occupants rescued',
#  'No injury, diver shot shark & it bit his speargun PROVOKED INCIDENT',
#  'FATAL, both legs severed ',
#  'Shark involvement probably post-mortem',
#  'No injury, flung off board',
#  'Thighs bitten, right hand lacerated',
#  'Minor laceration on foot',
#  'FATAL, right leg at hip, left leg and right forearm severed  ',
#  'Lacerations to left calf & ankle, puncture wounds to left foot',
#  'Torso & hand lacerated',
#  'FATAL, left arm & right leg severed ',
#  'FATAL     Injured by shark, died of tetanus',
#  'Right hand bitten by hooked shark being pulled onboard PROVOKED INCIDENT',
#  'No injury from shark, scraped chest climbing out on reef',
#  'Leg & board bitten',
#  'No injury, chased by 3 sharks',
#  'FATAL, foot severed, hip bitten',
#  'Body recovered, mutilated by shark/s',
#  'Foot lacerated from toe to heel when he tripped on shark during fishing competition PROVOKED INCIDENT',
#  'FATAL, leg lacerated  ',
#  'Left thigh abraded, right knee and right index finger injured',
#  'Left calf & heel bitten',
#  'No injury to occupants, shark made 20 to 30 rushes at dinghy',
#  'Right leg bitten & foot severed, right arm bitten, bones fractured & nearly severed FATAL',
#  '2 inch laceration to left lower calf.',
#  'Chest bitten',
#  'No injury, hooked shark bit their 4.8 m inflatable boat',
#  'Minor injury, bite chest and left calf',
#  'Laceration to thigh from trapped shark PROVOKED INCIDENT',
#  'Right thigh and left foot severely bitten',
#  "Speared shark bit diver's right knee, and lacerated right thigh & buttocks PROVOKED INCIDENT",
#  'Laceration to right forearm',
#  'Right hand severely lacerated',
#  'No injury, shark struck camera',
#  "Mistook shark's tail for kelp & grabbed it, legs abraded by shark's fins PROVOKED INCIDENT",
#  'No injury; 4m white shark made a threat display',
#  'PROVOKED INCIDENT    Legs severed by shark entangled in his net',
#  'No injury but shark lifted boat out of the water',
#  'Injury required 16 stitches',
#  'Multiple injuries PROVOKED INCIDENT',
#  ' Search party saw a large shark devour what appeared to be part of her body',
#  'No injury, shark struck kayak, catapulting him into the water',
#  'Right shin, calf and sole of foot lacerated',
#  'Lacerations to torso & arm',
#  'Possible drowning / post mortem scavenging',
#  'Murdered, body scavenged by sharks',
#  'Severe bites to head & shoulder',
#  '3 to 4 cm laceration on foot from hooked shark brought on board PROVOKED INCIDENT',
#  'Right arm punctured, finger lacerated PROVOKED INCIDENT',
#  'No injury, pulled overboard by a shark that grabbed his coat',
#  'No injury, shark rammed his back',
#  'Laceration to calf  PROVOKED INCIDENT',
#  'Laceration on left foot',
#  'No injury, shark bit support boat, removing pieces of wood after Gerricke shot it  PROVOKED INCIDENT',
#  'Foot & swim fin punctured',
#  '3 small punctures on arm',
#  'No injury to occupants Sharks continually followed the dinghy, and one smashed its rudder ',
#  'No injury, shark tore diving suit',
#  'Left leg severed below the knee, defense injuries to left hand',
#  'Survived? Admitted to Thursday Island Hospital',
#  'No injury, swim fin torn',
#  'No injury to occupants, shark bumped & lifted dinghy',
#  'Hand and foot severely bitten, surgically amputated',
#  'FATAL  Autopsy report: bitten by shark while still alive',
#  'Thigh, lower back and surfboard bitten',
#  "No inury, shark caught leash attached to surfer's ankle & towed him a short distance",
#  'Lacerations to lower right leg',
#  'Lower left calf & ankle  lacerated',
#  'Lower legs lacerated ',
#  'Left index finger lacerated',
#  'FATAL, severe injuries to both arms & legs, 3 limbs surgically amputed & died after 3 days  ',
#  '5" gash in foot',
#  'Lacerations to knee & left lower leg by electrocuted captive shark PROVOKED INCIDENT',
#  'FATAL, "pulled below the surface\'  ',
#  'Calf severely lacerated',
#  'Minor scratch on calf',
#  'Abrasion to chest',
#  'Injury to foot    PROVOKED INCIDENT',
#  'No injury to occupants, launch holed',
#  'No injury to occupants, shark crashed through windshield of boat',
#  'No injury to occupants. Shark rammed boat as they were pulling in a flathead',
#  'Lacerations to 2 fingers, but shark involvement unconfirmed',
#  'Bruises & minor injuries from reef, not the shark PROVOKED INCIDENT',
#  'Puncture wounds to thigh, defense wounds  to hand',
#  'Abrasion above knee ',
#  'Severe laceration to finger',
#  '4 lacerations on the sole of his right foot',
#  'FATAL, left arm severed at elbow, right arm bitten, right leg severed at knee    ',
#  'No injury, hooked shark rammed boat & Ruark fell on its back PROVOKED INCIDENT',
#  'Speared shark bit his chest PROVOKED INCIDENT',
#  'Feet lacerated',
#  'Abrasions PROVOKED ATTACK',
#  'Foot & swim fin bitten ',
#  'No injury, right swim fin bitten',
#  'No injury to occupants, shark leapt onboard boat',
#  'Rescue aircraft saw bodies in the water being bitten by sharks. One survivor saw a shark take off a man�s leg & another reported that the second cook was killed by a shark',
#  'Both hands bitten while helping companion land speared shark PROVOKED INCIDENT',
#  "3 m to 3.7 m [10' to 12']  great hammerhead shark shark only made a threat display. No injury",
#  'Major injury to torso',
#  'No injury, board broken in two',
#  'No injury, but surfboard severely damaged',
#  'Doubtful incident, needs investigation',
#  'Thigh',
#  'Burns drowned as result of attack on boat',
#  'Foot, hand, elbow & calf lacerated & abraded, thigh gashed',
#  'Lower left leg bitten',
#  'Bitten on left leg by hooked shark PROVOKED INCIDENT',
#  'FATAL, but was it an accident or infanticide?',
#  '"Serious injuries"',
#  "His body was found in a tiger shark; next day other human remains found in sharks at Berry's Bay ",
#  'PROVOKED INCIDENT Torso bitten by shark hooked by an angler',
#  'Right posterior thigh bitten',
#  'Shark following hooked fish, rammed & holed boat',
#  'Lacerations on heel & dorsum of right foot',
#  'Facial lacerations',
#  'No injury,  bumped repeatedly',
#  'Of 104 people in the water, only 20 survived. 84 people were lost, many to sharks. Sharks 2 pulled crew off life rafts',
#  'Hand lacerated by hooked shark PROVOKED INCIDENT',
#  'Speculated that he was taken by a shark but most likely drowned',
#  ...]

# %%
# Check age column values

list(df["Age"].value_counts().index)
# Out:
# ['17',
#  '18',
#  '19',
#  '20',
#  '15',
#  '16',
#  '21',
#  '22',
#  '24',
#  '25',
#  '14',
#  '13',
#  '23',
#  '26',
#  '27',
#  '28',
#  '29',
#  '30',
#  '12',
#  '32',
#  '35',
#  '10',
#  '40',
#  '31',
#  '38',
#  '34',
#  '43',
#  '36',
#  '33',
#  '39',
#  '37',
#  '42',
#  '11',
#  '9',
#  '52',
#  '41',
#  '50',
#  '45',
#  '44',
#  '47',
#  '8',
#  '49',
#  '46',
#  '48',
#  '7',
#  '55',
#  '51',
#  '57',
#  '6',
#  '60',
#  '54',
#  '53',
#  '58',
#  '59',
#  '61',
#  '63',
#  '56',
#  '62',
#  'Teen',
#  '69',
#  '30s',
#  '5',
#  '70',
#  '68',
#  '20s',
#  'teen',
#  '65',
#  '64',
#  '3',
#  '77',
#  '71',
#  '66',
#  'young',
#  '74',
#  '7 or 8',
#  'F',
#  '75',
#  ' ',
#  '50s',
#  '1',
#  '8 or 10',
#  '40s',
#  '78',
#  '73',
#  '10 or 12',
#  '33 & 37',
#  '9 or 10',
#  'mid-20s',
#  'Elderly',
#  '84',
#  '20?',
#  'mid-30s',
#  'M',
#  '86',
#  '32 & 30',
#  '  ',
#  'Teens',
#  '21, 34,24 & 35',
#  '13 or 14',
#  'X',
#  '23 & 26',
#  '>50',
#  'adult',
#  '46 & 34',
#  '81',
#  '"young"',
#  '33 & 26',
#  '33 or 37',
#  '16 to 18',
#  '"middle-age"',
#  '7      &    31',
#  '18 or 20',
#  '28 & 26',
#  '21 or 26',
#  '36 & 23',
#  '28, 23 & 30',
#  '87',
#  '2 to 3 months',
#  '21 & ?',
#  '2�',
#  '30 & 32',
#  '67',
#  '25 to 35',
#  'MAKE LINE GREEN',
#  '9 months',
#  '17 & 35',
#  '18 to 22',
#  '23 & 20',
#  'A.M.',
#  '18 months',
#  '30 or 36',
#  '37, 67, 35, 27,  ? & 27',
#  '72',
#  '60s',
#  '36 & 26',
#  'Both 11',
#  '9 & 12',
#  '25 or 28',
#  '� ',
#  '31 or 33',
#  '34 & 19',
#  '? & 19',
#  "60's",
#  '17 & 16',
#  '?    &   14',
#  '13 or 18',
#  '(adult)',
#  '12 or 13',
#  'Ca. 33',
#  '50 & 30',
#  '6�']

# %%
# Objective: keep first instance of repeating digits. For pre-cleaning, remove every string with months value

df.loc[df["Age"].str.contains("month").fillna(False), ["Age"]] = np.nan

# %%
# Look at structure of age column

list(df["Age"].value_counts().index)
# Out:
# ['17',
#  '18',
#  '19',
#  '20',
#  '15',
#  '16',
#  '21',
#  '22',
#  '24',
#  '25',
#  '14',
#  '13',
#  '26',
#  '23',
#  '27',
#  '28',
#  '29',
#  '30',
#  '12',
#  '35',
#  '32',
#  '10',
#  '31',
#  '40',
#  '38',
#  '34',
#  '43',
#  '36',
#  '33',
#  '37',
#  '39',
#  '42',
#  '9',
#  '11',
#  '41',
#  '52',
#  '45',
#  '50',
#  '44',
#  '47',
#  '49',
#  '8',
#  '48',
#  '46',
#  '7',
#  '55',
#  '51',
#  '60',
#  '6',
#  '57',
#  '54',
#  '53',
#  '58',
#  '59',
#  '61',
#  '56',
#  '63',
#  '69',
#  'Teen',
#  '62',
#  '5',
#  '30s',
#  '68',
#  '70',
#  '20s',
#  'teen',
#  '64',
#  '3',
#  '65',
#  '66',
#  '71',
#  '77',
#  ' ',
#  '7 or 8',
#  'F',
#  '75',
#  '40s',
#  'young',
#  '1',
#  '8 or 10',
#  '78',
#  '50s',
#  '74',
#  '10 or 12',
#  'mid-20s',
#  '21, 34,24 & 35',
#  '20?',
#  'Elderly',
#  'mid-30s',
#  '32 & 30',
#  '84',
#  '  ',
#  '73',
#  'X',
#  'Teens',
#  '>50',
#  '13 or 14',
#  '23 & 26',
#  '86',
#  'M',
#  '33 & 37',
#  '9 or 10',
#  '46 & 34',
#  'adult',
#  '34 & 19',
#  '87',
#  '18 to 22',
#  '33 & 26',
#  '33 or 37',
#  '16 to 18',
#  '"middle-age"',
#  '7      &    31',
#  '18 or 20',
#  '28 & 26',
#  '36 & 23',
#  '"young"',
#  '28, 23 & 30',
#  '21 & ?',
#  '2�',
#  '30 & 32',
#  '67',
#  '25 to 35',
#  'MAKE LINE GREEN',
#  '17 & 35',
#  '23 & 20',
#  '50 & 30',
#  '81',
#  'Ca. 33',
#  'A.M.',
#  '30 or 36',
#  '37, 67, 35, 27,  ? & 27',
#  '72',
#  '60s',
#  '36 & 26',
#  'Both 11',
#  '9 & 12',
#  '25 or 28',
#  '� ',
#  '21 or 26',
#  '31 or 33',
#  '? & 19',
#  '17 & 16',
#  '6�',
#  '?    &   14',
#  '13 or 18',
#  '(adult)',
#  '12 or 13',
#  "60's"]

# %%
# for every age row without na, create new Age row containing the first instance of consecutive digits

df["newAge"] = 1
df.loc[~df["Age"].isna() , ["newAge"]] = df['Age'].str.extract(r"([0-9]+)", expand=False)

# %%
# Check for new Age value counts

df['newAge'].value_counts()
# Out:
# 1     2684
# 17     150
# 18     147
# 20     144
# 19     139
#       ...
# 87       1
# 67       1
# 2        1
# 86       1
# 84       1
# Name: newAge, Length: 81, dtype: int64

# %%
# Compare value count lists

print(list(df['newAge'].value_counts().index))
print(list(df['Age'].value_counts().index))
# Out:
# [1, '17', '18', '20', '19', '16', '15', '21', '22', '25', '24', '14', '13', '30', '23', '26', '28', '27', '29', '12', '32', '35', '40', '10', '31', '38', '34', '33', '43', '36', '37', '9', '39', '42', '11', '50', '41', '52', '45', '8', '44', '47', '49', '46', '48', '7', '55', '51', '60', '6', '57', '54', '53', '58', '61', '59', '63', '56', '69', '62', '5', '70', '68', '3', '65', '64', '71', '77', '66', '75', '74', '1', '78', '73', '81', '72', '87', '67', '2', '86', '84']
# ['17', '18', '19', '20', '15', '16', '21', '22', '24', '25', '14', '13', '26', '23', '27', '28', '29', '30', '12', '35', '32', '10', '31', '40', '38', '34', '43', '36', '33', '37', '39', '42', '9', '11', '41', '52', '45', '50', '44', '47', '49', '8', '48', '46', '7', '55', '51', '60', '6', '57', '54', '53', '58', '59', '61', '56', '63', '69', 'Teen', '62', '5', '30s', '68', '70', '20s', 'teen', '64', '3', '65', '66', '71', '77', ' ', '7 or 8', 'F', '75', '40s', 'young', '1', '8 or 10', '78', '50s', '74', '10 or 12', 'mid-20s', '21, 34,24 & 35', '20?', 'Elderly', 'mid-30s', '32 & 30', '84', '  ', '73', 'X', 'Teens', '>50', '13 or 14', '23 & 26', '86', 'M', '33 & 37', '9 or 10', '46 & 34', 'adult', '34 & 19', '87', '18 to 22', '33 & 26', '33 or 37', '16 to 18', '"middle-age"', '7      &    31', '18 or 20', '28 & 26', '36 & 23', '"young"', '28, 23 & 30', '21 & ?', '2�', '30 & 32', '67', '25 to 35', 'MAKE LINE GREEN', '17 & 35', '23 & 20', '50 & 30', '81', 'Ca. 33', 'A.M.', '30 or 36', '37, 67, 35, 27,  ? & 27', '72', '60s', '36 & 26', 'Both 11', '9 & 12', '25 or 28', '� ', '21 or 26', '31 or 33', '? & 19', '17 & 16', '6�', '?    &   14', '13 or 18', '(adult)', '12 or 13', "60's"]

# %%
# Check again

df[['newAge','Age']].dropna()
# Out:
#      newAge       Age
# 0        16        16
# 2        43        43
# 6        60       60s
# 7        51        51
# 8        50        50
# ...     ...       ...
# 5933     16        16
# 5944     50        50
# 5955     13  13 or 14
# 5966     16        16
# 5991     15        15
#
# [3276 rows x 2 columns]

# %%
## Fatal column. Rename and make binary

df = df.rename(columns={"Fatal (Y/N)":"Fatal"})

# %%
# Check Fatal column value names

df["Fatal"].value_counts()
# Out:
# N          4314
# Y          1552
# UNKNOWN      94
#  N            8
# #VALUE!       1
# F             1
# n             1
# N             1
# Name: Fatal, dtype: int64

# %%
# make Sex column to only M and F
df.loc[df["Fatal"] == " N", ["Fatal"]] = "N"
df.loc[df["Fatal"] == "N ", ["Fatal"]] = "N"
df.loc[df["Fatal"] == "n", ["Fatal"]] = "N"
df.loc[df["Fatal"] == "F", ["Fatal"]] = "UNKNOWN"
df.loc[df["Fatal"] == "#VALUE!", ["Fatal"]] = "UNKNOWN"

# convert UNKNOWN into NaN
df.loc[df["Fatal"] == "UNKNOWN", ["Fatal"]] = np.nan

# Convert into binary
df.loc[df["Fatal"] == "N", ["Fatal"]] = 0
df.loc[df["Fatal"] == "Y", ["Fatal"]] = 1

# %%
# Confirm new Fatal column structure

df["Fatal"].value_counts()
# Out:
# 0    4324
# 1    1552
# Name: Fatal, dtype: int64

# %%
## Check time column

list(df["Time"].value_counts().index)

df["nTime"] = 1
# Just convert first occurence of digits followed by h into hour
df.loc[~df["Time"].isna() , ["nTime"]] = df['Time'].str.extract(r"([0-9]+)[h]", expand=False)

# %%
# Check 

df[['nTime','Time']].dropna()
# Out:
#      nTime         Time
# 0       13        13h00
# 2       10        10h43
# 6       15        15h15
# 7       14        14h30
# 8       15        15h40
# ...    ...          ...
# 5782    14        14h00
# 5804    17  17h00-18h00
# 5811    19  19h00-20h00
# 5824    13        13h00
# 5890    18        18h00
#
# [2234 rows x 2 columns]

# %%
# Rename into time_hours

df = df.rename(columns={"nTime":"time_hours"})

# %%
# Remove trailing whitespace in Species column name

df = df.rename(columns={"Species ":"Species"})

# %%
# Check out species column

list(df["Species"].value_counts().index)
# Out:
# ['White shark',
#  'Shark involvement not confirmed',
#  'Tiger shark',
#  'Bull shark',
#  "6' shark",
#  "4' shark",
#  "1.8 m [6'] shark",
#  "1.5 m [5'] shark",
#  "1.2 m [4'] shark",
#  "3' shark",
#  "5' shark",
#  "4' to 5' shark",
#  "3 m [10'] shark",
#  '2 m shark',
#  'No shark involvement',
#  'Wobbegong shark',
#  "3' to 4' shark",
#  '3 m shark',
#  "2.4 m [8'] shark",
#  "3.7 m [12'] shark",
#  "12' shark",
#  'Blue shark',
#  'Blacktip shark',
#  'Mako shark',
#  "1.2 m to 1.5 m [4' to 5'] shark",
#  "7' shark",
#  '"a small shark"',
#  "5 m [16.5'] white shark",
#  "10' shark",
#  '1.5 m shark',
#  "4 m [13'] white shark",
#  'Raggedtooth shark',
#  'Zambesi shark',
#  'Bronze whaler shark',
#  "6 m [20'] white shark",
#  'Grey nurse shark',
#  'Nurse shark',
#  "3 m [10'] white shark",
#  '1 m shark',
#  "White shark, 4 m [13'] ",
#  "2.1 m [7'] shark",
#  "2' to 3' shark",
#  'a small shark',
#  'Hammerhead shark',
#  '"small shark"',
#  'Unidentified species',
#  '2.5 m shark',
#  "9' shark",
#  'Sandtiger shark',
#  'Basking shark',
#  'Lemon shark',
#  "Bull shark, 6'",
#  "2.5 m [8.25'] white shark",
#  "5.5 m [18'] shark",
#  ' ',
#  "White shark, 5 m [16.5'] ",
#  "4 m to 5 m [13' to 16.5'] white shark",
#  "14' shark",
#  "6' to 8' shark",
#  "15' shark",
#  'Tiger shark?',
#  '1.8 m shark',
#  'Thought to involve a Zambesi shark',
#  "White shark, 3 m [10'] ",
#  'Spinner shark',
#  "0.9 m [3'] shark",
#  "8' shark",
#  "4.3 m [14'] shark",
#  "4 m [13'] shark",
#  "5 m to 6 m [16.5' to 20'] white shark",
#  'Shark involvement prior to death not confirmed',
#  "5' to 6' shark",
#  'Oceanic whitetip shark',
#  "5.5 m [18'] white shark",
#  'Possibly a juvenile blacktip or spinner shark',
#  "Tiger shark, 3 m [10']",
#  "2' shark",
#  "1.8 m to 2.4 m [6' to 8'] shark",
#  'Blacktip or spinner shark',
#  "13' shark",
#  "1.8 m [6'] blacktip shark",
#  "3 m [10'] bull shark",
#  '"sand shark"',
#  "4.6 m [15'] shark",
#  'Angel shark',
#  "White shark, 3.7 m [12'] ",
#  "2 m [6.75'] shark",
#  '2 m [6\'9"] shark',
#  'blacktip or spinner shark',
#  'Sevengill shark',
#  "1.5 m to 1.8 m [5' to 6'] shark",
#  "Tiger shark, 2.4 m [8']",
#  "Tiger shark, 1.8 m to 2.4 m [6' to 8'] ",
#  "12' to 14' shark",
#  '2m shark',
#  '4 m shark',
#  "Tiger shark, 14' ",
#  "White shark, 2.4 m [8'] ",
#  "2.7 m [9'] shark",
#  "4' to 6' shark",
#  '2 sharks',
#  'Thought to involve a white shark',
#  'small shark',
#  'White shark?',
#  'Grey reef shark',
#  "Bronze whaler shark, 6'",
#  '4 m white shark',
#  "3 m to 4 m [10' to 13'] white shark",
#  "6 m [20'] shark",
#  'Galapagos shark',
#  'Unidentified',
#  '18" to 24" shark',
#  'reef shark?',
#  "16' shark",
#  "3' to 5' shark",
#  "Lemon shark, 4'",
#  'juvenile shark',
#  "Bronze whaler shark, 3 m [10'] ",
#  "Nurse shark, 1.5 m [5'] ",
#  'Caribbean reef shark',
#  '3 sharks',
#  "a small shark'",
#  '5 m shark',
#  "White shark, 15'",
#  "3.5' to 4' shark",
#  'White shark, 3m to 4m',
#  'Shark involvement prior to death was not confirmed',
#  "10' to 12' shark",
#  'White shark, 4m',
#  '4.5 m white shark',
#  "Bronze whaler shark, 2.5 m [8.25'] ",
#  'Blue pointer',
#  "20' shark",
#  'White shark, 5m',
#  '3 m white shark',
#  'Bronze whaler shark?',
#  "Tiger shark, 3.7 m [12'] ",
#  '"a dog shark"',
#  "Tiger shark, 10' to 12' ",
#  'Tiger shark, 3 m ',
#  "Tiger shark, 1.8 m [6'] ",
#  'White shark, 4.5 m ',
#  "Blacktip shark, 4'",
#  "Tiger shark, 1.8 m [6']",
#  '2 m to 3 m shark',
#  '"small sharks"',
#  "Tiger shark, 2.4 m to 3 m [8' to 10'] ",
#  '3.5 m white shark',
#  "2.3 m [7'] shark",
#  "18' shark",
#  "2.4 m [8']  shark",
#  "Tiger shark, 5 m [16.5']",
#  'White sharks',
#  'Bull shark suspected due to freshwater habitat',
#  '7-gill shark',
#  '6 m shark',
#  "White shark, 4 m to 5 m [13' to 16.5'] ",
#  'bull shark',
#  'Bull or tiger shark',
#  'A pack of 6 sharks',
#  '"sand" shark',
#  "Said to involve a 7 m [23'] white shark",
#  "Mako shark, 4.3 m [14']",
#  '3.6 m [11\'9"] white shark',
#  "Tiger shark, 2.5 m [8.25']",
#  'Thought to involve a tiger shark',
#  'Bronze whaler shark, 1.5 m ',
#  "Raggedtooth shark, 2.5 m [8.25'] ",
#  'Bronze whaler shark, 1.5m',
#  "1.2 m [4'] bull shark",
#  "Grey reef shark, 1.2 m [4'] ",
#  'Possibly a sand shark',
#  "Raggedtooth shark, 1.5 m [5'] ",
#  'small nurse shark',
#  "Sharks averaged 1.8 m [6'] in length",
#  'Dusky shark, 1 m ',
#  'White shark, 3.5 m',
#  "Tiger shark, 8' to 9' ",
#  'small blacktip shark?',
#  "Tiger shark, 7'",
#  "Tiger shark, 10' to 12'",
#  "Bull shark, 1.8 m to 2.1 m [6' to 7'] ",
#  'Possibly C. leucas',
#  "Tiger shark, 10' ",
#  "Bull shark, 5'",
#  "White shark, 5.5 m [18']",
#  "1.5 m [5'] blacktip shark",
#  'White shark, according to witnesses',
#  "Tiger shark, 3.7 m [12']",
#  'Whale shark',
#  "Tiger shark, 12'",
#  'Possibly a bull shark',
#  'Blacktip reef shark ',
#  "Nurse shark, 1.2 m [4'] ",
#  "1.8 m to 2.1 m [6' to 7'] shark",
#  'Wobbegong shark?',
#  'Bull shark, 1.5m ',
#  'Tiger shark, 4 m ',
#  "Thought to involve a 2.6 m [8.5'] white shark",
#  "2.5 m [8.25'] shark",
#  '"a large shark"',
#  "White shark, 10' to 12' ",
#  "6 m [20']  shark",
#  'Bull shark, 3.5 m',
#  'Carpet shark',
#  'Tiger shark, 300-kg [662-lb] ',
#  "White shark, 10'",
#  "2 m [6.75'] white shark",
#  "Tiger shark, 2.4 m 3.4 m [8' to 11']  ",
#  "White shark, 12' ",
#  "5.5 m to 6 m [18' to 20']  white shark",
#  "5.5 m to 6 m [18' to 20'] white shark",
#  "3.5 m [11.5'] white shark",
#  'Raggedtooth shark, 1 m ',
#  "White shark, 8' to 10'",
#  "Tiger shark, 10'",
#  "Tiger shark, 1.5 m [5']k",
#  "Tiger shark, 4.3 m [14'] ",
#  "0.9 m to 1.2 m [3' to 4'] shark",
#  '200-lb shark',
#  'White shark, 2.5 m ',
#  'White shark, 6 m',
#  "1.8 m to 2.4 m [6' to 8'] hammerhead shark",
#  'Possibly a bull shark or tiger shark',
#  "White shark, 5.5 m [18'] ",
#  "1.8 m [6'], 180-lb shark",
#  "Bull shark, 7'",
#  "3 m to 5 m [10' to 16.5'] white shark",
#  "Tiger shark, 3 m [10'] ",
#  "Nurse shark, 2.5' ",
#  'Shark involvement questionable',
#  "Tiger shark, 1.5 m to 1.8 m [5' to 6'] ",
#  'Raggedtooth shark ',
#  "1.2 m  [4'] shark",
#  "Raggedtooth shark, 1.2 m [4'] ",
#  "Said to be a 7.6 m [25'] shark",
#  'Shark involvement unconfirmed',
#  'Nurse shark, 1 m ',
#  'White shark, 2.5m ',
#  "Tiger shark, 15'",
#  "White shark, 2.7 m [9'] ",
#  "White shark, 4.9 m [16'] ",
#  '1m shark',
#  "3'  shark",
#  'Zambesi shark?',
#  "0.9 m to 1.5 m [3' to 5'] shark",
#  'White shark, 3 m ',
#  "White shark, 11' to 12'",
#  'White shark, 5 m ',
#  'Tiger shark, 3m ',
#  'A large white shark was filmed by divers on a local wreck 2 days prior to the incident.',
#  'Bull shark, 3m',
#  "2 m to 2.5 m [6.75'  to 8.25'] shark",
#  'A �small� shark',
#  "1.5 m [5'] Caribbean reef shark",
#  "White shark, 5.5 m to 6 m [18' to 20'] ",
#  '"A small shark"',
#  "Tiger shark, 6'",
#  'Nurse shark, 58", 34-lb ',
#  'White shark, 2m',
#  'Possibly a spinner shark',
#  "8' blue shark",
#  'Questionable incident',
#  '2 to 2.5 m shark',
#  'Salmon shark',
#  'Sand shark',
#  'Oceanic whitetip shark, 2.5m, female',
#  'Juvenile dusky shark',
#  '5 m white shark',
#  "1.8 m [6'] grey reef shark",
#  'White shark named �Spotty�',
#  'Shark involvement suspected but not confirmed',
#  'Reported to involve a hammerhead shark',
#  'Bull shark?',
#  "Grey nurse shark, 2.4 m [8'] ",
#  'Shark involvement not cofirmed',
#  "Wobbegong shark, 1.8 m [6'] ",
#  "4.5' shark",
#  'Grey nurse shark?',
#  "1.5 m [5'] shark, probable bull shark",
#  "Tiger shark, 14'",
#  "White shark, 5 m to 6 m [16.5 to 20'] ",
#  "Wobbegong shark, 1.2 m [4'] ",
#  '1.8 m blacktip "reef" shark',
#  '2.5 to 3 m shark',
#  "Grey nurse shark, 1.8 m [6']",
#  'White shark, 3 m',
#  'Thought to involve a bull shark',
#  '3.5 m shark',
#  "White shark, 2.4 m to 3 m [8' to 10'] ",
#  '� ',
#  'Blacktip Reef shark ',
#  "Grey nurse shark, 10' ",
#  "8' to 10' shark",
#  "Tiger shark, 10'  ",
#  'Possibly a bronze whaler shark',
#  'small blacktip shark',
#  'Shark involvement probable',
#  "1.8 m [6'] shark ",
#  "Tiger shark, 1.5 m [5'] ",
#  '2 m hammerhead',
#  "Blacktip shark, 5'",
#  'White shark, 3.6 m [11\'9"] ',
#  "Sandtiger shark, 2.1 m [7'] ",
#  'Bull shark, 2m',
#  "3.5 m [11.5'] shark",
#  "1.2 m [4'] blacktip shark",
#  'White shark (tooth fragment recovered)',
#  "Blacktip shark, 4' to 5'",
#  'Shark involvement doubtful',
#  "3 m to 4 m [10' to 13']  white shark",
#  "Bull shark, 8'",
#  'Tiger shark, 1.5 m ',
#  'small sharks',
#  'reef shark',
#  "Nurse shark, 2.1 m [7']",
#  '20 to 30kg shark',
#  'White shark, 15\'2" ',
#  "4.9 m [16'] shark",
#  "White shark, 4.6 m [15'] ",
#  "1.5 m to 2 m [5' to 6.75'] shark",
#  'Bronze whaler',
#  "Mako shark, 2 m [6.75'] ",
#  'Grey nurse shark, 3m',
#  'White shark, 2.5m',
#  "Bull shark, 4' to 5' ",
#  "Mako shark, 1.5 m [5'] ",
#  'Shark involvement  questionable',
#  'shark involvement not confirmed',
#  '3 m to 4 m shark',
#  'Allegedly a 33-foot shark',
#  '2 m to  3 m shark',
#  "1.8 m [6'] carpet shark",
#  "Tiger shark, 3.7 m to 4.3 m  [12' to 14']",
#  "numerous dusky sharks & a 3 m to 4.6 m [10' to 15'] to  tiger shark",
#  "Possibly a 6' lemon shark",
#  '>1.6 m shark',
#  'White shark or thresher shark',
#  'C. macrurus captured 48 hours after attack with tissue removed from man in its gut; species identified by G.P. Whitley,  reported as C. obscurus by  R. Steel',
#  "Bull shark, 2.3 m [7.5'] ",
#  'Bronze whaler shark, a  juvenile ',
#  "White shark, 12' to 15' female",
#  '�small brown shark�',
#  "14' to 16' white shark",
#  "Tiger sharks, 2.4 m to 4.9 m [8' to 16'] ",
#  '2.5 oceanic whitetip shark',
#  'Allegedly a 4 m tiger shark',
#  "Horn shar,k Heterodontus francisci, 1.2 m [4'] ",
#  'Bull shark, 1.3 m',
#  'Blacktip shark, 2m',
#  'A hammerhead shark, then 8 to 10 other sharks were said to be  involved',
#  "Oceanic whitetip shark, 6'",
#  "Bronze whaler shark, 4.6 m [15'] ",
#  "6' blacktip shark",
#  "According to Carlsmith, the shark's mouth was 3' wide",
#  "Mako shark, 14' ",
#  'Remains recovered 5 days later',
#  "Grey nurse shark, 4' ",
#  '1.8 m silky shark',
#  'Blue shark bites present ',
#  "White shark, 1.8 m to 2.1 m [6' to 7']  according to Shreuder and a witness",
#  'Survivors said 2 species of sharks were involved:  oceanic whitetip sharks and another species',
#  "Caribbean reef shark, 1.2 m to 1.5 m [4' to 5'] ",
#  '"Blue nose sharks"',
#  "3.5 m [11.5'], 510-kg [1125-lb] hooked & shot white shark",
#  "Shovelnose shark, 6 m [20'] ",
#  "Spinner shark, 6'",
#  "3' blacktip shark",
#  '2\' "banjo shark"',
#  "2.4 m [8'] tiger shark caught 40 hours later with shorts of the boy in its gut",
#  'Bonita sharkk, 200-lb',
#  '3 bull sharks',
#  "14' white shark",
#  "4.3 m [14'] shark seen in vicinity",
#  '250-lb "dog shark"',
#  "12' tiger shark",
#  'Small bull shark',
#  'Lemon shark, 2.5m to 3m ',
#  'Wobbegong shark, 1.4 m [4\'6"] ',
#  '40-lb sand shark',
#  "White shark, 6 m [20']",
#  'a small hammerhead shark',
#  "4' shark?",
#  'Nurse shark?',
#  "4m [13'] shark",
#  'Questionable incident; reported as shark attack but thought to involve a pinniped instead ',
#  "Blacktip shark, 1.2 m to 1.8 m [4' to 6'] ",
#  "2.1 m [7'] sandtiger shark",
#  "Bronze whaler shark,3.7 m [12'] ",
#  'White shark, 4.5 m  to 6 m [14\'9" to 20\'] according to witnesses',
#  'Bronze whaler shark, 4m',
#  "Raggedtooth shark, 3.5 m [11.5'] ",
#  '3- to 4-foot shark',
#  "Said to involve a 6.5 m [21.5'] shark",
#  "Oceanic whitetip shark,1.8 m [6'] ",
#  "Wobbegong shark, 3' ",
#  "Tiger shark, 2.4 m to 2.7 m [8' to 9']  ",
#  "White shark, 5' k",
#  '5m shark',
#  " white shark, 15' ",
#  'Said to involve 2 sharks',
#  '1.8 m to 2.4 m [6\' to 8\'] "black finned shark"',
#  "White shark, 2.1 m [7']  based on tooth pattern",
#  "2 m [6.75'] sevengill  shark",
#  'Possibly a blacktip reef shark',
#  '2.4 m shark',
#  '1.5 m [5\'] "whaler shark"',
#  "Shortfin mako shark, 3 m to 3.4 m [10' to 11'] ",
#  '1.8 to 2 m C. albimarginatus',
#  'Wobbegongs',
#  "2.7 m to 3 m [9' to 10'] sharks",
#  'Soupfin shark',
#  'Tiger shark, 4.8 m',
#  'Blue shark?',
#  '6 m, 600-kg shark',
#  "1.8 m to 2.1 m [6' to 7'] hammerhead shark",
#  '7-gill shark?',
#  '1.3 m [4\'3"] shark',
#  "2.1 m [7'] shark, possibly a spinner shark",
#  "White shark, 3.8 m [12.5']  ",
#  '4.5 m shark',
#  '300-kg [662-lb] shark',
#  "2.4 m to 3 m [8' to 10'] white shark",
#  'Shark involvement prior to death still to be determined',
#  "Tiger shark, 2.7m  [9']",
#  'possibly a bronze whaler shark',
#  "106 cm [3.5']  shark",
#  "Whaler shark, 2.7 m [9'], 350- to 450-lb  identified by G.P. Whitley",
#  'Raggedtooth shark, 147-kg [324-lb] ',
#  'Shark was said to �have a very rough ��-thick skin�',
#  "White shark, 1.8 m [6'] ",
#  "Blue shark, 1.8 m [6'] ",
#  'White shark, 2.7 m [9\'1"], 750-lb ',
#  'Grey reef shark, Identified as C. menisorrah, by E.S. Hobson, F. Mautin & E.S. Reese (1961)',
#  "1.7 m [5.5'] shark",
#  'Thought to involve a porbeagle or mako shark',
#  '1.2 m to 1.5 m [4\' to 5\'] "reef shark"',
#  '1.6 m shark',
#  'Tiger shark, 2.5 m',
#  "1.2 m to 1.5 m [4' to 5'] shark, possibly a bull shark",
#  'White shark, 4m ',
#  '1.5 m copper shark',
#  "Reef shark, 5'",
#  '2 to 3 m shark',
#  "Mako shark, 1.8 m [6']",
#  '2 m cow shark',
#  "Blacktip shark, 2.4 m to 3 m [8' to 10'] ",
#  'White shark (tooth fragments recovered)',
#  '8; 206-lb shark',
#  "5' to 6' spinner or bull shark",
#  "4.5 m to 5.5 m [15' to 18'] white shark",
#  ' Tiger shark, 2.8m',
#  "2.3 m [7.5'] white shark, identified by M. Smale",
#  'Tiger shark,  3.6 m [11\'9"], 850-kg [1874-lb] female, contained Girvan\'s remains ',
#  "Sandtiger shark, 3 m [10'] ",
#  "5 m  [16.5'] white shark",
#  'Remains recovered from shark caught days later',
#  "[4.5' to 5'] shark",
#  '"A pack of 6 sharks"',
#  '2.1 m [7\'] shark with "a very flat head� that had followed the boat for 3 days',
#  "Mako shark, 1.8 m [6']  ",
#  "2.7 m [9'] bull shark, identified by Capt. W. Gray",
#  'Tiger shark, 10?',
#  '1.7 m shark',
#  'White shark, 6.5 m ',
#  "Carpet shark, 1.5 m [5']",
#  "Nurse shark, 6'",
#  'White shark, 4.8 m ',
#  "Nurse shark, 60 cm to 90 cm [2' to 3'] ",
#  '<1.5 m shark',
#  'Tiger shark & others',
#  'Hammerhead shark?+O2356',
#  "1.2 m to 1.5 m [4' to 5'] hammerhead shark",
#  "Sandbar shark ,8'",
#  "Nurse shark, 4'",
#  "White shark, 12' to 14'",
#  'Though to involve a white shark',
#  "Blue pointer, 11' ",
#  "1' to 2' hammerhead or bonnethed shark",
#  "1.8 m [6'] blacktip shark or spinner shark",
#  "Tiger shark, 13' ",
#  'Possibly  a blacktip or spinner shark',
#  'Survivors said 2 species of sharks were involved:  oceanic whitetip sharks and another species,',
#  'said to involve a tiger shark',
#  'Bull shark, 8',
#  'Mako shark, 125-lb ',
#  "12' to 14' white shark",
#  "Tiger shark, 12' ",
#  "Zambesi shark, 1.7 m [5.5'] ",
#  "2.5 m [8.25'] white shark ",
#  "Nurse shark, 1.1 m [3.5'] ",
#  '100-kg [221-lb] dead blue shark',
#  "2.7 m [9']shark",
#  'Cookie cutter shark',
#  'white shark',
#  "Sevengill shark, 2.4 m [8'] ",
#  "1.5 m [5'] white shark or sevengill shark",
#  'Possibly a broadnose 7-gill shark',
#  'Shortfin mako shark, 175-lb ',
#  'Shark involvement not confirmed, injury may have been caused by a bluefish',
#  '"Attacked by a number of sharks"',
#  "3.7 m [12'], 1200-lb shark. Shark caught & its jaw exhibited at the Carnegie Museum",
#  "Wobbegong shark, 1.4 m [4.6'] ",
#  'Broadnose sevengill shark',
#  "4 m [13'], 590-kg white shark",
#  'Said to be a �small shark�',
#  'White shark, 1,900-lb ',
#  'Mako shark, 100-kg [221-lb] ',
#  "Mako shark, 3 m [10']",
#  "5.5 m [18'] shark seen in the vicinity",
#  'White shark, 2.7 m',
#  "Raggedtooth shark, 2.7 m [9'] ",
#  "Tiger shark, 4 m [13'] ?",
#  "Bronze whaler shark, 1.8 m [6'] ",
#  "+3' shark",
#  'Spinner or blacktip sharks',
#  'White shark, 2.8 to 3 m ',
#  'Shovel-nosed guitarfish',
#  'Reported to involve a 4 m white shark',
#  '2 m [6\'9"] shark ',
#  '"grey-colored shark"',
#  'A 6.5\' "blue-nosed shark"',
#  "3.5' hammerhead shark",
#  "Bull shark, 6' to 7'",
#  "Bull shark, 9' to 10'",
#  "3 m [10'] blue whaler",
#  "Tiger shark, 4 m to 4.3 m [13' to 14'] ",
#  'Hand found in gut of 2.9 m to 3.3 m [9\'7" to 10\'11"] Galapagos shark, C. galapagensis',
#  "3' small spotted catshark, Scyliorhinus canicula",
#  '5 m to 6 m white shark',
#  'Tooth fragments of �whaler� shark were recovered, a bull shark, according to Edwards',
#  "60 cm to 90 cm [2' to 3'] shark",
#  "Said to involve a Grey nurse shark 3.7 m [12'] ",
#  'Bull shark, 2m ',
#  'Raggedtooth shark, 2 m [6\'9"], 5-year-old, captive female ',
#  'White shark, 2 m [6\'9"]  (Tooth fragment recovered from victim\'s shoulder & identified by J.T. Nicholls)',
#  'Gray reef shark',
#  '"small brown-colored shark"',
#  "Shortfin mako shark, 2.3 m [7.5'] ",
#  '18" to 36" shark',
#  "2.1 m [7'] shark, a shark's serrated tooth recovered from toe",
#  'Raggedtooth shark, 2 m ',
#  'Raggedtooth shark, 2m',
#  'Species unidentified',
#  'Tiger shark, 4.5 to 5.5 m [14\'9" to 18\'], 2000-lb  ',
#  "Porbeagle shark, 3 m [10']rk",
#  'small carpet shark',
#  "1' to 2' shark",
#  '440-lb shark',
#  "Bull shark, 5' ",
#  'Tiger shark, 3.7 m to 4.5 m [12\' to 14\'9"]  ',
#  'Mako shark, 3m',
#  'sandtiger shark',
#  "Bronze whaler shark,  3m [10'] ",
#  ">1.8 m [6'] shark",
#  '250-lb female "blue fin" shark',
#  ">2.4 m [8'] shark",
#  "White shark, 12' to 15' ",
#  'Possibly a sandbar shark or small blacktip shark',
#  'Salmon shark suspected, but unlikely',
#  'sand shark',
#  "1.5 m [5'] shark, either a bronze whaler or a grey nurse shark",
#  "1.5 m to 2 m [5' to 6.75'] Caribbean reef shark ",
#  '"sandshark"',
#  'Zambezi shark (tooth fragments recovered)',
#  "White shark, 14' to 16' ",
#  "White shark, 1.5 m [5'] k",
#  'Small shark',
#  '43" shark',
#  'Bronze whaler shark, 3 m',
#  'Tiger sharks & bull sharks (20 sharks in all)',
#  "18', 750-lb shark",
#  "1.5 m to 2.1 m  [5' to 7'] shark",
#  'Bronze whaler shark, 3.5 m ',
#  "2.4 m [8'] white shark, species identity confirmed by witnesses & tooth pattern in surfboard",
#  '2.8 m [9\'3"] white shark',
#  "Bronze whaler shark, 10' ",
#  'Thought to involve a 1.2 to 1.5 m tubar�o da gralha preta -  a blacktip shark, C. limbatus?',
#  'A bull shark, according to some of the divers on the boat',
#  '"reef shark"',
#  "9.5' shark?",
#  "Tiger shark, 6' ",
#  'White shark, 3m, seen in area and hooked 3 days later',
#  'Thought to involve a small sand shark',
#  '9-foot shark',
#  "1.2 m [4'], possibly  larger shark",
#  'Raggedtooth shark, 56-kg [123-lb] ',
#  'Possibly a hammerhead shark',
#  "Silky shark, 1.9 m [6.5']",
#  'Tiger shark, 2.5 m ',
#  '4.9 m white shark',
#  "Hammerhead shark, 5' ",
#  "2.4 m [8'], 600-lb shark",
#  "On 11-Jan-1994, his remains washed ashore. A 2.4 m [8'] tiger shark thought to be involved",
#  "Wobbegong shark, 4'",
#  'White shark, 2000-lb',
#  "Alleged to involve a White shark, 7.6 m [25'] ",
#  'Unknown',
#  'Sandbar shark',
#  'White shark according to tooth pattern and witnesses',
#  'Mako shark, 1.3 m gaffed ',
#  'Said to involve a 1.5 m shark',
#  'White shark (identified by Dr. Hugh Smith) ',
#  "White shark,4.6 m [15'] ",
#  'Mako shark, 2.3 m, 150-kg  ',
#  "Remains recovered from 5.5 m [18'] white shark",
#  '>1 m shark',
#  '40 to 50 sharks attacked survivors in the water',
#  "1.8 m [6'] reef shark - or a 2.1 m to 2.4 m [7' to 8'] grey-colored shark",
#  'Tooth fragments recovered from hull',
#  "Reported to involve a White shark, 6 m to 7m [20' to 23'] ",
#  'Spinner shark or blacktip shark',
#  '80-lb hooked shark',
#  "6' to 8' bull shark",
#  '1 m shark, possibly whitetip reef shark',
#  ">6 m [20'] white shark",
#  "A 2' shark was seen in the area by witnesses",
#  '"Dog shark"',
#  "0.9 m  [3'] shark",
#  "Bull shark, 2.4 m [8']",
#  'Reported by media as shark attack, but shark involvement prior to death was not confirmed',
#  '"a very large shark"',
#  'Bull shark, 1.65 m [5\'5"] was speared & killed',
#  'Lemon shark, 1.8 m [6\'] male, N. breviostris, identified by W.A. Stark II, later the same day a 6\'8" pregnant female lemon shark bit the bow of the boat',
#  "Tiger shark, 8' ",
#  '300- to 400-lb Zambesi shark',
#  " Tiger shark, 3'",
#  '2 white shark: 13\' & 9"8"',
#  "1.2 m to 1.8 m [4' to 6'] shark observed in area",
#  'White shark, 2 m',
#  "5.5' shark",
#  "Blue shark, 1.5 m [5'] ",
#  'Shark involvement not confirmed; officials considered barracua',
#  'Most likely, a small shark',
#  'Whitetip reef shark, 1m',
#  'Oceanic whitetip shark, 2.5m ',
#  '30-kg [66-lb] shark',
#  "Tiger shark, 4.6 m to 7.6 m [15' to 25'] ",
#  'reef shark, 1.5m',
#  "1.5 m [5'] dusky shark",
#  'A small spinner shark',
#  'Possibly white sharks',
#  '5 m to 7 m white shark',
#  "1.8 m [6'] Zambezi shark",
#  "5.5 m [18'] white shark, identified by witnesses & tooth marks",
#  "60 cm to 90 cm [2' to 3'] blacktip or spinner shark",
#  "White shark, 3 m [10']rk",
#  "Spinner shark, 1.2 m to 1.5 m [4' to 5'] ",
#  'Tawny nurse shark',
#  'White shark, 4 m to 5m ',
#  "White shark, 4.3 m [14'] ",
#  '1.8 m grey shark',
#  'Copper shark',
#  "Said to involve an 8' shark but more likely damage caused by debris",
#  "Bull shark caught, leg recovered & buried beside the man's body",
#  ' Bull shark, 1.2m ',
#  'Shark involvement prior to death remains unconfirmed',
#  "Hammerhead shark, 5.2 m [17'] ",
#  "6', 100-lb shark",
#  'Raggedtooth shark, 1.96 m, 140-kg ',
#  'White shark (tooth fragments recovered from hull of boat)',
#  '270 kg shark',
#  "1.8 m to 2.7 m [6' to 9'] shark",
#  "Said to be 6.4 m [21'] shark",
#  'Doubtful / Unconfirmed attack / Unable to verify in local records',
#  '"a school of sharks"',
#  'Blacktip reef shark, 1m',
#  'Oceanic whitetip shark x 2',
#  'Hammerhead sp.',
#  'small hammerhead shark',
#  "White shark, 2.5 m [8.25']  ",
#  'Said to involve a white shark but shark involvement not confirmed',
#  "Thought to involve a 12' white shark",
#  "Tiger shark, 8'",
#  'Bull shark, 400-lb ',
#  'Sand shark?',
#  "Lemon shark, 2.7 m [9'] ",
#  'whaler shark',
#  "1.2 m [4'] blacktip or sandbar shark",
#  "Grey reef shark, 2 m [6.75'] ",
#  "Tiger shark, 4 m [13']  ?",
#  'Lemon shark, >1 m ',
#  "Tiger shark, 3 m to 4 m [10' to 13'] ",
#  ' Raggedtooth shark, 2m',
#  "Blacktip or spinner shark, 4'",
#  'C. maculpinnis or C. limbatus',
#  "White shark, 5 m [16.5']",
#  "3 m [10'], 270- kg [595-lb] shark",
#  "Tiger shark, 3 to 4 m [10' to 13'] ",
#  '500-lb shark',
#  "1.8 to 2.1 m [6' to 7'] shark",
#  '"a young shark"',
#  'Tiger shark, 3.5 m ',
#  "2.4 m [8'] white shark, species identity confirmed by tooth fragment",
#  'Shark involvement prior to death could not be determined',
#  "White shark, 4.3 m [14'] (or bronze whaler)",
#  "3 m to 4 m [10' to 13'] shark",
#  ">3.4 m [11'] white shark",
#  'Tiger shark, 4 m, 420-kg, caught 13-Dec-1987',
#  'Large tiger shark seen in the vicinity the following morning',
#  '"Shark had a very large girth"',
#  'Bull shark, 2.5m',
#  'Hammerhead shark, 500-llb ',
#  ">6.7 m [22']  shark",
#  "Grey nurse shark, 8'",
#  "Tiger shark, 3 m to 4.9 m [10' to 16'] ",
#  "Tiger shark, 8' to 10' ",
#  '3 hammerhead sharks nearby',
#  "3 m [10'] white shark (Tooth  recovered from boat)",
#  ' Lemon shark, 3.5 m',
#  "3.5' to 4.5' shark",
#  "Thought to involve a 2.7 m [9'], 400-lb bull shark",
#  '2 m shark, possibly a dusky or blacktip shark',
#  'Identified as C. gangeticus by Dr. J. Fayrer',
#  '6 m  white shark',
#  "Bronze whaler shark, 3.7 m [12'] identified by G.P. Whitley based on description",
#  "Bull shark, 4' to bull shark",
#  'Leopard shark',
#  "Hammerhead shark. 6' to 7'",
#  "White shark, 10 '",
#  "White shark, 3 m to 3.7 m [10' to 12'] ",
#  "Bronze whaler shark,4 m [13'] ",
#  "White shark, 3.5 m [11.5'], identified by W. I.  Follett on tooth fragments",
#  "1.2 m [4'] hammerhead shark",
#  'Thought to involve a 5.5 m white shark named Kong',
#  "Grey nurse shark, 4'",
#  "Bronze whaler shark, 2.5 m [8.25']  k",
#  '5\'7" shark',
#  'White shark, 4.5m',
#  "6' shark, possibly a blactip or spinner shark",
#  "Blacktip shark, 5' to 6'",
#  "1.5 to 2 m [5' to 6.75'] shark",
#  "Bronze whaler shark, 1.5 m [5'] ",
#  "Tooth fragment of a white shark recovered. Authorities believed shark was 6 m [20']  total length",
#  "White shark, 4.4 m [14.5'] . ",
#  'Bull sharks x 2',
#  "White shark, 3.5 m to 4 m [11.5' to 13'] ",
#  'Thought to involve a juvenile hammerhead shark',
#  'Possibly a small blacktip shark',
#  "White shark, 3 m [10']; identifed by Dr. W.I. Follett on tooth marks",
#  "Tiger shark, 13'",
#  "0.9 m to 1.2 m [3' to 4'] white shark",
#  '3 m to 4 m white shark',
#  'Tiger shark, 3.5 m, 250-lb female',
#  ' Wobbegong shark, 1.6 to 1.8m ',
#  'Wobbegong shark, 1m',
#  "Lemon shark, 9'",
#  '150-lb shark',
#  'Tiger shark, <2 m TL',
#  'Lemon shark, 2 m [6\'9"]',
#  'Blue shark, 8 to 9 feet',
#  "1.2 m to 1.5 m [4' to 5']   shark",
#  ' Tawney nurse shark, 1m',
#  '60 cm [23.6"] blind or brown shark',
#  "1.5 m to 1.8 m  [5' to 6'] shark",
#  "0.9 m [3']  shark",
#  'Unidentified shark',
#  '4 to 5 m white shark',
#  "1.5 m to 1.8 m [5' to 6'] sharks",
#  'Thought to involve a white, bull or tiger shark',
#  'Tiger shark (pregnant)',
#  '2.27 m shark',
#  '136-kg [300-lb] shark',
#  'White shark, 5m to 6m',
#  "3.7 m to 4.3 m [12' to 14'] shark",
#  '200 to 300 kg shark',
#  "Tiger shark, 13' female",
#  "Bull shark, 1.5 m to 1.8 m [5' to 6'] ",
#  "1.5 m to 1.8 m [5' to 6']  blacktip shark",
#  "2.7 m  [9'] shark",
#  'Lesser spotted dogfish, Scyliorhinus canicula, less than 80 cm in length',
#  "4.7 m [15.5'] shark",
#  '3.5 m [11\'6"] shark captured',
#  "1.5 m to 2.1 m [5' to 7'] shark, possibly a mako shark",
#  "Five 1.8 m [6']  sharks",
#  "Mako shark, 3 m [10'] ",
#  'Tiger shark, 4.5 m [14\'9"]',
#  'Mako shark, 90kg',
#  'White shark, 4 to 5 m',
#  "Bronze whaler shark, 2 m to 3 m [6.75' to 10']  ",
#  'Shark involvement not confirmed & highly unlikely',
#  "Bitten by several 1.8 m [6'] sharks",
#  '4\' "ground shark"',
#  "Shovelnose shark, 5'",
#  "0.7 m [2.5'] sand shark",
#  "White shark, 6m [20']",
#  '>6 m white shark, according to witnesses',
#  '2 m  "yellow belly" captive shark. Shark destroyed by aquarium staff next day',
#  '36"  shark',
#  'Blacktip or spinner shark?',
#  'Though to involve a tiger shark',
#  "15'",
#  '4.5 m & 5 m white shark ',
#  '3.6 m  porbeagle shark',
#  'Possibly a lemon shark',
#  'Bronze whaler shark, 2 m to 3 m ',
#  'Lemon shark, 0.5 m',
#  '2 sharks involved',
#  '"A 2\' (0.6 m) brown shark"',
#  "2 m [6.75'] copper shark",
#  "Teeth in hull identified as those from a white shark 4.6 m [15'] in length",
#  "Tiger shark, 3 m [10']k",
#  "Zambesi shark, 1.8 m [6'] ",
#  'Reportedly: oceanic whitetip sharks, blue sharks, tiger sharks & bull sharks',
#  "White shark, 5 m [16.5'], identified by Dr. W. I. Follett on tooth marks",
#  '3 m, 600-kg shark',
#  "White shark, > 3 m [10']",
#  "1.8 m [6'] shark, possibly a blacktip",
#  "4 m [13'] shark x 6",
#  "3 m [10'] gaffed shark",
#  '3.5 to 4 m shark',
#  'Reported as a shark attack, the story was a hoax',
#  'Grey nurse shark, 2.9 m [9\'6"] ',
#  '1m to 1.2 m shark',
#  "White shark, 18' to 20'",
#  'possibly a bull shark',
#  '2.2 m shark',
#  '1.74 m, 116-kg Zambesi shark',
#  "Said to involve a 2.7 m [9'] shark",
#  'White shark, 7m',
#  "2.5 m [8.25'] bull shark",
#  'Tiger shark, 2m to 3m ',
#  '68" shark',
#  "4.3 m [14'] shark seen in area previous week",
#  "Nurse shark, 0.9 m  [3'] ",
#  "3 m to 4.5 m [10' to 15'] white shark",
#  '20 kg shark',
#  'Tiger shark, 8 to 12 feet',
#  ' a small shark',
#  '"The fish was harpooned, dried, and presented to the sailor, who went round Europe exhibiting it  It was said to be 20 feet long.',
#  '234-lb shark',
#  '193-lb shark',
#  "Dusky shark, 2.7 m [9'] dusky shark C. obscurus identified by S. Springer on tooth recovered",
#  'White shark, 4.5 m [14\'9"], identity confirmed by witness & tooth pattern',
#  ' White shark',
#  "White shark, 2.7 m to 3 m [9' to 10'] ",
#  '90-kg "blackfin" shark',
#  "Caribbean reef shark, 4.5'",
#  'Wobbegong shark, 1.6m',
#  'Considered a "Doubtful" incident',
#  'unknown, possibly a white shark',
#  ">2.4 m [8'] white shark",
#  "White shark, 5.2 m [17'], 2500-lb ",
#  'Blue shark, 1m',
#  "Nurse shark, 2.1 m [7']  identified by Dr. E. Clark on color & tooth impressions",
#  "7' silvertip shark",
#  " Galapagos shark, 6'",
#  "Bull shark, 10'",
#  "3 m to 4.3 m [10' to 14'] shark",
#  "Carpet shark, 10' ",
#  'Dooley believed his Injury was caused by stingray (Dasyatidae family)',
#  'White shark, 6 m ',
#  "1.8 m [6'] grey-colored shark",
#  "4.9 m [16']shark",
#  "3.5 m [11.5']  white shark",
#  'Possibly a 3 m bull shark',
#  "1.8 m [6'] dogfish",
#  "Hammerhead shark, 1.8 m [6'] ",
#  "14' to 18'shark",
#  "4.9 m [16'] whaler",
#  '"black tipped" shark',
#  'possibly a small blacktip shark',
#  'Possibly a blacktip shark',
#  'Grey nurse shark, 2 m',
#  "5' to 8' shark",
#  'Not authenticated',
#  'Possibly a Caribbean reef shark',
#  "8' bull shark or Caribbean reef shark",
#  '2.13 m shark',
#  "Zambesi shark, 1.2 m [4'] ",
#  "Blue shark, 3 m [10']",
#  "Tiger shark, 2.4 m to 2.7 m [8' to 9'] ",
#  "Atkins' remains were recovered from a dusky shark, C. obscurus, by Capt. W. F. Young, shark fisherman",
#  "White shark, 2.1 m [7'] ",
#  '3.7m  to 4.2 m white shark',
#  "15' shark seen with the man's body in its mouth, but shark involvement prior to death was not confirmed",
#  "Tiger shark, 3.4 m [11'] captured",
#  "White shark, 4.3 m 4.9 m [14' to 16'] ",
#  'Blue pointers',
#  'Not a shark attack; it was a hoax',
#  "2' to 3.5' shark",
#  "1,5 m [5'] Caribbean reef shark (Carcharhinus  perezi)",
#  'Fishermen recovered partial remains from shark a week later',
#  "White shark, 3 m [10'], tooth fragment from wounds identified as that of a white shark",
#  "4.5' to 5' shark",
#  "Mako shark, 3.7 m [12'] identified by tooth fragments by G.P. Whitley",
#  "Carpet shark, 5' ",
#  ">2.5 m [8.25'] white shark",
#  "Raggedtooth shark, 1.5 to 2 m [5' to 6.75']",
#  "Tiger shark, less than 10'",
#  'Possibly a blue shark',
#  "Lemon shark, 4' to 5' ",
#  "Silky shark, 6.5'",
#  "Two sharks seen in vicinity: 2.4 m & 4.25 m  [8' & 14'] TL",
#  "Caribbean reef shark, 7' to 8'",
#  "2.1 m to 2.4 m  [7' to 8'] shark",
#  'Thresher shark',
#  "3 m [10'], 200-kg [441-lb] bull shark",
#  "2.7 m [9'] silky shark",
#  'Bronze whaler sharks x 3',
#  '13\'10" shark',
#  "White shark, 5 m  to 6 m [16.5' to 20'] ",
#  "1.8 m [6']  shark",
#  "White shark, 3 m to 4 m [10' to 13'] ",
#  "Spinner shark, 3' to 4' ",
#  ' Bull shark, 2.5 m',
#  'Port Jackson shark, 1m',
#  "Hammerhead shark, 2.4 m [8'], according to lifeguard Sam Barrows",
#  'White shark, 5.5 m ',
#  'Believed white shark and other smaller species of sharks involved.',
#  "Possibly a 5' to 6' sandtiger shark",
#  "White shark, 2.3 m [7.5'], tooth fragment recovered",
#  'White shark, species identity confirmed by tooth pattern',
#  "4 m to 5 m [13' to 16.5']  white shark",
#  'Raggedtooth shark, >1 m ',
#  "Next morning a 3 m [10'] shark was caught that had Andrews' leg in its gut",
#  'Dusky shark, 2m',
#  'Blue shark, 2m ',
#  "1.2 m [4'] shark hindered recovery of body",
#  'Small shark with white-tipped dorsal fin',
#  "3.7 m [12'] shark & may have been another shark nearby",
#  '3.3 m [10\'9"] shark',
#  'Possibly a small hammerhead shark',
#  'Hammerhead shark.',
#  "16' 800-lb shark",
#  "Two shark's teeth recovered from canoe",
#  'Tiger shark, 12',
#  "White shark, 12' to 15'",
#  "1.5' to 2' shark",
#  "White shark, 4 m [13'] rk",
#  'A large hammerhead shark',
#  '"grey shark"',
#  "7.5' shark",
#  '400-lb shark',
#  'Juvenile dusky or blacktip shark',
#  "4.5 m to 5.5 m [14.7' to 18'] white shark",
#  'Lemon shark or sandtiger shark',
#  'Mako shark, 180-kg [397-lb]',
#  "Thresher shark, 3.7 m [12'] ",
#  "12' sandtiger shark",
#  "Nurse shark, 1.5 m [5']",
#  'Shark seen feeding on turtle scraps thrown overboard prior to incident.',
#  "3.7 to 4.5 m [12' to 15'] shark seen in vicinity",
#  "1.8 m [6'] white shark",
#  "1.5 to 2.5 m [5' to 8.25'] copper shark",
#  '"a black-tipped shark"',
#  "12' white shark",
#  "2 m to 2.5 m [6.75'  to 8.25'] sixgill or sevengill shark",
#  '4.5 m [14\'9"] white shark',
#  'Large tiger shark',
#  '1.5 m white-tipped reef shark',
#  "White shark, 3.7 m to 4.6 m [12' to 15'] ",
#  'Wobbegong shark, 2 m ',
#  "7' to 8' bull shark",
#  '80-lb sand shark',
#  "White shark, 5' to 6' juvenile ",
#  "Nurse shark, 0.94 m to 1.2 m [3' to 4'] ",
#  'White shark, 3m ',
#  'Raggedtooth shark, 2.5m ',
#  "Whaler shark, 4 m [13'] ",
#  'Blacktail reef shark',
#  "0.9 m [3'] shark,  probably a blacktip or spinner shark",
#  "Possibly a 5' to 6' bull shark",
#  'Thought to involve a mako or grey nurse shark',
#  "Blue shark, 7'",
#  "3 m [10'] sharks",
#  "White shark, 3 m [10'] k",
#  "3' to 3.5' shark",
#  'Unknown, but it was reported that a shark tooth was recovered from the wound',
#  'Silvertip shark',
#  "3.5 m [11.5']shark",
#  " Bull shark, 8'",
#  "Blue shark, 8' [2.4 m], 500-lb ",
#  'White shark, 5m ',
#  '4.2 m white shark',
#  'White shark, 4.5 m [14\'9"] ',
#  'Raggedtooth shark, 1.3 m',
#  'White shark, 2m ',
#  "4.5 to 5' shark",
#  'a small reef shark',
#  'White shark, 15\'3", 2,333-lb ',
#  "White shark, 15' to 16' ",
#  "Tiger shark, 12' ?",
#  "1.2 m [4'] shark (spinner shark?)",
#  'Oceanic whitetip shar,; identified by Dr. W.C. Schoeder on photograph & Dr. L.P. L. Schultz on sketch by observer',
#  "1.8 m to 2.4 m [6' to 8'] white shark",
#  "Nurse shark, 2' to 3' ",
#  "Raggedtooth shark, 50-kg [110-lb], 2 m [6.75'] gaffed ",
#  "Two 2.1 m [7'] sharks",
#  'Grey reef shark ',
#  '4.3 m shark',
#  "1.8 m [6'] sandtiger shark",
#  'White shark, 600-kg [1323-lb]',
#  'Bull shark, 1.8m',
#  '4.5  m [14\'9"] shark',
#  "2.4 m [8'] whaler shark",
#  '1.2 m [4\'] "grey-colored shark"',
#  'Grey nurse shark, 1m ',
#  'White shark, 2 m to 4 m [6\'9" to 13\'] ',
#  "Tiger shark, 4.3 m [14'], 3 tooth fragments retrieved from his wounds",
#  ...]

# %%
# Convert whole column to lowercase

df["Species"] = df["Species"].str.lower()

# %%
# Keep only letters excluding single m

#stop_words = ["thought", "large", "small", "�", "named", "of", "to","lb ", " lb", "m ", " m", "or", "a ", "not","confirmed", "injury", "may", "be", "due", "stringray", "probable", "but", "kg", "possibly", "said", "involve","identity","confirmed", "by", "tooth", "pattern"]
stop_words = [" m ", "m ", "lb"]

df["nSpecies"] = df["Species"]
for i in stop_words:

    df.loc[~df["nSpecies"].isna() , ["nSpecies"]] = df["nSpecies"].str.replace(i,"")

# %%
# Remove numbers

df.loc[~df["nSpecies"].isna() , ["nSpecies"]] = df["nSpecies"].str.replace(r"[0-9]+","",regex=True)

# %%
# Remove special characters

df.loc[~df["nSpecies"].isna() , ["nSpecies"]] = df["nSpecies"].str.replace(r"[.',?\[\]\"-><]+","",regex=True)

# %%
# Remove one and two letter words

df.loc[~df["nSpecies"].isna() , ["nSpecies"]] = df["nSpecies"].str.replace(r"\b[a-zA-Z]{1,2}\b","",regex=True)

# %%
# Remove trailing whitespaces

df.loc[~df["nSpecies"].isna() , ["nSpecies"]] = df["nSpecies"].str.strip()

# %%
list(df["nSpecies"].value_counts().index)
# Out:
# ['shark',
#  'white shark',
#  'tiger shark',
#  'bull shark',
#  'shark involvement not confirmed',
#  'bronze whaler shark',
#  'blacktip shark',
#  'nurse shark',
#  'small shark',
#  'raggedtooth shark',
#  'wobbegong shark',
#  'mako shark',
#  'grey nurse shark',
#  'blue shark',
#  'hammerhead shark',
#  'zambesi shark',
#  'lemon shark',
#  'shark involvement',
#  'sandtiger shark',
#  'sand shark',
#  'spinner shark',
#  'sharks',
#  'grey reef shark',
#  'reef shark',
#  'oceanic whitetip shark',
#  'blacktip  spinner shark',
#  'caribbean reef shark',
#  'blacktip reef shark',
#  '',
#  'sevengill shark',
#  'unidentified species',
#  'dusky shark',
#  'carpet shark',
#  'basking shark',
#  'thought  involve  zambesi shark',
#  'small sharks',
#  'dog shark',
#  'blue pointer',
#  'copper shark',
#  'angel shark',
#  'possibly  bull shark',
#  'porbeagle shark',
#  'juvenile shark',
#  'possibly  juvenile blacktip  spinner shark',
#  'shark involvement prior  death not confirmed',
#  'greycolored shark',
#  'gill shark',
#  'sandbar shark',
#  'small blacktip shark',
#  'thought  involve  white shark',
#  'shortfin mako shark',
#  'whaler shark',
#  'galapagos shark',
#  'shark seen  vicinity',
#  'silky shark',
#  'hammerhead',
#  'white shark according  witnesses',
#  'bull  tiger shark',
#  'bull shark suspected due  freshwater habitat',
#  'reported  involve  white shark',
#  'unidentified',
#  'questionable incident',
#  'possibly  bronze whaler shark',
#  'tiger shark  female',
#  'thought  involve   white shark',
#  'pack   sharks',
#  'said  involve   shark',
#  'whitetip reef shark',
#  'thresher shark',
#  'white sharks',
#  'shark involvement prior  death was not confirmed',
#  'foot shark',
#  'thought  involve  tiger shark',
#  'sevengill  shark',
#  'shark seen  the vicinity',
#  'possibly   bull shark',
#  'bull shark  caribbean reef shark',
#  'thought  involve  bull shark',
#  'said  involve   white shark',
#  'shark involvement suspected but not confirmed',
#  'white shark tooth fragments recovered',
#  'salmon shark',
#  'small nurse shark',
#  'sharks averaged   length',
#  'possibly  spinner shark',
#  'bull sharks',
#  'school  sharks',
#  'small hammerhead shark',
#  'wobbegong',
#  'white shark tooth fragment recovered',
#  'whale shark',
#  'possibly   blacktip  spinner shark',
#  'possibly  leucas',
#  'shark involvement doubtful',
#  'female shark',
#  'silvertip shark',
#  'shovelnose shark',
#  'said     shark',
#  'shark involvement probable',
#  'white shark  tooth fragment recovered',
#  'large shark',
#  'bronze whaler',
#  'grey shark',
#  'shark probable bull shark',
#  'possibly  sand shark',
#  'juvenile dusky shark',
#  'reported  involve  hammerhead shark',
#  '�',
#  '�small� shark',
#  'possibly  bull shark  tiger shark',
#  'said  involve      white shark',
#  'shark involvement unconfirmed',
#  'possibly  small blacktip shark',
#  'white shark named �spotty�',
#  'tawny nurse shark',
#  'white shark identification   nakaya',
#  'large white shark was filmed  divers   local wreck  days prior  the incident',
#  'said  involve  sharks',
#  'oceanic whitetip shark  female',
#  'shark involvement not cofirmed',
#  'survivors said  species  sharks were involved  oceanic whitetip sharks and another species',
#  'shark involvement questionable',
#  'white shark   bronze whaler',
#  'thought  involve  bronze whale shark',
#  'shark possibly whitetip reef shark',
#  'shark tooth fragments recovered',
#  'shark involvement prior  death could not  determined',
#  'small slibrown shark',
#  'bronze whaler shark   juvenile',
#  'unidentified shark',
#  'hammerhead sharko',
#  'spinner  bull shark',
#  'wobbegong shark  barbatus   identified   whitley',
#  'tiger shark tooth fragment recovered',
#  'white shark   based  tooth pattern',
#  'white shark   female',
#  'bitten  several  sharks',
#  'white shark  species identity confirmed  tooth fragment',
#  'tiger shark said',
#  'raggedtooth shark  yearold captive female',
#  'cow shark',
#  'bronze whaler shark  identified  clyde buttery',
#  'reported  involve   shark possibly  white shark',
#  'shark possibly  mako shark',
#  'thought  involve    tubar�  gralha preta    blacktip shark  limbatus',
#  'shark involvement not confirmed  highly unlikely',
#  'tiger shark  others',
#  'blue shark    feet',
#  'bull sharks     length',
#  'lemon shark  bull shark',
#  'less than',
#  'sharks attacked survivors  the water',
#  'shark possibly  blactip  spinner shark',
#  'sharks teeth found embedded  the woodwork  the boat',
#  'lemon shark  female',
#  'remains recovered fro sharks',
#  'possibly  porbeagle shark',
#  'bronze whaler  tiger shark',
#  'blue  porbeagle shark',
#  'teeth  hull identified  those froa white shark   length',
#  'white shark  identity confirmed  tooth fragment witness and photograph  captured shark',
#  'female white shark named notchfin',
#  'spurdog',
#  'shark involvement not confirmed officials considered barracua',
#  'thought  involve  mako shark but possibly  sea lion',
#  'macrurus captured  hours after attack with tissue removed froman  its gut species identified   whitley  reported   obscurus    steel',
#  'mako shark tooth fragments recovered',
#  'shark possibly  dusky shark',
#  'thought  involve  mako  grey nurse shark',
#  'possibly  caribbean reef shark',
#  'jan his remains washed ashore   tiger shark thought   involved',
#  'five   sharks',
#  'zambezi shark tooth fragments recovered',
#  'tooth fragment   white shark recovered authorities believed shark was   total length',
#  'cto     bite diameter just below left knee',
#  'hammerhead shark then    other sharks were said    involved',
#  'blind  brown shark',
#  'small bull sharks',
#  'nurse shark   identified    clark  description  shark',
#  'shark species identity questionable',
#  'shark involvement  questionable',
#  'remains recovered fro white shark',
#  'porbeagle  white shark',
#  'white shark  oceanic whitetip shark',
#  'alleged  involve  white shark',
#  'large tiger shark seen  the vicinity the following morning',
#  'white shark  bronze whaler',
#  'two  sharks',
#  'blacktip shark pup',
#  'said  involve   blue shark',
#  'said  involve  grey nurse shark that leapt out  the water and  seized the boy but species identification  questionable',
#  'white shark species identity confirmed  tooth pattern',
#  'zambesi shark   female',
#  'blue nosed shark',
#  'white shark   immature female previously injured',
#  'said  involve  white shark but shark involvement not confirmed',
#  'soupfin shark',
#  'lemon shark  male  breviostris identified   stark  later the same day   pregnant female lemon shark bit the bow  the boat',
#  'reef shark        greycolored shark',
#  'blue nose shark',
#  'caribbean reef sharks',
#  'tiger shark  captured',
#  'small dusky shark  blackfin shark',
#  'sharks most were oceanic whitetip sharks',
#  'mako shark  tooth fragment recovered  identified   nichols',
#  'sixgill  sevengill shark',
#  'shark  sharks serrated tooth recovered frotoe',
#  'shark involvement prior  death remains unconfirmed',
#  'said  involve  large mako shark',
#  'hammerhead  bonnethed shark',
#  'sandtiger shark   male',
#  'blue shark bites present',
#  'shark possibly  dusky  blacktip shark',
#  'white shark  identifed    follett  tooth marks',
#  'white shark white shark',
#  'shark seen  area previous week',
#  'questionable',
#  'gummy shark rhizoprionodon  loxodon',
#  'thought  involve   lemon shark two lemon sharks caught within  yds  the site  week prior    week after this incident',
#  'white shark   male',
#  'lemon shark  sandtiger shark',
#  'shovelnosed guitarfish',
#  'ground shark',
#  'said  involve  oceanic whitetip shark',
#  'nurse shark   identified     schultz  photograph',
#  'cto     blacktip  spinner shark',
#  'tawney nurse shark',
#  'salmon shark suspected but unlikely',
#  'white shark  sevengill shark',
#  'blue whaler',
#  'shark caught later',
#  'possibly  white shark',
#  'possibly  blacktip shark',
#  'said  involve   shark but more likely damage caused  debris',
#  'possibly  sandbar shark  small blacktip shark',
#  'leopard shark  triakis semifasciata identified   dewitt',
#  'tintorero',
#  'shark known  old tom',
#  'small shark with whitetipped dorsal fin',
#  'spinner  blacktip sharks',
#  'thought  involve  blacktip shark',
#  'whaler shark captured  days later with his remains  its gut',
#  'species unidentified',
#  'nurse shark juvenile',
#  'allegedly  foot shark',
#  'fishermen recovered partial remains froshark  week later',
#  'whaler',
#  'thought  involve    bull shark',
#  'cto     shark',
#  'believed white shark and other smaller species  sharks involved',
#  'captive shark',
#  'hooked shark',
#  'not authenticated',
#  'shark involvement not confirmed injury may  due   stingray',
#  'blackfin shark',
#  'blue shark bites post mortem',
#  'tiger shark  tooth fragment recovered frowound',
#  'maculpinnis   limbatus',
#  'dead blue shark',
#  'possibly  small hammerhead shark',
#  'shark had  very large girth',
#  'white shark  gill shark',
#  'dooley believed his injury was caused  stingray dasyatidae family',
#  'szots right hand found     tiger shark caught   safety bay south  freemantle',
#  'possibly     sandtiger shark',
#  'shovelnose guitarfish adult male',
#  'possibly juvenile tiger shark',
#  'shark later captured  mitchellhedges',
#  'said  involve hammerhead sharks',
#  'gaffed shark',
#  'shark involvement  not confirmed',
#  'atkins remains were recovered froa dusky shark  obscurus  capt   young shark fisherman',
#  'leopard shark',
#  'small reef shark',
#  'small browncolored shark',
#  'unknown possibly  white shark',
#  'possibly   blacktip shark',
#  'black tipped shark',
#  'said  involve   red shark',
#  'raggedtooth shark    gaffed',
#  'shark hindered recovery  body',
#  'gray reef shark',
#  'said  involved      shark',
#  'reported   shark attack the story was  hoax',
#  'white shark based  bite pattern',
#  'blacktip  sandbar shark',
#  'shark  may have been another shark nearby',
#  'white shark  mtooth fragment  recovered frothe hull',
#  'hammerhead sharks nearby',
#  'shark involvement prior  death still   determined',
#  'white shark tooth fragment recovered froankle  identified     follett',
#  'white shark   according  witnesses',
#  'two     sharks',
#  'shark possibly  tiger shark',
#  'port jackson shark',
#  'white shark species identity confirmed  tooth fragment',
#  'thought  involve  oceanic whitetip shark   white shark',
#  'blue sharks',
#  'not  shark attack  was  hoax',
#  'tiger shark   tooth fragments retrieved frohis wounds',
#  'whaler shark      identified   whitley',
#  'shark with  very flat head� that had followed the boat for  days',
#  'white shark identified  tooth pattern',
#  'comrades saw sharks tail appear about  away',
#  'lemon shark     tooth fragment recovered',
#  'tooth fragments  �whaler� shark were recovered  bull shark according  edwards',
#  'white shark     male',
#  'yellow belly captive shark shark destroyed  aquariustaff next day',
#  'white shark tooth fragments recovered frohull  boat',
#  'white shark   tooth fragment recovered frovictims shoulder  identified   nicholls',
#  'shark possibly  bull shark',
#  'sharks involved',
#  'thought  involve  cookie cutter shark',
#  'long thin browncolored shark',
#  'possibly     bull shark',
#  'bull sandbar  dusky shark',
#  'grey reef shark identified   menisorrah   hobson  mautin   reese',
#  'several sharks involved',
#  'blacktip shark  spinner shark',
#  'bronze whaler shark  identified   whitley based  description',
#  'little shark',
#  'spinner shark  blacktip shark',
#  'probable bluefish bite',
#  'blue shark  blue shark',
#  'unknown',
#  'said  involve  grey nurse shark',
#  'shark involvement not confirmed injury may have been caused   bluefish',
#  'tiger shark    caught dec',
#  'lemon shark   immature male identified    springer',
#  'unknown but  was reported that  shark tooth was recovered frothe wound',
#  'white shark  identified     follett  tooth marks',
#  'identified  carcharinid shark based  its behavior     schultz mako shark according  huges',
#  'said  involve  shark',
#  'lemon shark  identified   the surfer',
#  'hammerhead shark  according  lifeguard sabarrows',
#  'tiger shark    feet',
#  'juvenile dusky  blacktip shark',
#  'dogfish',
#  'description  shark does not ring true',
#  'white shark      according  shreuder and  witness',
#  'tiger shark    female',
#  'hooked  shot white shark',
#  'bronze whaler sharks',
#  'bull shark  lemon shark',
#  'longfin mako shark',
#  'reported  involve  bull shark',
#  'zambezi shark',
#  'tiger shark caught  hours later with shorts  the boy  its gut',
#  'small spotted catshark scyliorhinus canicula',
#  'shark was seen  the area  witnesses',
#  'bull  lemon shark',
#  'white shark  thresher shark',
#  'shark  shark',
#  'tiger shark caught  days later with diver� remains  its gut',
#  'blue whaler galeolamna',
#  'said   �leopard sharks� more probably tiger sharks',
#  'shark captured',
#  'said    shark',
#  'blacktip shark  caribbean reef shark',
#  'nurse shark   identified    clark  color  tooth impressions',
#  'six zambesi sharks seen    length',
#  'allegedly  tiger shark',
#  'two  oceanic whitetip sharks',
#  'white shark    female',
#  'possibly  hammerhead shark',
#  'dogfish shark',
#  'thought  involve  porbeagle  mako shark',
#  'his hand was found    tiger shark caught',
#  'days later   shark was caught  yards frothe site',
#  'shark involvement probable but not confirmed',
#  'whitetipped reef shark',
#  'white shark tooth  recovered froboat',
#  'white shark   identity confirmed  tooth pattern',
#  'tiger sharks  area',
#  'next morning   shark was caught that had andrews leg  its gut',
#  'tiger shark     female contained girvans remains',
#  'white shark       identified    shroeder based  tooth fragment ebedded  gunwale',
#  'reported  media  shark attack but shark involvement prior  death was not confirmed',
#  'grey reef shark  grey reef shark identified     schultz based  photographs identified   melanopterus  stewart',
#  'possibly  lemon shark',
#  'mako shark aka bonito shark',
#  'alleged  involve  white shark with little yellow eyes',
#  'possibly  broadnose gill shark',
#  '� caribbean reef shark',
#  'metre shark',
#  'thought  involve     shark but shark involvement not confirmed',
#  'large hammerhead shark',
#  'blue pointers',
#  'small carpet shark',
#  'whale',
#  'white shark  female',
#  'possibly  blue shark',
#  'identified   gangeticus    fayrer',
#  'shark possibly  spinner shark',
#  'shark shark caught  its jaw exhibited  the carnegie museum',
#  'white shark  tooth fragment frowounds identified  that   white shark',
#  'bonita sharkk',
#  'shark seen feeding  turtle scraps thrown overboard prior  incident',
#  'tiger sharks',
#  'shark involvement  his death uncofirmed',
#  'white shark      male',
#  'according  carlsmith the sharks mouth was  wide',
#  'possibly   lemon shark',
#  'caribbean reef shark carcharhinus  perezi',
#  'leucas tooth fragment recovered frokayak',
#  'mako shark  identified  tooth fragments   whitley',
#  'banjo shark',
#  'white shark species identity confirmed  witnesses  tooth pattern  surfboard',
#  'tooth fragments recovered frohull',
#  'juvenile white shark',
#  'white shark according  tooth pattern and witnesses',
#  'nurse shark  cto',
#  'remains recovered  days later',
#  'black finned shark',
#  'white shark  identified     follett  tooth fragments',
#  'female blue fin shark',
#  'doubtful  unconfirmed attack  unable  verify  local records',
#  'blacktipped shark',
#  'shark observed  area',
#  'broadnose sevengill shark',
#  'cookie cutter shark',
#  'bull shark  was captured  dragged  the sand where tissue taken froeggink was found  its gut species identification  was made   springer based   photographs  the shark',
#  'species unknown possible white shark',
#  'thought  involve   grey nurse shark',
#  'blue nose sharks',
#  'possibly  larger shark',
#  'said  involve   white shark but thought  that  was more likely  blue shark',
#  'shark landed  hours later',
#  'small catsharks',
#  'white shark identified   hugh smith',
#  'mako shark   identified     schultz  photograph',
#  'remains found     shark caught  baker� haulover miami beach  oct',
#  'starry smoothhound shark',
#  'nurse shark    male',
#  'aimarginatus',
#  'bull shark identified  capt  gray',
#  'white shark    juvenile',
#  'thought  involve   bull shark',
#  'shark possibly  blacktip',
#  'said  involve white shark but species identify questionable',
#  'blacktail reef shark',
#  'tiger shark pregnant',
#  'possibly    zambezi shark',
#  'said  involve  tiger shark',
#  'attacked   number  sharks',
#  'bull shark according  some  the divers  the boat',
#  'brown shark',
#  'sand shark listed  questionable incident',
#  'tiger shark less than',
#  'blacktip reef shark pup',
#  'bull shark caught leg recovered  buried beside the mans body',
#  'horn shark heterodontus francisci',
#  'shark either  bronze whaler   grey nurse shark',
#  'very large shark',
#  'possibly white sharks',
#  'bluenosed shark',
#  'possibly     blacktip  spinner shark',
#  'unknown but the shark was caught and put  exhibition',
#  'gray shark',
#  'white shark identified  witnesses  tooth marks',
#  'anglers fronew zealand caught     shark  the same spot  was believed this was the same shark that killed alysha',
#  'white shark  seen  area and hooked  days later',
#  'small bull shark',
#  '�small brown shark�',
#  'though  involve  tiger shark',
#  'believed  involve   white shark',
#  'thought  involve bull sharks',
#  'thought  involve  juvenile hammerhead shark',
#  'scalloped hammerhead sharks',
#  'though  involve  white shark',
#  'possiby white shark',
#  'bull shark  was speared  killed',
#  'shark seen with the mans body  its mouth but shark involvement prior  death was not confirmed',
#  'thought  involve  white shark named kong',
#  'remains recovered froshark caught days later',
#  'bull shark   bull shark',
#  'considered  doubtful incident',
#  'sevengill shark  was caught  the vicinity',
#  'grey colored shark',
#  'small blue shark',
#  'mako shark gaffed',
#  'burgess  isaf announced the injury was the bite      year old white shark subsequent investigation revealed there was   shark involvement  this incident',
#  'most likely  small shark',
#  'species unknown possibly  white shark',
#  'two sharks teeth recovered frocanoe',
#  'questionable incident  shark bite may have precipitated drowning',
#  'shark  probably  blacktip  spinner shark',
#  'said  involve  tiger shark   hammerhead shark',
#  'unconfirmed incident',
#  'tiger sharks  bull sharks  sharks  all',
#  'reportedly oceanic whitetip sharks blue sharks tiger sharks  bull sharks',
#  'sandshark',
#  'white shark identified   smale',
#  'possibly  tiger shark',
#  'lesser spotted dogfish scyliorhinus canicula less than  cin length',
#  'tiger shark    shark',
#  'great hammerhead shark',
#  'whtietip reef shark',
#  'shark spinner shark',
#  'mako shark      with hook  wire leader caught  mouth',
#  'moreno� leg   part  his swisuit found   shark caught two hours after the attack identified  carcharhinid shark   schultz   limbaugh  photograph',
#  'thresher  blue shark the shark  was killed following the incident',
#  'raggedtooth shark  tooth fragment recovered',
#  'grey reef shark identified   hobson  mautin   reese',
#  'thought  involve  bull  tiger shark',
#  'white shark  identity confirmed  witness  tooth pattern',
#  'large tiger shark',
#  'possibily     sandtiger shark',
#  'questionable incident reported  shark attack but thought  involve  pinniped instead',
#  'shark was said  �have  very rough ��thick skin�',
#  'miami   cblacktip  shark and two  cbamboo catsharks',
#  'possibly  blacktip reef shark',
#  'said  involve   hammerhead shark',
#  'numerous dusky sharks         tiger shark',
#  'according  benjamin the injury was inflicted   barracuda not  shark',
#  'local authorities speculated that the water was too cold for sharks but    pregnant sandbar shark was caught next day',
#  'goblin shark',
#  'yearold pound pregnant blacktip reef shark',
#  'spinner  blacktip shark',
#  'small spinner shark',
#  'bronze whaler shark   tooth was embedded  the speargun',
#  'thought  involve  small sand shark',
#  'shark possibly   blacktip  spinner shark',
#  'porbeagle',
#  'white shark identified  tooth fragments  surfboard',
#  'said    �small shark�',
#  'hand found  gut      galapagos shark  galapagensis',
#  'pack  sharks',
#  'young shark',
#  'dusky shark  dusky shark  obscurus identified   springer  tooth recovered',
#  'hammerhead shark   zygena identified   limbaugh  description',
#  'oceanic whitetip sharks were  the vicinity',
#  'blacktip shark  maculipinnis',
#  'shark involvement prior  death unconfired',
#  'white shark  species identity confirmed  witnesses  tooth pattern  leg  board',
#  'shark with blacktipped pectoral fins',
#  'two sharks seen  vicinity',
#  'thought  involve  white bull  tiger shark',
#  'shark tooth fragment recovered frohand',
#  'wobbegongs',
#  'oceanic whitetip shar identified    schoeder  photograph     schultz  sketch  observer',
#  'white shark based   teeth retrieved frorudder',
#  'the fish was harpooned dried and presented  the sailor who went round europe exhibiting    was said    feet long',
#  'white shark      according  witnesses',
#  'shark involvement not confirmed thought    barracuda bite',
#  'cocktail shark',
#  '�speareye� shark',
#  'shark possibly  bronze whaler',
#  'whiptail shark thresher shark']

# %%
# List of shark species

shark_list = ["thresher", "grey","small","foot","goblin","silvertip","sevengill", "cocktail","bonita","whale","basket","angel","dog", "leopard","shovelnose", "red","raggedtooth","gummy", "bronze whaler", "galapagos", "sand", "wobbegong", "white ", "tiger", "lemon", "blue", "gray", "hammerhead", "spinner", "brown", "whitetip", "blacktip", "bull", "zambezi", "banjo", "nurse", "blue nose", "salmon", "mako", "blue pointer","porbeagle", "cow", "reef","smoothhound", "dogfish", "dusky"]

# new column
df["mSpecies"] = df["nSpecies"]

# find shark species 
for i in shark_list:
    df.loc[df["nSpecies"].str.contains(i).fillna(False), ["mSpecies"]] = i


# Drop all values not in shark list

df = df[df['mSpecies'].isin(shark_list)]

# %%
df = df.drop(columns=["Time","original order","nSpecies","Species"])

# %%
df = df.reset_index()

# %%
df.dtypes
# Out:
# index                              int64
# Date                      datetime64[ns]
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex_Male                          object
# Age                               object
# Injury                            object
# Fatal                             object
# Investigator or Source            object
# href                              object
# newAge                            object
# time_hours                        object
# mSpecies                          object
# dtype: object

# %%
# Make Sex Male, Age and Fatal to numeric

df['Sex_Male'] = pd.to_numeric(df['Sex_Male'], errors='coerce')
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
df['Fatal'] = pd.to_numeric(df['Fatal'], errors='coerce')
df['time_hours'] = pd.to_numeric(df['time_hours'], errors='coerce')

# %%
# Check numeric columns with describe

df.describe()
# Out:
#              index     Sex_Male          Age        Fatal   time_hours
# count  1916.000000  1749.000000  1245.000000  1899.000000  1751.000000
# mean   2387.072547     0.889651    28.714859     0.164824     7.556254
# std    1477.759363     0.313414    13.512938     0.371119     6.409467
# min       7.000000     0.000000     3.000000     0.000000     1.000000
# 25%    1191.750000     1.000000    19.000000     0.000000     1.000000
# 50%    2296.000000     1.000000    25.000000     0.000000     8.000000
# 75%    3508.750000     1.000000    37.000000     0.000000    14.000000
# max    5986.000000     1.000000    84.000000     1.000000    23.000000

# %%
df = df.drop(columns="index")

# %%
# display fraction of missing cell count per column of total cells


null_columns = df.isna().sum()
null_columns[null_columns.gt(0)]/len(df)
# Out:
# Date                      0.038100
# Country                   0.001566
# Area                      0.038622
# Location                  0.045407
# Activity                  0.049061
# Name                      0.016701
# Sex_Male                  0.087161
# Age                       0.350209
# Injury                    0.002088
# Fatal                     0.008873
# Investigator or Source    0.001566
# newAge                    0.002610
# time_hours                0.086117
# dtype: float64

# %%
# Only column with high number of missing values is Age, which is not very important. 
# It is probably still a representative subset.
# Therefore nan rows or column are not dropped

# %%
# Rename mSpecies to Species and newAge to Age and time_hours to Time_Hours

df = df.rename(columns={"mSpecies":"Species", "newAge":"Age", "time_hours":"Time_Hours"})

# %%
df
# Out:
#            Date        Type    Country             Area  \
# 0    2016-09-07  Unprovoked        USA           Hawaii
# 1    2016-09-01  Unprovoked        USA       California
# 2    2016-08-29  Unprovoked        USA          Florida
# 3    2016-08-27  Unprovoked    REUNION              NaN
# 4    2016-08-06  Unprovoked        USA           Hawaii
# ...         ...         ...        ...              ...
# 1911        NaT  Unprovoked     BELIZE              NaN
# 1912 1906-01-01  Unprovoked  AUSTRALIA              NaN
# 1913 1906-01-01  Unprovoked  AUSTRALIA              NaN
# 1914 1906-01-01  Unprovoked  AUSTRALIA              NaN
# 1915 1906-01-01  Unprovoked  AUSTRALIA  New South Wales
#
#                                        Location           Activity  \
# 0                                  Makaha, Oahu           Swimming
# 1     Refugio State Beach, Santa Barbara County       Spearfishing
# 2              New Smyrna Beach, Volusia County            Surfing
# 3                                  Boucan Canot            Surfing
# 4                                          Maui  SUP Foil boarding
# ...                                         ...                ...
# 1911                                        NaN           Standing
# 1912                                        NaN            Fishing
# 1913                                        NaN            Fishing
# 1914                                        NaN            Fishing
# 1915                                                      Swimming
#
#                    Name  Sex_Male   Age  \
# 0                female       0.0  51.0
# 1      Tyler McQuillen        1.0  22.0
# 2         Sam Cumiskey        1.0  25.0
# 3     Laurent Chardard        1.0  20.0
# 4         Connor Baxter       1.0  21.0
# ...                 ...       ...   ...
# 1911          a servant       1.0  16.0
# 1912                boy       1.0   NaN
# 1913          fisherman       1.0   NaN
# 1914          fisherman       1.0   NaN
# 1915           Arab boy       1.0   NaN
#
#                                                  Injury  Fatal  \
# 0              Severe lacerations to shoulder & forearm    0.0
# 1                           Two toes broken & lacerated    0.0
# 2                             Lacerations to right foot    0.0
# 3             Right arm severed, ankle severely bitten     0.0
# 4                      No inury, shark & board collided    0.0
# ...                                                 ...    ...
# 1911                                              FATAL    1.0
# 1912  FATAL, knocked overboard by tail of shark & ca...    1.0
# 1913                                              FATAL    1.0
# 1914                                              FATAL    1.0
# 1915                                              FATAL    1.0
#
#                                  Investigator or Source  \
# 0                             Hawaii News Now, 9/7/2016
# 1                                      R. Collier, GSAF
# 2                               News Channel 8, 8/30/16
# 3                                  LaDepeche, 8/29/2016
# 4                                         SUP, 8/9/2015
# ...                                                 ...
# 1911                                    Mitchell-Hedges
# 1912  NY Sun, 9/9/1906, referring to account by Loui...
# 1913  NY Sun, 9/9/1906, referring to account by Loui...
# 1914  NY Sun, 9/9/1906, referring to account by Loui...
# 1915  L. Becke in New York Sun, 9/9/1906; L. Schultz...
#
#                                                    href Age  Time_Hours  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  51        14.0
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...  22         1.0
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...  25        15.0
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...  20        17.0
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...  21         1.0
# ...                                                 ...  ..         ...
# 1911  http://sharkattackfile.net/spreadsheets/pdf_di...  16         1.0
# 1912  http://sharkattackfile.net/spreadsheets/pdf_di...   1         1.0
# 1913  http://sharkattackfile.net/spreadsheets/pdf_di...   1         1.0
# 1914  http://sharkattackfile.net/spreadsheets/pdf_di...   1         1.0
# 1915  http://sharkattackfile.net/spreadsheets/pdf_di...   1         1.0
#
#            Species
# 0            tiger
# 1           white
# 2             bull
# 3             bull
# 4            tiger
# ...            ...
# 1911         tiger
# 1912  blue pointer
# 1913  blue pointer
# 1914  blue pointer
# 1915         nurse
#
# [1916 rows x 16 columns]

# %%
# Export as csv

df.to_csv("sharkattack_clean.csv")
