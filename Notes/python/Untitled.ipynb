# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("vehicles_messy.csv", low_memory=False)

# %%
df.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                       createdOn                    modifiedOn  startStop  \
# ...

# %%
df.describe()
# Out:
#           barrels08    barrelsA08  charge120     charge240        city08  \
# count  37843.000000  37843.000000    37843.0  37843.000000  37843.000000
# mean      17.532506      0.216169        0.0      0.023531     17.941389
# std        4.575950      1.141527        0.0      0.427647      6.660360
# min        0.060000      0.000000        0.0      0.000000      6.000000
# 25%       14.330870      0.000000        0.0      0.000000     15.000000
# 50%       17.347895      0.000000        0.0      0.000000     17.000000
# 75%       20.600625      0.000000        0.0      0.000000     20.000000
# max       47.087143     18.311667        0.0     12.000000    138.000000
#
#             city08U       cityA08      cityA08U        cityCD         cityE  \
# count  37843.000000  37843.000000  37843.000000  37843.000000  37843.000000
# mean       4.042737      0.520149      0.327163      0.000406      0.184790
# std        9.645820      3.837874      3.542596      0.039918      2.904558
# ...

# %% [markdown]
# ## 1. Missing values

# %%
df.isna()
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0          False       False      False      False   False    False    False
# 1          False       False      False      False   False    False    False
# 2          False       False      False      False   False    False    False
# 3          False       False      False      False   False    False    False
# 4          False       False      False      False   False    False    False
# ...          ...         ...        ...        ...     ...      ...      ...
# 37838      False       False      False      False   False    False    False
# 37839      False       False      False      False   False    False    False
# 37840      False       False      False      False   False    False    False
# 37841      False       False      False      False   False    False    False
# 37842      False       False      False      False   False    False    False
#
# ...

# %%
df.isna().sum()
# Out:
# barrels08         0
# barrelsA08        0
# charge120         0
# charge240         0
# city08            0
#               ...
# modifiedOn        0
# startStop     31705
# phevCity          0
# phevHwy           0
# phevComb          0
# Length: 83, dtype: int64

# %%
null_columns = df.isna().sum()
null_columns[null_columns.gt(0)]
# Out:
# cylinders       123
# displ           120
# drive          1189
# eng_dscr      15403
# trany            11
# guzzler       35562
# trans_dscr    22796
# tCharger      32657
# sCharger      37177
# atvType       34771
# fuelType2     36435
# rangeA        36440
# evMotor       37281
# mfrCode       30818
# c240Dscr      37806
# c240bDscr     37807
# startStop     31705
# dtype: int64

# %%
df[['cylinders']][df['cylinders'].isna()]
# Out:
#        cylinders
# 7138         NaN
# 7139         NaN
# 8143         NaN
# 8144         NaN
# 8146         NaN
# ...          ...
# 30969        NaN
# 30972        NaN
# 30973        NaN
# 30974        NaN
# 30975        NaN
#
# [123 rows x 1 columns]

# %%
df.loc[df['cylinders'].isna(),'cylinders'].to_frame()
# Out:
#        cylinders
# 7138         NaN
# 7139         NaN
# 8143         NaN
# 8144         NaN
# 8146         NaN
# ...          ...
# 30969        NaN
# 30972        NaN
# 30973        NaN
# 30974        NaN
# 30975        NaN
#
# [123 rows x 1 columns]

# %%
null_columns[null_columns.gt(0)] / len(df)
# Out:
# cylinders     0.003250
# displ         0.003171
# drive         0.031419
# eng_dscr      0.407024
# trany         0.000291
# guzzler       0.939725
# trans_dscr    0.602384
# tCharger      0.862960
# sCharger      0.982401
# atvType       0.918823
# fuelType2     0.962794
# rangeA        0.962926
# evMotor       0.985149
# mfrCode       0.814365
# c240Dscr      0.999022
# c240bDscr     0.999049
# startStop     0.837804
# dtype: float64

# %%
null_columns[null_columns.gt(0)]
# Out:
# cylinders       123
# displ           120
# drive          1189
# eng_dscr      15403
# trany            11
# guzzler       35562
# trans_dscr    22796
# tCharger      32657
# sCharger      37177
# atvType       34771
# fuelType2     36435
# rangeA        36440
# evMotor       37281
# mfrCode       30818
# c240Dscr      37806
# c240bDscr     37807
# startStop     31705
# dtype: int64

# %%
df["cylinders","displ"] = df["cylinders"].fillna(0)

# %%
df["displ"].isna().sum()
# Out:
# 120

# %%
df[["trany","drive"]]
# Out:
#                  trany                       drive
# 0         Manual 5-spd            Rear-Wheel Drive
# 1         Manual 5-spd            Rear-Wheel Drive
# 2         Manual 5-spd           Front-Wheel Drive
# 3      Automatic 3-spd            Rear-Wheel Drive
# 4         Manual 5-spd  4-Wheel or All-Wheel Drive
# ...                ...                         ...
# 37838  Automatic 4-spd           Front-Wheel Drive
# 37839     Manual 5-spd           Front-Wheel Drive
# 37840  Automatic 4-spd  4-Wheel or All-Wheel Drive
# 37841     Manual 5-spd  4-Wheel or All-Wheel Drive
# 37842  Automatic 4-spd  4-Wheel or All-Wheel Drive
#
# [37843 rows x 2 columns]

# %%
df[df["trany"].isna()]
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 7138    0.240000         0.0        0.0        0.0      81      0.0        0
# 7139    0.282000         0.0        0.0        0.0      81      0.0        0
# 8143    0.282000         0.0        0.0        0.0      81      0.0        0
# 8144    0.312000         0.0        0.0        0.0      74      0.0        0
# 8146    0.522000         0.0        0.0        0.0      45      0.0        0
# 8147    0.270000         0.0        0.0        0.0      84      0.0        0
# 9212    0.258000         0.0        0.0        0.0      87      0.0        0
# 9213    0.522000         0.0        0.0        0.0      45      0.0        0
# 10329   0.258000         0.0        0.0        0.0      87      0.0        0
# 19097  29.964545         0.0        0.0        0.0      11      0.0        0
# 19128  23.543571         0.0        0.0        0.0      13      0.0        0
#
# ...

# %%
np.percentile(df["city08"], 46.2)
# Out:
# 17.0

# %%
df[""]
